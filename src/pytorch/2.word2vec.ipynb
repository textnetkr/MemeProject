# %% [markdown]
# # Data Load

# %%
import config
from pshmodule.utils import filemanager as fm

# %%
df = fm.load(config.origin_data)
# Out:
# extension : .pickle
# Loaded 10317 records from /Volumes/GoogleDrive/내 드라이브/MemeProject/data/temp_for_doc2vec.pickle

# %%
df.head()
# Out:
#                   content                       pos
# 0         나 중간고사 반에서 1등했어              [나, 중간고사, 반]
# 1  중간고사 점수 내가 반에서 제일 잘 받음  [중간고사, 점수, 내, 반, 제일, 받음]
# 2       나 반에서 중간 성적 제일 좋아    [나, 반, 중간, 성적, 제일, 좋아]
# 3    우리 반에서 내가 시험 제일 잘 봤다    [우리, 반, 내, 시험, 제일, 봤다]
# 4            중간고사 반 1등 먹음             [중간고사, 반, 먹음]

# %% [markdown]
# #

# %% [markdown]
# # word2vec

# %%
import swifter

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ### vocabulary

# %%
vocab_list = []
for sentence in df.pos_str:
    for s in sentence:
        vocab_list.append(s)

# %%
vocab = set(vocab_list)

# %%
vocab_size = len(vocab)

# %%
print(vocab_size)
# Out:
# 1211

# %%
w2i = {w: i for i, w in enumerate(vocab)}
i2w = {i: w for i, w in enumerate(vocab)}

# %%
print(f"w2i : {w2i}")
print(f"i2w : {i2w}")
# Out:
# w2i : {'뛰': 0, '눔': 1, '랜': 2, '입': 3, '첨': 4, '연': 5, '컴': 6, '끔': 7, '엎': 8, '생': 9, '확': 10, '떡': 11, '힙': 12, '엌': 13, '딱': 14, '멘': 15, '드': 16, '칠': 17, '샵': 18, '산': 19, '빙': 20, '옷': 21, '뀄': 22, '펌': 23, '깥': 24, '층': 25, '빽': 26, '욀': 27, '엽': 28, '순': 29, '없': 30, '플': 31, '꼭': 32, '끄': 33, '터': 34, '뽀': 35, '눈': 36, '쩜': 37, '워': 38, '낀': 39, '넓': 40, '쩔': 41, '췄': 42, '내': 43, '닦': 44, '짰': 45, '젠': 46, '몰': 47, '톤': 48, '꾸': 49, '쿡': 50, '욤': 51, '얺': 52, '싫': 53, '툰': 54, '판': 55, '리': 56, '폰': 57, '훈': 58, '못': 59, '좔': 60, '흉': 61, '랑': 62, '멤': 63, '신': 64, '맑': 65, '찬': 66, '페': 67, '렐': 68, '건': 69, '셋': 70, '펠': 71, '암': 72, '왤': 73, '찔': 74, '릭': 75, '귤': 76, '호': 77, '쉬': 78, '습': 79, '음': 80, '시': 81, '씀': 82, '듦': 83, '흰': 84, '오': 85, '쇠': 86, '딸': 87, '식': 88, '벨': 89, '냠': 90, '뜯': 91, '뢰': 92, '롯': 93, '쁠': 94, '길': 95, '말': 96, '쇼': 97, '룩': 98, '뭣': 99, '커': 100, '춘': 101, '림': 102, '붓': 103, '먼': 104, '뉴': 105, '킹': 106, '측': 107, '환': 108, '쾌': 109, '션': 110, '착': 111, '뀌': 112, '쉴': 113, '미': 114, '스': 115, '춥': 116, '츠': 117, '픈': 118, '셤': 119, '개': 120, '썩': 121, '릇': 122, '렘': 123, '겜': 124, '쨔': 125, '죠': 126, '곁': 127, '데': 128, '친': 129, '돈': 130, '밖': 131, '렇': 132, '던': 133, '첫': 134, '나': 135, '부': 136, '클': 137, '땡': 138, '쏨': 139, '흘': 140, '균': 141, '켓': 142, '캔': 143, '블': 144, '같': 145, '럼': 146, '베': 147, '둑': 148, '낳': 149, '겪': 150, '샌': 151, '촌': 152, '밂': 153, '옵': 154, '꿔': 155, '듯': 156, '겸': 157, '댔': 158, '후': 159, '텄': 160, '씹': 161, '텅': 162, '석': 163, '위': 164, '동': 165, '메': 166, '코': 167, '무': 168, '색': 169, '뜰': 170, '까': 171, '앱': 172, '쨩': 173, '잃': 174, '짖': 175, '걔': 176, '헤': 177, '솜': 178, '봇': 179, '왔': 180, '꽃': 181, '쐈': 182, '뿡': 183, '텍': 184, '립': 185, '뒈': 186, '똥': 187, '귈': 188, '뭘': 189, '휴': 190, '넌': 191, '응': 192, '거': 193, '윗': 194, '예': 195, '햄': 196, '겨': 197, '래': 198, '십': 199, '랏': 200, '꽤': 201, '꾼': 202, '샛': 203, '맣': 204, '뱄': 205, '샘': 206, '잼': 207, '댈': 208, '쥬': 209, '뻤': 210, '볍': 211, '옴': 212, '란': 213, '릴': 214, '냐': 215, '험': 216, '홉': 217, '율': 218, '날': 219, '혔': 220, '짝': 221, '슴': 222, '져': 223, '뜨': 224, '맥': 225, '룸': 226, '조': 227, '뒀': 228, '되': 229, '따': 230, '픔': 231, '센': 232, '또': 233, '튼': 234, '천': 235, '컬': 236, '름': 237, '힐': 238, '라': 239, '켰': 240, '운': 241, '찹': 242, '삶': 243, '창': 244, '둘': 245, '평': 246, '캉': 247, '혜': 248, '랗': 249, '섯': 250, '쫑': 251, '푼': 252, '받': 253, '긋': 254, '밥': 255, '을': 256, '즈': 257, '륙': 258, '실': 259, '흡': 260, '넹': 261, '아': 262, '흠': 263, '촉': 264, '집': 265, '낙': 266, '쪽': 267, '밣': 268, '꼽': 269, '풀': 270, '익': 271, '새': 272, '겟': 273, '욜': 274, '섬': 275, '교': 276, '항': 277, '폭': 278, '약': 279, '레': 280, '히': 281, '삥': 282, '악': 283, '숩': 284, '참': 285, '좀': 286, '에': 287, '로': 288, '엘': 289, '걸': 290, '떠': 291, '덕': 292, '퀘': 293, '겉': 294, '좁': 295, '뎁': 296, '게': 297, '절': 298, '대': 299, '냈': 300, '밈': 301, '삿': 302, '쩝': 303, '뚫': 304, '송': 305, '덤': 306, '둔': 307, '웨': 308, '않': 309, '걀': 310, '여': 311, '닥': 312, '었': 313, '샀': 314, '딧': 315, '깎': 316, '주': 317, '뮤': 318, '밌': 319, '체': 320, '룹': 321, '택': 322, '흐': 323, '셈': 324, '흑': 325, '그': 326, '밟': 327, '빈': 328, '뜻': 329, '억': 330, '티': 331, '늠': 332, '덥': 333, '렵': 334, '민': 335, '뜬': 336, '둬': 337, '탕': 338, '엄': 339, '님': 340, '릉': 341, '퓨': 342, '셉': 343, '흔': 344, '돋': 345, '팀': 346, '볶': 347, '텐': 348, '압': 349, '쁜': 350, '제': 351, '하': 352, '책': 353, '성': 354, '효': 355, '촬': 356, '즘': 357, '쨌': 358, '꺾': 359, '빻': 360, '빠': 361, '웠': 362, '원': 363, '졌': 364, '씩': 365, '브': 366, '넬': 367, '황': 368, '틈': 369, '캠': 370, '긴': 371, '늦': 372, '꽂': 373, '챌': 374, '엑': 375, '쌩': 376, '깊': 377, '쌈': 378, '컸': 379, '땄': 380, '낄': 381, '곳': 382, '써': 383, '핌': 384, '녹': 385, '표': 386, '늙': 387, '샴': 388, '턱': 389, '뻥': 390, '깜': 391, '충': 392, '릿': 393, '싶': 394, '눌': 395, '얜': 396, '낌': 397, '뚝': 398, '든': 399, '갱': 400, '독': 401, '컷': 402, '몇': 403, '쑤': 404, '근': 405, '즐': 406, '했': 407, '뤄': 408, '찜': 409, '먐' ...
# i2w : {0: '뛰', 1: '눔', 2: '랜', 3: '입', 4: '첨', 5: '연', 6: '컴', 7: '끔', 8: '엎', 9: '생', 10: '확', 11: '떡', 12: '힙', 13: '엌', 14: '딱', 15: '멘', 16: '드', 17: '칠', 18: '샵', 19: '산', 20: '빙', 21: '옷', 22: '뀄', 23: '펌', 24: '깥', 25: '층', 26: '빽', 27: '욀', 28: '엽', 29: '순', 30: '없', 31: '플', 32: '꼭', 33: '끄', 34: '터', 35: '뽀', 36: '눈', 37: '쩜', 38: '워', 39: '낀', 40: '넓', 41: '쩔', 42: '췄', 43: '내', 44: '닦', 45: '짰', 46: '젠', 47: '몰', 48: '톤', 49: '꾸', 50: '쿡', 51: '욤', 52: '얺', 53: '싫', 54: '툰', 55: '판', 56: '리', 57: '폰', 58: '훈', 59: '못', 60: '좔', 61: '흉', 62: '랑', 63: '멤', 64: '신', 65: '맑', 66: '찬', 67: '페', 68: '렐', 69: '건', 70: '셋', 71: '펠', 72: '암', 73: '왤', 74: '찔', 75: '릭', 76: '귤', 77: '호', 78: '쉬', 79: '습', 80: '음', 81: '시', 82: '씀', 83: '듦', 84: '흰', 85: '오', 86: '쇠', 87: '딸', 88: '식', 89: '벨', 90: '냠', 91: '뜯', 92: '뢰', 93: '롯', 94: '쁠', 95: '길', 96: '말', 97: '쇼', 98: '룩', 99: '뭣', 100: '커', 101: '춘', 102: '림', 103: '붓', 104: '먼', 105: '뉴', 106: '킹', 107: '측', 108: '환', 109: '쾌', 110: '션', 111: '착', 112: '뀌', 113: '쉴', 114: '미', 115: '스', 116: '춥', 117: '츠', 118: '픈', 119: '셤', 120: '개', 121: '썩', 122: '릇', 123: '렘', 124: '겜', 125: '쨔', 126: '죠', 127: '곁', 128: '데', 129: '친', 130: '돈', 131: '밖', 132: '렇', 133: '던', 134: '첫', 135: '나', 136: '부', 137: '클', 138: '땡', 139: '쏨', 140: '흘', 141: '균', 142: '켓', 143: '캔', 144: '블', 145: '같', 146: '럼', 147: '베', 148: '둑', 149: '낳', 150: '겪', 151: '샌', 152: '촌', 153: '밂', 154: '옵', 155: '꿔', 156: '듯', 157: '겸', 158: '댔', 159: '후', 160: '텄', 161: '씹', 162: '텅', 163: '석', 164: '위', 165: '동', 166: '메', 167: '코', 168: '무', 169: '색', 170: '뜰', 171: '까', 172: '앱', 173: '쨩', 174: '잃', 175: '짖', 176: '걔', 177: '헤', 178: '솜', 179: '봇', 180: '왔', 181: '꽃', 182: '쐈', 183: '뿡', 184: '텍', 185: '립', 186: '뒈', 187: '똥', 188: '귈', 189: '뭘', 190: '휴', 191: '넌', 192: '응', 193: '거', 194: '윗', 195: '예', 196: '햄', 197: '겨', 198: '래', 199: '십', 200: '랏', 201: '꽤', 202: '꾼', 203: '샛', 204: '맣', 205: '뱄', 206: '샘', 207: '잼', 208: '댈', 209: '쥬', 210: '뻤', 211: '볍', 212: '옴', 213: '란', 214: '릴', 215: '냐', 216: '험', 217: '홉', 218: '율', 219: '날', 220: '혔', 221: '짝', 222: '슴', 223: '져', 224: '뜨', 225: '맥', 226: '룸', 227: '조', 228: '뒀', 229: '되', 230: '따', 231: '픔', 232: '센', 233: '또', 234: '튼', 235: '천', 236: '컬', 237: '름', 238: '힐', 239: '라', 240: '켰', 241: '운', 242: '찹', 243: '삶', 244: '창', 245: '둘', 246: '평', 247: '캉', 248: '혜', 249: '랗', 250: '섯', 251: '쫑', 252: '푼', 253: '받', 254: '긋', 255: '밥', 256: '을', 257: '즈', 258: '륙', 259: '실', 260: '흡', 261: '넹', 262: '아', 263: '흠', 264: '촉', 265: '집', 266: '낙', 267: '쪽', 268: '밣', 269: '꼽', 270: '풀', 271: '익', 272: '새', 273: '겟', 274: '욜', 275: '섬', 276: '교', 277: '항', 278: '폭', 279: '약', 280: '레', 281: '히', 282: '삥', 283: '악', 284: '숩', 285: '참', 286: '좀', 287: '에', 288: '로', 289: '엘', 290: '걸', 291: '떠', 292: '덕', 293: '퀘', 294: '겉', 295: '좁', 296: '뎁', 297: '게', 298: '절', 299: '대', 300: '냈', 301: '밈', 302: '삿', 303: '쩝', 304: '뚫', 305: '송', 306: '덤', 307: '둔', 308: '웨', 309: '않', 310: '걀', 311: '여', 312: '닥', 313: '었', 314: '샀', 315: '딧', 316: '깎', 317: '주', 318: '뮤', 319: '밌', 320: '체', 321: '룹', 322: '택', 323: '흐', 324: '셈', 325: '흑', 326: '그', 327: '밟', 328: '빈', 329: '뜻', 330: '억', 331: '티', 332: '늠', 333: '덥', 334: '렵', 335: '민', 336: '뜬', 337: '둬', 338: '탕', 339: '엄', 340: '님', 341: '릉', 342: '퓨', 343: '셉', 344: '흔', 345: '돋', 346: '팀', 347: '볶', 348: '텐', 349: '압', 350: '쁜', 351: '제', 352: '하', 353: '책', 354: '성', 355: '효', 356: '촬', 357: '즘', 358: '쨌', 359: '꺾', 360: '빻', 361: '빠', 362: '웠', 363: '원', 364: '졌', 365: '씩', 366: '브', 367: '넬', 368: '황', 369: '틈', 370: '캠', 371: '긴', 372: '늦', 373: '꽂', 374: '챌', 375: '엑', 376: '쌩', 377: '깊', 378: '쌈', 379: '컸', 380: '땄', 381: '낄', 382: '곳', 383: '써', 384: '핌', 385: '녹', 386: '표', 387: '늙', 388: '샴', 389: '턱', 390: '뻥', 391: '깜', 392: '충', 393: '릿', 394: '싶', 395: '눌', 396: '얜', 397: '낌', 398: '뚝', 399: '든', 400: '갱', 401: '독', 402: '컷', 403: '몇', 404: '쑤', 405: '근', 406: '즐', 407: '했', 408: '뤄', 409: '찜', 410 ...

# %% [markdown]
# ### dataset

# %%
# context window size is two
def create_cbow_dataset(text):
    data = []
    for i in range(2, len(text) - 2):
        context = [text[i - 2], text[i - 1],
                   text[i + 1], text[i + 2]]
        target = text[i]
        data.append((context, target))
    return data

# %%
def create_skipgram_dataset(text):
    import random
    data = []
    for i in range(2, len(text) - 2):
        data.append((text[i], text[i-2], 1))
        data.append((text[i], text[i-1], 1))
        data.append((text[i], text[i+1], 1))
        data.append((text[i], text[i+2], 1))
        # negative sampling
        for _ in range(4):
            if random.random() < 0.5 or i >= len(text) - 3:
                rand_id = random.randint(0, i-1)
            else:
                rand_id = random.randint(i+3, len(text)-1)
            data.append((text[i], text[rand_id], 0))
    return data

# %%
df['cbow'] = df.pos.swifter.apply(create_cbow_dataset)
df['skipgram'] = df.pos.swifter.apply(create_skipgram_dataset)
# Out:
# Pandas Apply:   0%|          | 0/10317 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/10317 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#                   content                       pos  \
# 0         나 중간고사 반에서 1등했어              [나, 중간고사, 반]
# 1  중간고사 점수 내가 반에서 제일 잘 받음  [중간고사, 점수, 내, 반, 제일, 받음]
# 2       나 반에서 중간 성적 제일 좋아    [나, 반, 중간, 성적, 제일, 좋아]
# 3    우리 반에서 내가 시험 제일 잘 봤다    [우리, 반, 내, 시험, 제일, 봤다]
# 4            중간고사 반 1등 먹음             [중간고사, 반, 먹음]
#
#                                              cbow  \
# 0                                              []
# 1  [([중간고사, 점수, 반, 제일], 내), ([점수, 내, 제일, 받음], 반)]
# 2   [([나, 반, 성적, 제일], 중간), ([반, 중간, 제일, 좋아], 성적)]
# 3    [([우리, 반, 시험, 제일], 내), ([반, 내, 제일, 봤다], 시험)]
# 4                                              []
#
#                                             skipgram
# 0                                                 []
# 1  [(내, 중간고사, 1), (내, 점수, 1), (내, 반, 1), (내, 제일, ...
# 2  [(중간, 나, 1), (중간, 반, 1), (중간, 성적, 1), (중간, 제일,...
# 3  [(내, 우리, 1), (내, 반, 1), (내, 시험, 1), (내, 제일, 1)...
# 4                                                 []

# %% [markdown]
# ### model

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_size, embd_size):
        super(SkipGram, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embd_size)
    
    def forward(self, focus, context):
        embed_focus = self.embeddings(focus).view((1, -1))
        embed_ctx = self.embeddings(context).view((1, -1))
        score = torch.mm(embed_focus, torch.t(embed_ctx))
        log_probs = F.logsigmoid(score)
    
        return log_probs

# %%
def train_skipgram():
    losses = []
    loss_fn = nn.MSELoss()
    model = SkipGram(vocab_size, embd_size)
    print(model)
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    
    for epoch in range(n_epoch):
        total_loss = .0
        for in_w, out_w, target in skipgram_train:
            in_w_var = Variable(torch.LongTensor([w2i[in_w]]))
            out_w_var = Variable(torch.LongTensor([w2i[out_w]]))
            
            model.zero_grad()
            log_probs = model(in_w_var, out_w_var)
            loss = loss_fn(log_probs[0], Variable(torch.Tensor([target])))
            
            loss.backward()
            optimizer.step()

            total_loss += loss.data[0]
        losses.append(total_loss)
    return model, losses

# %%
embd_size = 100
learning_rate = 0.001
n_epoch = 30

# %%
sg_model, sg_losses = train_skipgram()

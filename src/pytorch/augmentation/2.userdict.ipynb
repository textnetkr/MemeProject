# %% [markdown]
# # import

# %%
# !pip3 install swifter

# %%
# !pip3 install pshmodule

# %%
# !pip3 install pickle5

# %%
# !pip3 install pandas==1.5.0

# %%
# !pip3 install kiwipiepy

# %%
# !pip3 install konlpy

# %%
# !pip3 install jamo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jamo in /usr/local/lib/python3.9/dist-packages (0.4.1)

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Load

# %%
import sys
sys.path.append('/content/drive/MyDrive/MemeProject/src/pytorch/augmentation')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python39.zip', '/usr/lib/python3.9', '/usr/lib/python3.9/lib-dynload', '', '/usr/local/lib/python3.9/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.9/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/MemeProject/src/pytorch/augmentation']

# %%
import swifter
import config as cfg
from pprint import pprint
from pshmodule.utils import filemanager as fm

# %%
df = fm.load(cfg.aug_first)
# Out:
# extension : .pickle
# Loaded 87221 records from drive/MyDrive/MemeProject/data/augmentation/aug_1.pickle

# %%
df.head()
# Out:
#   g_num u_num material speech                  u  arg1 arg_op1 arg_op2 label
# 0  2210     6       음식     의지  나 다시는 라면 안 먹을 거야!    라면     다시는            98
# 1     1     1     학교생활     자랑    나 중간고사 반에서 1등했어  중간고사                   147
# 2     1     1     학교생활     자랑    나 중간시험 반에서 1등했어  중간시험                   147
# 3     1     1     학교생활     자랑      나 중간 반에서 1등했어    중간                   147
# 4     1     1     학교생활     자랑      나 시험 반에서 1등했어    시험                   147

# %%
# 정렬
# df.sort_values(['g_num', 'u_num'], ascending=True, inplace=True)
# df.reset_index(drop=True, inplace=True)

# int→str
df = df.astype({'g_num':'str', 'u_num':'str', 'label':'str'})
df['g_num'] = df.g_num.apply(lambda x: x.replace('.0', ''))
df['u_num' ] = df.u_num.apply(lambda x: x.replace('.0', ''))
df['label'] = df.label.apply(lambda x: x.replace('.0', ''))

# %%
user_dict = fm.load(cfg.user_dict)
# Out:
# extension : .xlsx
# Loaded 5103 records from /content/drive/MyDrive/MemeProject/data/user_dict/UGCD.xlsx
# /usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# Dict

# %%
user_dict_2 = user_dict[5:]
user_dict_2.columns = user_dict.iloc[5]
user_dict_2.reset_index(drop=True, inplace=True)

# %%
user_dict_2 = user_dict_2[1:]
user_dict_2 = user_dict_2[['표제어', '기본형', '품사', '감정1', '연령', '용례', '반의어']]
user_dict_2.rename(columns={'표제어':'lemma', '기본형':'formal', '품사':'pos', '감정1':'sentiment', '연령':'age', '용례':'example', '반의어':'antonym'}, inplace=True)
user_dict_2.reset_index(drop=True, inplace=True)

# %%
user_dict_2.head(10)
# Out:
# 5    lemma formal pos sentiment  age           example antonym
# 0      가지다    가지다  VV       Neu  NaN         그거 내가 가진다     버리다
# 1       갖다    가지다  VV       Neu  NaN      이 지갑은 내가 갖는다     버리다
# 2   내 거 하다    가지다  VV       Hap   MZ        걔 내 거 할 거야     NaN
# 3     소유하다    가지다  VV       Hap  NaN     그 신발은 이미 소유했어     버리다
# 4     보유하다    가지다  VV       Hap  NaN  나도 그 아이템 보유하고 싶어     버리다
# 5      겟하다    가지다  VV       Hap   MZ           드디어 겟했다     버리다
# 6     겟또하다    가지다  VV       Hap   MZ          피규어 겟또했음     버리다
# 7     득템하다    가지다  VV       Hap   MZ          신상템 득템했다     버리다
# 8  굴러들어 오다    가지다  VV       Hap  NaN      꽁돈이 굴러들어 왔음!     NaN
# 9    손에 넣다    가지다  VV       Hap  NaN    한정판 운동화 손에 넣었다     NaN

# %%
user_dict_2.shape
# Out:
# (5097, 7)

# %%
user_dict_3 = user_dict_2[~user_dict_2.lemma.isnull()]

# %%
user_dict_3.shape
# Out:
# (3315, 7)

# %%
user_dict_3.pos.value_counts()
# Out:
# VV     1398
# NN     1234
# VA      308
# MAG     154
# NNP      82
# IC       74
# EO       46
# NP       17
# MM        2
# Name: pos, dtype: int64

# %% [markdown]
# Tag Mapping

# %% [markdown]
# Okt

# %%
def okt(pos):
  result = ""
  if pos in ['NN', 'NNP', 'NR', 'NP']:
    result = "Noun" # 명사
  elif pos == "VV":
    result = "Verb" # 동사
  elif pos == "VA":
    result = "Adjective" # 형용사
  elif pos == "MM":
    result = "Determiner" # 관형사
  elif pos in ['MAG', 'MAJ']:
    result = "Adverb" # 부사
  elif pos == "IC":
    result = "Exclamation" # 감탄사
  elif pos == "JO":
    result = "Josa" # 조사
  elif pos == "EO":
    result = "Eomi" # 어미
  return result

# %%
user_dict_3['okt_pos'] = user_dict_3.pos.swifter.apply(okt)
# Out:
# Pandas Apply:   0%|          | 0/3315 [00:00<?, ?it/s]
# <ipython-input-25-780ddc5911d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_dict_3['okt_pos'] = user_dict_3.pos.swifter.apply(okt)

# %%
user_dict_3.head()
# Out:
# 5   lemma formal pos sentiment  age           example antonym okt_pos
# 0     가지다    가지다  VV       Neu  NaN         그거 내가 가진다     버리다    Verb
# 1      갖다    가지다  VV       Neu  NaN      이 지갑은 내가 갖는다     버리다    Verb
# 2  내 거 하다    가지다  VV       Hap   MZ        걔 내 거 할 거야     NaN    Verb
# 3    소유하다    가지다  VV       Hap  NaN     그 신발은 이미 소유했어     버리다    Verb
# 4    보유하다    가지다  VV       Hap  NaN  나도 그 아이템 보유하고 싶어     버리다    Verb

# %% [markdown]
# Mecab

# %%
def mecab(pos):
  result = ""
  if pos == "NN":
    result = "NNG" # 일반 명사
  elif pos == "NNP":
    result = "NNP" # 고유 명사
  elif pos == "NR":
    result = "NR" # 수사
  elif pos == "NP":
    result = "NP" # 대명사
  elif pos == "VV":
    result = "VV" # 동사
  elif pos == "VA":
    result = "VA" # 형용사
  elif pos == "MM":
    result = "MM" # 관형사
  elif pos == "MAG":
    result = "MAG" # 일반부사
  elif pos == "MAJ":
    result = "MAJ" # 접속부사
  elif pos == "IC":
    result = "IC" # 감탄사
  elif pos == "JO":
    result = "JKS" # 조사
  elif pos == "EO":
    result = "EF" # 조사
  return result

# %%
user_dict_3['mecab_pos'] = user_dict_3.pos.swifter.apply(mecab)
# Out:
# Pandas Apply:   0%|          | 0/3315 [00:00<?, ?it/s]
# <ipython-input-28-ed5046f81635>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_dict_3['mecab_pos'] = user_dict_3.pos.swifter.apply(mecab)

# %% [markdown]
# # Add Dict

# %% [markdown]
# ### Okt

# %% [markdown]
# test

# %%
import konlpy
konlpy.data.path
# Out:
# ['/root/konlpy_data',
#  '/usr/share/konlpy_data',
#  '/usr/local/share/konlpy_data',
#  '/usr/lib/konlpy_data',
#  '/usr/local/lib/konlpy_data',
#  '/usr/local/lib/python3.8/dist-packages/konlpy/data']

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
user_dict_3.pos.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-f3112a890604> in <module>
# ----> 1 user_dict_3.pos.value_counts()
#
# NameError: name 'user_dict_3' is not defined

# %%
user_dict_3[user_dict_3.pos=='VA']
# Out:
# 5           lemma formal pos sentiment  age                  example antonym  \
# 30            귀엽다    귀엽다  VA       Hap  NaN                    나 귀여워     NaN
# 31        쏘 러블리하다    귀엽다  VA       Hap   MZ                 너 쏘 러블리해     NaN
# 32          존귀탱이다    귀엽다  VA       Hap   MZ                   님 존귀탱임     NaN
# 33         쏘 큐트하다    귀엽다  VA       Hap   MZ                 얘 쏘 큐트하다     NaN
# 34        초 카와이하다    귀엽다  VA       Hap   MZ                이거 초 카와이해     NaN
# ...           ...    ...  ..       ...  ...                      ...     ...
# 3241       눈물버튼이다    슬프다  VA       Sad   MZ             이거 내 눈물버튼인데.     NaN
# 3242         비상이다    슬프다  VA       Sad   MZ            비상이다... 비상...     NaN
# 3265          꾸꾸꾸    꾸꾸꾸  VA       Dis   MZ                뭘 해도 꾸꾸꾸다     NaN
# 3266  꾸며도 꾸질 꾸질하다    꾸꾸꾸  VA       Dis   MZ  내 주변에 꾸며도 꾸질 꾸질한 사람 있음ㅋ     NaN
# 3295         빼박캔트    못하다  VA       Sad   MZ             빼박캔트 개강이라는 것     NaN
#
# 5       okt_pos mecab_pos
# 30    Adjective        VA
# 31    Adjective        VA
# 32    Adjective        VA
# 33    Adjective        VA
# 34    Adjective        VA
# ...         ...       ...
# 3241  Adjective        VA
# 3242  Adjective        VA
# 3265  Adjective        VA
# 3266  Adjective        VA
# 3295  Adjective        VA
#
# [308 rows x 9 columns]

# %%
print(okt.pos('핸드폰을 겟또하다.'))
print(okt.pos('동전을 득템하다.'))
print(okt.pos('가상화폐를 살거야'))
print(okt.pos('틀니딱딱 거리지마~'))
print(okt.pos('엄마가 젤루 좋아'))
print(okt.pos('이번엔 틀림없이 합격할 거야'))
print(okt.pos('쏘 러블리하다'))
# Out:
# [('핸드폰', 'Noun'), ('을', 'Josa'), ('겟또하다', 'Verb'), ('.', 'Punctuation')]
# [('동전', 'Noun'), ('을', 'Josa'), ('득템하다', 'Verb'), ('.', 'Punctuation')]
# [('가상화폐', 'Noun'), ('를', 'Josa'), ('살거야', 'Verb')]
# [('틀니딱딱', 'Noun'), ('거리', 'Noun'), ('지', 'Josa'), ('마', 'Noun'), ('~', 'Punctuation')]
# [('엄마', 'Noun'), ('가', 'Josa'), ('젤루', 'Adverb'), ('좋아', 'Adjective')]
# [('이번', 'Noun'), ('엔', 'Josa'), ('틀림없이', 'Adverb'), ('합격', 'Noun'), ('할', 'Verb'), ('거야', 'Eomi')]
# [('쏘', 'Verb'), ('러블리하다', 'Adjective')]

# %% [markdown]
# add dict

# %%
import os

os.chdir('/usr/local/lib/python3.8/dist-packages/konlpy/java')
os.getcwd()
# Out:
# '/usr/local/lib/python3.8/dist-packages/konlpy/java'

# %%
# !ls
# Out:
# aho-corasick.jar     kkma-2.0.jar		 shineware-ds-1.0.jar
# bin		     komoran-3.0.jar		 snakeyaml-1.12.jar
# conf		     open-korean-text-2.1.0.jar  twitter-text-1.14.7.jar
# data		     scala-library-2.12.3.jar
# jhannanum-0.8.4.jar  shineware-common-1.0.jar

# %%
# !jar xvf open-korean-text-2.1.0.jar

# %%
user_dict_3.okt_pos.value_counts()
# Out:
# Verb           1398
# Noun           1333
# Adjective       308
# Adverb          154
# Exclamation      74
# Eomi             46
# Determiner        2
# Name: okt_pos, dtype: int64

# %%
paths = {
    'noun/nouns.txt':'Noun',
    'verb/verb.txt':'Verb',
    'adjective/adjective.txt':'Adjective',
    'adverb/adverb.txt':'Adverb',
    'josa/josa.txt':'Josa',
    'auxiliary/exclamation.txt':'Exclamation',
    'verb/eomi.txt':'Eomi',
    'auxiliary/determiner.txt':'Determiner'
}

# %%
for p in paths:
  with open(f"/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/{p}") as f:
    data = f.read()
  
  data += '\n'.join(map(str, user_dict_3[user_dict_3.okt_pos == paths[p]].lemma.tolist())) + '\n'
  
  with open(f"/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/{p}", 'w') as f:
    f.write(data)
  data = ""

# %%
# !ls /usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util
# Out:
# ls: cannot access '/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util': No such file or directory

# %%
with open(f"/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/adjective/adjective.txt") as f:
  data = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-50235daa5f40> in <module>
# ----> 1 with open(f"/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/adjective/adjective.txt") as f:
#       2   data = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/adjective/adjective.txt'

# %%
# !ls /usr/local/lib/python3.8/dist-packages/konlpy/java
# Out:
# aho-corasick.jar     kkma-2.0.jar		 scala-library-2.12.3.jar
# bin		     komoran-3.0.jar		 shineware-common-1.0.jar
# conf		     META-INF			 shineware-ds-1.0.jar
# data		     open-korean-text-2.1.0.jar  snakeyaml-1.12.jar
# jhannanum-0.8.4.jar  org			 twitter-text-1.14.7.jar

# %%
# !rm open-korean-text-2.1.0.jar
# !jar cvf open-korean-text-2.1.0.jar org
# !rm -rf org

# %% [markdown]
# check

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
print(f"겟또하다 Verb : {okt.pos('핸드폰을 겟또하다.')}")
print(f"득템하다 Verb : {okt.pos('동전을 득템하다.')}")
print(f"가상화폐 Noun : {okt.pos('가상화폐를 살거야')}")
print(f"틀니딱딱 Noun : {okt.pos('틀니딱딱 거리지마~')}")
print(f"젤루 Adverb : {okt.pos('엄마가 젤루 좋아')}")
print(f"틀림없이 Adverb : {okt.pos('이번엔 틀림없이 합격할 거야')}")
print(f"쏘 러블리하다 Adjective : {okt.pos('쏘 러블리하다')}")
print(f"가죽 무늬 Noun : {okt.pos('가죽 무늬 지갑을 샀어!')}")
print(f"러블리 그 잡채다 Verb : {okt.pos('러블리 그 잡채다')}")
# Out:
# 겟또하다 Verb : [('핸드폰', 'Noun'), ('을', 'Josa'), ('겟또하다', 'Verb'), ('.', 'Punctuation')]
# 득템하다 Verb : [('동전', 'Noun'), ('을', 'Josa'), ('득템하다', 'Verb'), ('.', 'Punctuation')]
# 가상화폐 Noun : [('가상화폐', 'Noun'), ('를', 'Josa'), ('살거야', 'Verb')]
# 틀니딱딱 Noun : [('틀니딱딱', 'Noun'), ('거리', 'Noun'), ('지', 'Josa'), ('마', 'Noun'), ('~', 'Punctuation')]
# 젤루 Adverb : [('엄마', 'Noun'), ('가', 'Josa'), ('젤루', 'Adverb'), ('좋아', 'Adjective')]
# 틀림없이 Adverb : [('이번', 'Noun'), ('엔', 'Josa'), ('틀림없이', 'Adverb'), ('합격', 'Noun'), ('할', 'Verb'), ('거야', 'Eomi')]
# 쏘 러블리하다 Adjective : [('쏘', 'Verb'), ('러블리하다', 'Adjective')]
# 가죽 무늬 Noun : [('가죽', 'Noun'), ('무늬', 'Noun'), ('지갑', 'Noun'), ('을', 'Josa'), ('샀어', 'Verb'), ('!', 'Punctuation')]
# 러블리 그 잡채다 Verb : [('러블리', 'Noun'), ('그', 'Noun'), ('잡채', 'Noun'), ('다', 'Josa')]

# %% [markdown]
# ### Kiwi

# %% [markdown]
# #### Install

# %%
from kiwipiepy import Kiwi
from kiwipiepy.utils import Stopwords

from tqdm import tqdm
import pandas as pd
from pshmodule.processing import processing as p

# %%
kiwi = Kiwi()
stopwords = Stopwords()

# %% [markdown]
# #### UserDict Add

# %% [markdown]
# 1. 일단 사용자 사전을 공백을 제거 후 등록(불변어 기준)
# 2. 토크나이징 할 때 어떤 문장이 들어오면 공백 제거 후 토큰화

# %%
constant = ['NNG', 'NNP', 'NR', 'NP', 'MM', 'MAG', 'MAJ', 'IC']

# %%
# 합성어 기준
for c in constant:
  for i in user_dict_3[user_dict_3.mecab_pos==c].iterrows():
    kiwi.add_user_word(str(i[1]['lemma']).replace(' ', ''), c, 0)

# %% [markdown]
# #### Augmentation

# %% [markdown]
# 1. 입력 문과 사용자 사전 표제어를 하은 님이 추출해준 실질 형태소&불변어 들만 살린 후 사용자 사전 실질 형태소가 입력 문 실질 형태소에 있는지를 비교함.<br>
# 2. 포함이 있으면 유의어 셋으로 교체하는 방법 - 가변어, 사용자 사전 추가 불변어는 공백 제거로 비교 후 교체(키 밸류로 원본 들고 있다가 교체 후 뱉기? 확인)<br>
# 3. 테스트 : 품사 별로 용례가 입력문으로 가정해서 표제어랑 비교해서 위 상황이 비교될만 한지

# %% [markdown]
# * 동사, 형용사 등 가변어는 형태소 분석 과정에서 어근 추출을 잘 못하거나 품사를 다르게 추출하는 경우가 생겨서 좀 더 고민이 필요해 보이고 따라서 불변어 위주로 교체가 우선으로 되려고 함.

# %% [markdown]
# 평균 미만

# %%
count = {i[1]['label']: 0 for i in df.iterrows()}
for i in df.iterrows():
  count[i[1]['label']] += 1
sorted_dict = dict(sorted(count.items(), key = lambda item: item[1], reverse = True))

# %%
sorted_dict
# Out:
# {18: 2508,
#  110: 1867,
#  108: 1714,
#  16: 1571,
#  28: 1429,
#  66: 1285,
#  102: 1173,
#  146: 1129,
#  94: 1113,
#  144: 1100,
#  128: 1090,
#  96: 1069,
#  63: 1029,
#  119: 987,
#  36: 983,
#  41: 939,
#  33: 937,
#  134: 936,
#  42: 927,
#  31: 902,
#  100: 899,
#  46: 895,
#  0: 891,
#  78: 887,
#  148: 872,
#  121: 862,
#  9: 861,
#  81: 858,
#  34: 855,
#  92: 832,
#  142: 828,
#  80: 820,
#  48: 772,
#  52: 769,
#  47: 763,
#  101: 761,
#  2: 756,
#  62: 755,
#  8: 744,
#  143: 738,
#  67: 730,
#  50: 722,
#  151: 720,
#  152: 714,
#  68: 713,
#  153: 708,
#  150: 702,
#  17: 687,
#  89: 673,
#  20: 673,
#  4: 672,
#  60: 672,
#  75: 654,
#  135: 632,
#  138: 628,
#  132: 609,
#  7: 608,
#  104: 600,
#  123: 599,
#  126: 596,
#  3: 592,
#  12: 589,
#  59: 581,
#  21: 581,
#  97: 576,
#  74: 564,
#  44: 554,
#  64: 545,
#  49: 544,
#  6: 543,
#  115: 539,
#  140: 536,
#  73: 528,
#  106: 510,
#  111: 504,
#  114: 504,
#  13: 503,
#  127: 501,
#  32: 498,
#  53: 495,
#  109: 495,
#  120: 484,
#  38: 478,
#  19: 475,
#  145: 474,
#  71: 467,
#  25: 465,
#  118: 465,
#  98: 456,
#  72: 449,
#  61: 438,
#  57: 434,
#  51: 431,
#  91: 423,
#  26: 422,
#  107: 419,
#  82: 412,
#  39: 409,
#  54: 408,
#  141: 407,
#  117: 403,
#  99: 400,
#  95: 394,
#  136: 393,
#  124: 377,
#  93: 371,
#  139: 366,
#  147: 365,
#  88: 365,
#  24: 364,
#  40: 361,
#  125: 355,
#  15: 335,
#  85: 316,
#  58: 314,
#  29: 308,
#  22: 305,
#  122: 294,
#  37: 294,
#  70: 281,
#  65: 280,
#  10: 274,
#  45: 274,
#  103: 268,
#  129: 267,
#  43: 265,
#  1: 264,
#  77: 249,
#  133: 240,
#  112: 236,
#  137: 234,
#  14: 229,
#  11: 221,
#  130: 220,
#  105: 210,
#  87: 207,
#  131: 198,
#  27: 194,
#  90: 181,
#  69: 177,
#  76: 176,
#  149: 162,
#  84: 158,
#  116: 155,
#  5: 147,
#  55: 141,
#  79: 115,
#  23: 98,
#  86: 75,
#  83: 70,
#  56: 68,
#  113: 50,
#  35: 33,
#  30: 8}

# %%
average = round(sum([i[1] for i in sorted_dict.items()]) / len(sorted_dict))

upper_average = dict({i for i in sorted_dict.items() if i[1] >= average})
under_average = dict({i for i in sorted_dict.items() if i[1] < average})

print(f"평균 : {average}")
print(f"평균 미만 건수 : {sum([i[1] for i in under_average.items() if i[1] < average])}")

upper_average_temp = [[i[1]['g_num'], i[1]['u_num'], i[1]['material'], i[1]['speech'], i[1]['u'], i[1]['arg1'], i[1]['arg_op1'], i[1]['arg_op2'], i[1]['label']] for i in df.iterrows() if i[1]['label'] in upper_average.keys()]
under_average_temp = [[i[1]['g_num'], i[1]['u_num'], i[1]['material'], i[1]['speech'], i[1]['u'], i[1]['arg1'], i[1]['arg_op1'], i[1]['arg_op2'], i[1]['label']] for i in df.iterrows() if i[1]['label'] in under_average.keys()]

df_upper_average = pd.DataFrame(upper_average_temp, columns=['g_num', 'u_num', 'material', 'speech', 'u', 'arg1', 'arg_op1', 'arg_op2', 'label'])
df_under_average = pd.DataFrame(under_average_temp, columns=['g_num', 'u_num', 'material', 'speech', 'u', 'arg1', 'arg_op1', 'arg_op2', 'label'])
# Out:
# 평균 : 566
# 평균 미만 건수 : 29884

# %% [markdown]
# 사용자 사전 - 실질 형태소 & 불변어만

# %%
morpheme = ['NNG', 'NNP', 'NNB', 'NR', 'NP', 'MM', 'MAG', 'MAJ', 'IC']

stopwords = "은/는/이/가/을/를/와/과/이랑/랑/도/로/으로/에서/에게/한테/부터/까지/에/만/와도/와는/과도/과는/이랑도/이랑은/랑도/랑은/로는/에는/에도/까지도/한테도/한테는"
stop_list = stopwords.split("/")

# %%
user_dict = [[i[1]['lemma'], i[1]['formal'], i[1]['pos'], i[1]['sentiment'], i[1]['age'], i[1]['example'], i[1]['antonym'], i[1]['okt_pos'], i[1]['mecab_pos']] for i in user_dict_3.iterrows() if i[1]['mecab_pos'] in morpheme]
df_userdict = pd.DataFrame(user_dict, columns=['lemma', 'formal', 'pos', 'sentiment', 'age', 'example', 'antonym', 'okt_pos', 'mecab_pos'])

# %%
df_userdict.head()
# Out:
#   lemma formal  pos sentiment  age      example antonym okt_pos mecab_pos
# 0    가장     가장  MAG       Neu  NaN   그게 가장 예쁘더라     NaN  Adverb       MAG
# 1    제일     가장  MAG       Neu  NaN     너가 제일 좋아     NaN  Adverb       MAG
# 2     젤     가장  MAG       Neu   MZ    젤 많이 먹어야지     NaN  Adverb       MAG
# 3    젤루     가장  MAG       Neu   MZ  난 귀신이 젤루 싫어     NaN  Adverb       MAG
# 4   최고로     가장  MAG       Neu   MZ    최고로 성능 좋지     NaN  Adverb       MAG

# %% [markdown]
# 증강 작업

# %%
from trie import Trie
from itertools import compress

# %%
df_under_average.shape
# Out:
# (29884, 9)

# %%
# userdict trie 실질 형태소 & 불변어
trie = Trie()

udict = [[f"{k[0]}, {k[1]}" for k in kiwi.tokenize(str(ii[1]['lemma']).replace(' ', '')) if k[1] in morpheme] for ii in df_userdict.iterrows()]
for d in udict:
  if d:
    trie.insert(str(d[0]))

# %%
text = '토요일에 남돌 팬싸 가게 됐지롱'

print([f"{i[0]}, {i[1]}" for i in kiwi.tokenize(text.replace(' ', ''))])
# Out:
# ['토요일, NNG', '에, JKB', '남, NNG', '돌, NNG', '팬싸, NNG', '가게, NNG', '되, VV', '었, EP', '지, EF', '롱, NNP']

# %%
df_under_average_temp = df_under_average[df_under_average.g_num==2210]

# %%
df_under_average_temp.head()
# Out:
#        g_num u_num material speech                    u arg1 arg_op1 arg_op2  \
# 0       2210     6       음식     의지    나 다시는 라면 안 먹을 거야!   라면     다시는
# 29878   2210     1       음식     의지         라면 끊을 거다...!   라면
# 29879   2210     2       음식     의지  나 이제 라면 절대 안 먹을 거!!   라면      이제
# 29880   2210     2       음식     의지  나 이제 라면 절대 안 먹을 거!!   라면
# 29881   2210     3       음식     의지      라면 쳐다보지도 않겠다,,,   라면
#
#        label
# 0         98
# 29878     98
# 29879     98
# 29880     98
# 29881     98

# %%
# trie 구조로 속도 개선

# 증강 할 유저 발화 86,141건 중 평균 559 중 미만 데이터 29,489건
result = []
for k, v in tqdm(enumerate(df_under_average.iterrows())):
  # 원본
  result.append([v[1]['g_num'], v[1]['u_num'], v[1]['material'], v[1]['speech'], v[1]['u'], v[1]['arg1'], v[1]['arg_op1'], v[1]['arg_op2'], '', v[1]['label']])

  input = [f"{i[0]}, {i[1]}" for i in kiwi.tokenize(v[1]['u'].replace(' ', '')) if i[1] in morpheme]
  check = sum([i in input for i in sum(udict, [])])
  # input 토큰 iterable
  for i in input:
    # trie 검색
    if trie.search(i):
      replace_set = list(set(df_userdict[df_userdict.formal == i.split(',')[0]].lemma.tolist()))
      if len(replace_set) > 1:
        # 교체될 단어가 문장의 첫 어절이면 스페이스를 뒤만.
        # 교체될 단어가 문장의 첫 어절이 아니면 스페이스를 앞뒤로.
        for kk, vv in enumerate(replace_set):
          replace_set_copy = replace_set.copy()
          replace_set_copy.pop(kk)

          for r in replace_set_copy:
            # 어절이 맨 앞인 경우
            if str(v[1]['u']).find(str(vv)) == 0 and str(v[1]['u']) != str(v[1]['u']).replace(str(vv)+" ", str(r)+" "):              
              result.append([v[1]['g_num'], v[1]['u_num'], v[1]['material'], v[1]['speech'], str(v[1]['u']).replace(str(vv)+" ", str(r)+" "), v[1]['arg1'], v[1]['arg_op1'], v[1]['arg_op2'], str(r), v[1]['label']])
            # 어절이 중간에 있는 경우
            elif str(v[1]['u']).find(str(vv)) > 0 and str(v[1]['u']) != str(v[1]['u']).replace(" "+str(vv)+" ", " "+r+" "):
              result.append([v[1]['g_num'], v[1]['u_num'], v[1]['material'], v[1]['speech'], str(v[1]['u']).replace(" "+str(vv)+" ", " "+str(r)+" "), v[1]['arg1'], v[1]['arg_op1'], v[1]['arg_op2'], str(r), v[1]['label']])
            # 조사는 어절의 뒤에 붙기 때문에 목적어를 찾아 뒤에 말에 조사가 있는지를 판단해서 ex) 올림픽 은메달도 -> 올림픽 은메달 x
            for s in stop_list:
              if str(v[1]['u']).find(str(vv)+s+" ") >= 0:
                # 교체할 말이 있는 경우 말이 중복이 생겨 매끄럽지 않기 때문에 제외
                if str(v[1]['u']).find(str(r)+s+" ") < 0:
                  temp = str(v[1]['u']).replace(str(vv)+s+" ", p.jongsung_rep(str(r), s)+" ").split() # 조사 결합 시 종성 체크 후 맞는 조사를 붙여 자연스러운 문장 추가
                  temp_result = " ".join(list(dict.fromkeys(temp)))
                  result.append([v[1]['g_num'], v[1]['u_num'], v[1]['material'], v[1]['speech'], temp_result, v[1]['arg1'], v[1]['arg_op1'], v[1]['arg_op2'], str(r), v[1]['label']])
# Out:
# 29884it [03:57, 126.03it/s]

# %%
result[:5]
# Out:
# [[2210, '6', '음식', '의지', '나 다시는 라면 안 먹을 거야!', '라면', '다시는', '', '', 98],
#  [2210, '6', '음식', '의지', '와타시 다시는 라면 안 먹을 거야!', '라면', '다시는', '', '와타시', 98],
#  [2210, '6', '음식', '의지', '와따시 다시는 라면 안 먹을 거야!', '라면', '다시는', '', '와따시', 98],
#  [1, 1, '학교생활', '자랑', '나 중간고사 반에서 1등했어', '중간고사', '', '', '', 147],
#  [1, 1, '학교생활', '자랑', '와타시 중간고사 반에서 1등했어', '중간고사', '', '', '와타시', 147]]

# %%
df_under_aug = pd.DataFrame(result, columns=['g_num', 'u_num', 'material', 'speech', 'u', 'arg1', 'arg_op1', 'arg_op2', 'user_dic', 'label'])

# %%
df_under_aug.drop_duplicates(inplace=True)
df_under_aug.reset_index(drop=True, inplace=True)

# %%
df_under_aug.label.value_counts()
# Out:
# 147    2312
# 51     1929
# 57     1842
# 65     1673
# 106    1646
#        ...
# 86      143
# 83       90
# 113      50
# 35       33
# 30        8
# Name: label, Length: 89, dtype: int64

# %%
df_under_aug.shape
# Out:
# (64070, 10)

# %%
df_upper_average['user_dic'] = ''
df_upper_average = df_upper_average[['g_num', 'u_num', 'material', 'speech', 'u', 'arg1', 'arg_op1', 'arg_op2', 'user_dic', 'label']]
df_temp = pd.concat([df_under_aug, df_upper_average])

# %%
df_temp.drop_duplicates(inplace=True)
df_temp.reset_index(drop=True, inplace=True)

# %% [markdown]
# 같은 단어 반복 삭제

# %%
u_rep = [' '.join(list(dict.fromkeys(i[1]['u'].split()))) for i in df_temp.iterrows()]
df_temp['u'] = u_rep

# %%
df_temp.shape
# Out:
# (121407, 10)

# %%
df_temp.iloc[30:40]
# Out:
#     g_num u_num material speech                         u  arg1 arg_op1  \
# 30      1     3     학교생활     자랑     와타시 반에서 중간고사 성적 제일 좋아  중간고사
# 31      1     3     학교생활     자랑     와따시 반에서 중간고사 성적 제일 좋아  중간고사
# 32      1     3     학교생활     자랑         나 반에서 시험 성적 제일 좋아    시험
# 33      1     3     학교생활     자랑       와타시 반에서 시험 성적 제일 좋아    시험
# 34      1     3     학교생활     자랑       와따시 반에서 시험 성적 제일 좋아    시험
# 35      1     3     학교생활     자랑          나 반에서 셤 성적 제일 좋아    시험
# 36      1     4     학교생활     자랑      우리 반에서 내가 시험 제일 잘 봤다    시험
# 37      1     4     학교생활     자랑       우리 반에서 내가 셤 제일 잘 봤다    시험
# 38      1     4     학교생활     자랑  우리 반에서 내가 시험 제일 알잘딱깔센 봤다    시험
# 39      1     4     학교생활     자랑    우리 반에서 내가 중간시험 제일 잘 봤다  중간시험
#
#    arg_op2 user_dic  label
# 30              와타시    147
# 31              와따시    147
# 32                     147
# 33              와타시    147
# 34              와따시    147
# 35                셤    147
# 36                     147
# 37                셤    147
# 38            알잘딱깔센    147
# 39                     147

# %%
df_temp[df_temp.g_num == 2210]
# Out:
#        g_num u_num material speech                      u arg1 arg_op1  \
# 0       2210     6       음식     의지      나 다시는 라면 안 먹을 거야!   라면     다시는
# 1       2210     6       음식     의지    와타시 다시는 라면 안 먹을 거야!   라면     다시는
# 2       2210     6       음식     의지    와따시 다시는 라면 안 먹을 거야!   라면     다시는
# 64060   2210     1       음식     의지           라면 끊을 거다...!   라면
# 64061   2210     2       음식     의지    나 이제 라면 절대 안 먹을 거!!   라면      이제
# 64062   2210     2       음식     의지  와타시 이제 라면 절대 안 먹을 거!!   라면      이제
# 64063   2210     2       음식     의지  와따시 이제 라면 절대 안 먹을 거!!   라면      이제
# 64064   2210     2       음식     의지    나 이제 라면 절대 안 먹을 거!!   라면
# 64065   2210     2       음식     의지  와타시 이제 라면 절대 안 먹을 거!!   라면
# 64066   2210     2       음식     의지  와따시 이제 라면 절대 안 먹을 거!!   라면
# 64067   2210     3       음식     의지        라면 쳐다보지도 않겠다,,,   라면
# 64068   2210     4       음식     의지            라면이랑 연 끊는다.   라면
# 64069   2210     5       음식     의지          라면 입에도 안 댈 거임   라면
#
#       arg_op2 user_dic  label
# 0                          98
# 1                  와타시     98
# 2                  와따시     98
# 64060                      98
# 64061                      98
# 64062              와타시     98
# 64063              와따시     98
# 64064                      98
# 64065              와타시     98
# 64066              와따시     98
# 64067                      98
# 64068                      98
# 64069                      98

# %% [markdown]
# Save

# %%
# 참고용
# fm.save(cfg.userdict_check, df_temp)

# pickle
fm.save(cfg.userdict_aug, df_temp)
# Out:
# Saved 121407 records

# %% [markdown]
# Count

# %%
df_temp = fm.load(cfg.userdict_check)
# Out:
# extension : .xlsx
# Loaded 72015 records from drive/MyDrive/MemeProject/data/report/userdict_check.xlsx

# %%
df_temp = df_temp[['material', 'speech', 'label', 'u']]

# %%
df_temp.drop_duplicates(inplace=True)
df_temp.reset_index(drop=True, inplace=True)

# %%
check = {f"{i[1]['material']}, {i[1]['speech']}, {i[1]['label']}": 0 for i in df_temp.iterrows()}

# %%
for i in df_temp.iterrows():
  check[f"{i[1]['material']}, {i[1]['speech']}, {i[1]['label']}"] += 1

# %%
temp = sorted(check.items(), key=lambda x: x[1], reverse=True)

# %%
print(temp)
# Out:
# [('기념일, 계획, 18', 2319), ('학교생활, 자랑, 147', 1764), ('반려동물, 자랑, 57', 1699), ('자기개발, 의지, 110', 1598), ('미용, 자랑, 51', 1581), ('반려동물, 진술, 58', 1525), ('자기개발, 계획, 108', 1519), ('학교생활, 소망, 145', 1517), ('인간관계, 진술, 106', 1441), ('교통, 진술, 16', 1424), ('기후, 진술, 28', 1334), ('미용, 소망, 49', 1311), ('여행, 계획, 66', 1170), ('자기개발, 자랑, 111', 1129), ('연애, 소망, 73', 1114), ('교통, 소망, 13', 1052), ('미디어콘텐츠, 의지, 44', 1025), ('음료, 진술, 94', 1019), ('직장생활, 의지, 128', 1008), ('패션, 소망, 139', 997), ('쇼핑, 칭찬, 65', 976), ('연애, 의지, 74', 970), ('미용, 칭찬, 53', 970), ('학교생활, 의지, 146', 964), ('쇼핑, 진술, 64', 962), ('쇼핑, 자랑, 63', 954), ('반려동물, 계획, 54', 945), ('연애, 칭찬, 77', 934), ('음료, 자랑, 93', 926), ('인간관계, 계획, 102', 923), ('음식, 계획, 96', 916), ('학교생활, 계획, 144', 908), ('기후, 자랑, 27', 902), ('문화예술, 칭찬, 41', 891), ('패션, 의지, 140', 888), ('돈, 소망, 31', 879), ('인간관계, 칭찬, 107', 873), ('음식, 진술, 100', 869), ('돈, 자랑, 33', 862), ('여행, 칭찬, 71', 858), ('전자기기, 칭찬, 119', 855), ('문화예술, 계획, 36', 855), ('미디어콘텐츠, 계획, 42', 848), ('취미, 의지, 134', 842), ('패션, 자랑, 141', 828), ('미디어콘텐츠, 진술, 46', 825), ('가정생활, 계획, 0', 819), ('운동, 계획, 78', 812), ('패션, 진술, 142', 796), ('학교생활, 진술, 148', 790), ('주거, 소망, 121', 789), ('미디어콘텐츠, 자랑, 45', 772), ('취미, 진술, 136', 771), ('경사, 계획, 6', 770), ('운동, 의지, 80', 768), ('음료, 의지, 92', 765), ('경사, 자랑, 9', 763), ('운동, 자랑, 81', 763), ('돈, 진술, 34', 756), ('문화예술, 의지, 38', 749), ('음료, 칭찬, 95', 736), ('음식, 칭찬, 101', 734), ('전자기기, 자랑, 117', 728), ('패션, 칭찬, 143', 725), ('미디어콘텐츠, 칭찬, 47', 720), ('유명인, 소망, 85', 719), ('연애, 계획, 72', 719), ('밈봇, 명령, 151', 718), ('밈봇, 실망, 152', 712), ('쇼핑, 의지, 62', 705), ('음식, 의지, 98', 704), ('밈봇, 혐오, 153', 704), ('밈봇, 만족, 150', 700), ('경사, 의지, 8', 691), ('가정생활, 의지, 2', 691), ('미용, 의지, 50', 678), ('여행, 의지, 68', 672), ('여행, 소망, 67', 671), ('교통, 칭찬, 17', 663), ('돈, 의지, 32', 659), ('미용, 계획, 48', 651), ('전자기기, 계획, 114', 649), ('전자기기, 소망, 115', 644), ('유명인, 칭찬, 89', 642), ('쇼핑, 계획, 60', 630), ('문화예술, 자랑, 39', 629), ('가정생활, 진술, 4', 629), ('기념일, 의지, 20', 626), ('연애, 자랑, 75', 620), ('주거, 계획, 120', 619), ('자기개발, 소망, 109', 616), ('음식, 자랑, 99', 616), ('미용, 진술, 52', 614), ('주거, 칭찬, 125', 607), ('기념일, 소망, 19', 599), ('운동, 진술, 82', 596), ('쇼핑, 소망, 61', 589), ('기후, 소망, 25', 582), ('패션, 계획, 138', 573), ('교통, 자랑, 15', 571), ('가정생활, 자랑, 3', 567), ('음료, 소망, 91', 561), ('반려동물, 칭찬, 59', 561), ('기후, 의지, 26', 558), ('전자기기, 진술, 118', 546), ('취미, 계획, 132', 544), ('미디어콘텐츠, 소망, 43', 542), ('인간관계, 의지, 104', 542), ('가정생활, 소망, 1', 535), ('경사, 소망, 7', 530), ('음식, 소망, 97', 525), ('경사, 칭찬, 11', 522), ('문화예술, 소망, 37', 519), ('직장생활, 소망, 127', 517), ('취미, 자랑, 135', 516), ('여행, 자랑, 69', 506), ('기념일, 자랑, 21', 504), ('주거, 자랑, 123', 499), ('주거, 진술, 124', 484), ('문화예술, 진술, 40', 471), ('교통, 계획, 12', 470), ('인간관계, 소망, 103', 467), ('직장생활, 계획, 126', 464), ('경사, 진술, 10', 460), ('기념일, 진술, 22', 459), ('유명인, 진술, 88', 434), ('여행, 진술, 70', 432), ('취미, 칭찬, 137', 376), ('전자기기, 의지, 116', 374), ('학교생활, 칭찬, 149', 368), ('직장생활, 자랑, 129', 357), ('연애, 진술, 76', 354), ('유명인, 자랑, 87', 342), ('취미, 소망, 133', 341), ('기후, 칭찬, 29', 334), ('교통, 의지, 14', 333), ('기후, 계획, 24', 330), ('주거, 의지, 122', 317), ('자기개발, 진술, 112', 309), ('인간관계, 자랑, 105', 298), ('직장생활, 진술, 130', 263), ('반려동물, 소망, 55', 251), ('유명인, 계획, 84', 247), ('음료, 계획, 90', 228), ('기념일, 칭찬, 23', 214), ('직장생활, 칭찬, 131', 202), ('가정생활, 칭찬, 5', 200), ('운동, 소망, 79', 168), ('반려동물, 의지, 56', 137), ('유명인, 의지, 86', 133), ('운동, 칭찬, 83', 90), ('자기개발, 칭찬, 113', 48), ('돈, 칭찬, 35', 26), ('돈, 계획, 30', 6)]

# %%
temp_check = pd.DataFrame(temp, columns=['label', '건수'])

# %%
temp_check['대화소재'] = temp_check.label.apply(lambda x: x.split(',')[0])
temp_check['화행'] = temp_check.label.apply(lambda x: x.split(',')[1])
temp_check['레이블'] = temp_check.label.apply(lambda x: x.split(',')[2])

# %%
temp_check = temp_check[['대화소재', '화행', '레이블', '건수']]

# %%
fm.save('drive/MyDrive/MemeProject/data/report/count.xlsx', temp_check)
# Out:
# Saved 154 records

# %% [markdown]
# #### 가변어 - 대기

# %% [markdown]
# 동사, 형용사, 조사, 어미

# %% [markdown]
# Okt<br>
# 가변어는 어간을 추출하여 비교

# %%
from jamo import h2j, j2hcj

# %%
variable = ['VV', 'VA', 'JKS', 'EF']

# %%
user_dict_variable = [i[1] for i in user_dict_3.iterrows() if i[1]['mecab_pos'] in variable]

# %%
user_dict = pd.DataFrame(user_dict_variable)

# %%
user_dict.mecab_pos.value_counts()
# Out:
# VV    1398
# VA     308
# EF      46
# Name: mecab_pos, dtype: int64

# %%
user_dict.head()
# Out:
# 5   lemma formal pos sentiment  age           example antonym okt_pos  \
# 0     가지다    가지다  VV       Neu  NaN         그거 내가 가진다     버리다    Verb
# 1      갖다    가지다  VV       Neu  NaN      이 지갑은 내가 갖는다     버리다    Verb
# 2  내 거 하다    가지다  VV       Hap   MZ        걔 내 거 할 거야     NaN    Verb
# 3    소유하다    가지다  VV       Hap  NaN     그 신발은 이미 소유했어     버리다    Verb
# 4    보유하다    가지다  VV       Hap  NaN  나도 그 아이템 보유하고 싶어     버리다    Verb
#
# 5 mecab_pos
# 0        VV
# 1        VV
# 2        VV
# 3        VV
# 4        VV

# %% [markdown]
# Okt

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
df_temp.head()
# Out:
#    g_num  u_num material speech                  u   arg arg_op1 arg_op2  \
# 0      1      1     학교생활     자랑    나 중간고사 반에서 1등했어  중간고사
# 1      1      1     학교생활     자랑  와따시 중간고사 반에서 1등했어  중간고사
# 2      1      1     학교생활     자랑  와타시 중간고사 반에서 1등했어  중간고사
# 3      1      1     학교생활     자랑    나 중간시험 반에서 1등했어  중간시험
# 4      1      1     학교생활     자랑  와따시 중간시험 반에서 1등했어  중간시험
#
#   user_dic  label
# 0     None    146
# 1      와따시    146
# 2      와타시    146
# 3     None    146
# 4      와따시    146

# %% [markdown]
# Kiwi add word

# %%
okt.morphs('나 해냈다!', stem=True)
# Out:
# ['나', '해내다', '!']

# %%
udict_variable = [[f"{i[0]}, {i[1]}" for i in kiwi.tokenize(''.join(okt.morphs(str(ii[1]['lemma']).replace(' ', ''), stem=True)))] for ii in user_dict.iterrows()]

# %%
for u in udict_variable:
  trie.insert(', '.join(u))

# %% [markdown]
# ##### Tokenizer

# %%
df_temp.head()
# Out:
#    g_num  u_num material speech                  u   arg arg_op1 arg_op2  \
# 0      1      1     학교생활     자랑    나 중간고사 반에서 1등했어  중간고사
# 1      1      1     학교생활     자랑  와따시 중간고사 반에서 1등했어  중간고사
# 2      1      1     학교생활     자랑  와타시 중간고사 반에서 1등했어  중간고사
# 3      1      1     학교생활     자랑    나 중간시험 반에서 1등했어  중간시험
# 4      1      1     학교생활     자랑  와따시 중간시험 반에서 1등했어  중간시험
#
#   user_dic  label
# 0     None    146
# 1      와따시    146
# 2      와타시    146
# 3     None    146
# 4      와따시    146

# %%
for i in df_temp.iterrows():
  print(f"원본 : {i[1]['u']}")
  # VV, VA만?
  # print(f"수정 : {okt.pos(i[1]['u'].replace(' ', ''), stem=True)}")
  #print(i[1]['u'].replace(' ', ''))
  # print(okt.morphs(str(i[1]['lemma']).replace(' ', ''), stem=True))
# Out:
#   File "<ipython-input-74-ca9a19debb01>", line 3
# pos(i[1]['u'].replace(' ', ''), stem=True)}")
#        ^
# SyntaxError: f-string: invalid syntax

# %%
""

# %%
temp = trie.search(i)

# %%
text = "이 지갑은 내가 갖는다"

# %%
okt.morphs(text, stem=True)
# Out:
# ['이', '지갑', '은', '내', '가', '갖다']

# %%
okt.morphs('갖다', stem=True)
# Out:
# ['갖다']

# %%
# sample_text_list = list(text)
# last_word = sample_text_list[-1]
# last_word_jamo_list = list(j2hcj(h2j(last_word)))
# last_jamo = last_word_jamo_list[-1]

# jongsung_TF = "T"

# if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ', 'ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
#     jongsung_TF = "F"

# %%
# text_split = [list(j2hcj(h2j(t))) for t in text.split()]

# %% [markdown]
# # .

# %% [markdown]
# ### Mecab

# %% [markdown]
# test<br>
# 사용자 사전 등록이 안되는데 원인 파악 안 됨.

# %%
from konlpy.tag import Mecab

m = Mecab()

# %%
print(f"겟또하다 Verb : {m.pos('핸드폰을 겟또하다.')}")
print(f"득템하다 Verb : {m.pos('동전을 득템하다.')}")
print(f"가상화폐 Noun : {m.pos('가상화폐를 살거야')}")
print(f"틀니딱딱 Noun : {m.pos('틀니딱딱 거리지마~')}")
print(f"젤루 Adverb : {m.pos('엄마가 젤루 좋아')}")
print(f"틀림없이 Adverb : {m.pos('이번엔 틀림없이 합격할 거야')}")
print(f"쏘 러블리하다 Adjective : {m.pos('쏘 러블리하다')}")
# Out:
# 겟또하다 Verb : [('핸드폰', 'NNG'), ('을', 'JKO'), ('겟', 'NNP'), ('또', 'MAG'), ('하', 'VV'), ('다', 'EF'), ('.', 'SF')]
# 득템하다 Verb : [('동전', 'NNG'), ('을', 'JKO'), ('득템', 'NNG'), ('하', 'XSV'), ('다', 'EF'), ('.', 'SF')]
# 가상화폐 Noun : [('가상', 'NNG'), ('화폐', 'NNG'), ('를', 'JKO'), ('살', 'VV+ETM'), ('거', 'NNB'), ('야', 'VCP+EF')]
# 틀니딱딱 Noun : [('틀니', 'NNG'), ('딱딱', 'MAG'), ('거리', 'NNG'), ('지마', 'NNG'), ('~', 'SY')]
# 젤루 Adverb : [('엄마', 'NNG'), ('가', 'JKS'), ('젤', 'NNG'), ('루', 'JKB'), ('좋', 'VA'), ('아', 'EC')]
# 틀림없이 Adverb : [('이번', 'NNG'), ('엔', 'JKB+JX'), ('틀림없이', 'MAG'), ('합격', 'NNG'), ('할', 'XSV+ETM'), ('거', 'NNB'), ('야', 'VCP+EF')]
# 쏘 러블리하다 Adjective : [('쏘', 'NNP'), ('러블리', 'NNP'), ('하', 'VV'), ('다', 'EC')]

# %% [markdown]
# Add Dict

# %%
# !pip3 install jamo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jamo
#   Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Installing collected packages: jamo
# Successfully installed jamo-0.4.1

# %%
from jamo import h2j, j2hcj

def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF

# %%
paths = {
    'NNG.csv':'NNG',
    'NNP.csv':'NNP',
    'NR.csv':'NR',
    'NP.csv':'NP',
    'VV.csv':'VV',
    'VA.csv':'VA',
    'MM.csv':'MM',
    'MAG.csv':'MAG',
    'MAJ.csv':'MAJ',
    'IC.csv':'IC',
    'J.csv':'JO',
}

# %%
for p in paths:
  with open(f'/tmp/mecab-ko-dic-2.1.1-20180720/{p}', "r", encoding='utf-8') as f:
    user_dict = f.readlines()

  for i in user_dict_3[user_dict_3.mecab_pos == paths[p]].iterrows():
    jongsung_TF = get_jongsung_TF(str(i[1]['lemma']))
    line = '{},*,*,*,{},*,{},{},*,*,*,*,*\n'.format(i[1]['lemma'], paths[p], jongsung_TF, i[1]['lemma'])
    user_dict.append(line)
  
  with open(f'/tmp/mecab-ko-dic-2.1.1-20180720/{p}', 'w', encoding='utf-8') as f:
    for line in user_dict:
      f.write(line)

  user_dict = []

# %%
# !bash /tmp/mecab-ko-dic-2.1.1-20180720/tools/add-userdic.sh
# !make /tmp/mecab-ko-dic-2.1.1-20180720/install
# Out:
# generating userdic...
# nnp.csv
# /tmp/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /tmp/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/nnp.csv ...
# done!
# person.csv
# /tmp/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /tmp/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/person.csv ...
# done!
# place.csv
# /tmp/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /tmp/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/place.csv ...
# done!
# test -z "model.bin matrix.bin char.bin sys.dic unk.dic" || rm -f model.bin matrix.bin char.bin sys.dic unk.dic
# /usr/local/libexec/mecab/mecab-dict-index -d . -o . -f UTF-8 -t UTF-8
# reading ./unk.def ... 13
# emitting double-array: 100% |###########################################|
# reading ./NNP.csv ... 2453
# reading ./Group.csv ... 3176
# reading ./Inflect.csv ... 44820
# reading ./VV.csv ... 8729
# reading ./NR.csv ... 482
# reading ./user-place.csv ... 2
# reading ./XPN.csv ... 83
# reading ./VX.csv ... 125
# reading ./NNBC.csv ... 677
# reading ./Place.csv ... 30303
# reading ./Place-address.csv ... 19301
# reading ./XSN.csv ... 124
# reading ./VCN.csv ... 7
# reading ./NorthKorea.csv ... 3
# reading ./EF.csv ... 1820
# reading ./NP.csv ... 359
# reading ./J.csv ... 416
# reading ./CoinedWord.csv ... 148
# reading ./user-nnp.csv ... 2
# reading ./Symbol.csv ... 16
# reading ./MAG.csv ... 14396
# reading ./NNB.csv ... 140
# reading ./MM.csv ... 455
# reading ./Preanalysis.csv ... 5
# reading ./Hanja.csv ... 125750
# reading ./XSV.csv ... 23
# reading ./NNG.csv ... 209758
# reading ./MAJ.csv ... 240
# reading ./XR.csv ... 3637
# reading ./ETN.csv ... 14
# reading ./Person-actor.csv ... 99230
# reading ./VCP.csv ... 9
# reading ./EP.csv ... 51
# reading ./user-person.csv ... 1
# reading ./Foreign.csv ... 11690
# reading ./Place-station.csv ... 1145
# reading ./Wikipedia.csv ... 36762
# reading ./XSA.csv ... 19
# reading ./EC.csv ... 2547
# reading ./Person.csv ... 196459
# reading ./VA.csv ... 2668
# reading ./ETM.csv ... 133
# reading ./IC.csv ... 1379
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3822x2693
# emitting matrix      : 100% |###########################################|
#
# done!
# echo To enable dictionary, rewrite /usr/local/etc/mecabrc as \"dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic\"
# To enable dictionary, rewrite /usr/local/etc/mecabrc as "dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic"
# make: *** No rule to make target '/tmp/mecab-ko-dic-2.1.1-20180720/install'.  Stop.

# %% [markdown]
# check

# %%
with open("/tmp/mecab-ko-dic-2.1.1-20180720/VV.csv", 'r', encoding='utf-8') as f:
  file_new = f.readlines()
file_new[-20:]
# Out:
# ['속 썩이다,*,*,*,VV,*,F,속 썩이다,*,*,*,*,*\n',
#  '시전하다,*,*,*,VV,*,F,시전하다,*,*,*,*,*\n',
#  '애프터 신청하다,*,*,*,VV,*,F,애프터 신청하다,*,*,*,*,*\n',
#  '궁예질하다,*,*,*,VV,*,F,궁예질하다,*,*,*,*,*\n',
#  '갑분싸되다,*,*,*,VV,*,F,갑분싸되다,*,*,*,*,*\n',
#  '급 어색해지다,*,*,*,VV,*,F,급 어색해지다,*,*,*,*,*\n',
#  '갑자기 분위기 싸해지다,*,*,*,VV,*,F,갑자기 분위기 싸해지다,*,*,*,*,*\n',
#  '고스팅하다,*,*,*,VV,*,F,고스팅하다,*,*,*,*,*\n',
#  '잠수 타다,*,*,*,VV,*,F,잠수 타다,*,*,*,*,*\n',
#  '꾸꾸꾸,*,*,*,VV,*,F,꾸꾸꾸,*,*,*,*,*\n',
#  '꾸미고 꾸미고 꾸몄다,*,*,*,VV,*,F,꾸미고 꾸미고 꾸몄다,*,*,*,*,*\n',
#  '발컨하다,*,*,*,VV,*,F,발컨하다,*,*,*,*,*\n',
#  '발로 컨트롤하다,*,*,*,VV,*,F,발로 컨트롤하다,*,*,*,*,*\n',
#  '오저치고,*,*,*,VV,*,F,오저치고,*,*,*,*,*\n',
#  '오늘 저녁에 치킨 고,*,*,*,VV,*,F,오늘 저녁에 치킨 고,*,*,*,*,*\n',
#  '이생망,*,*,*,VV,*,T,이생망,*,*,*,*,*\n',
#  '이번 생은 망했다,*,*,*,VV,*,F,이번 생은 망했다,*,*,*,*,*\n',
#  '혼틈,*,*,*,VV,*,T,혼틈,*,*,*,*,*\n',
#  '혼란한 틈 타,*,*,*,VV,*,F,혼란한 틈 타,*,*,*,*,*\n',
#  '일며들다,*,*,*,VV,*,F,일며들다,*,*,*,*,*\n']

# %%
from konlpy.tag import Mecab

m = Mecab(dicpath='/tmp/mecab-ko-dic-2.1.1-20180720')
# m = Mecab()

# %%
print(f"겟또하다 Verb : {m.pos('핸드폰을 겟또하다. 쿠쿠루삥뽕')}")
print(f"득템하다 Verb : {m.pos('동전을 득템하다.')}")
print(f"가상화폐 Noun : {m.pos('가상화폐를 살거야')}")
print(f"틀니딱딱 Noun : {m.pos('틀니딱딱 거리지마~')}")
print(f"젤루 Adverb : {m.pos('엄마가 젤루 좋아')}")
print(f"틀림없이 Adverb : {m.pos('이번엔 틀림없이 합격할 거야')}")
print(f"쏘 러블리하다 Adjective : {m.pos('쏘 러블리하다')}")
# Out:
# 겟또하다 Verb : [('핸드폰', 'NNG'), ('을', 'JKO'), ('겟또', 'NNG'), ('하', 'VV'), ('다', 'EF'), ('.', 'SF'), ('쿠쿠루삥뽕', 'IC')]
# 득템하다 Verb : [('동전', 'NNG'), ('을', 'JKO'), ('득템', 'NNG'), ('하', 'VV'), ('다', 'EF'), ('.', 'SF')]
# 가상화폐 Noun : [('가상화폐', 'NNG'), ('를', 'JKO'), ('살', 'VV+ETM'), ('거', 'NNB'), ('야', 'VCP+EF')]
# 틀니딱딱 Noun : [('틀니딱딱', 'NNG'), ('거리', 'NNG'), ('지마', 'NNG'), ('~', 'SY')]
# 젤루 Adverb : [('엄마', 'NNG'), ('가', 'JKS'), ('젤루', 'MAG'), ('좋', 'VA'), ('아', 'EC')]
# 틀림없이 Adverb : [('이번', 'NNG'), ('엔', 'JKB+JX'), ('틀림없이', 'MAG'), ('합', 'NNG'), ('격할', 'VV+ETM'), ('거', 'NNB'), ('야', 'VCP+EF')]
# 쏘 러블리하다 Adjective : [('쏘', 'MAG'), ('러블리', 'NNG'), ('하', 'VV'), ('다', 'EC')]

# %% [markdown]
# ### Customized KoNLPy

# %% [markdown]
# test
# 사용자 사전 등록이 안되는데 원인 파악 안 됨.

# %%
# !pip install customized_konlpy

# %%
from ckonlpy.tag import Twitter

# %%
twitter = Twitter()

# %%
tags = ['Noun', 'Verb', 'Adjective', 'Adverb', 'Exclamation', 'Eomi', 'Determiner']

# %%
for t in tags:
  for i in user_dict_3[user_dict_3.okt_pos==t].iterrows():
    twitter.add_dictionary(str(i[1]['lemma']), t)

# %% [markdown]
# check

# %%
from ckonlpy.tag import Twitter

# %%
twitter = Twitter()

# %%
print(f"겟또하다 Verb : {twitter.pos('핸드폰을 겟또하다.')}")
print(f"득템하다 Verb : {twitter.pos('동전을 득템하다.')}")
print(f"가상화폐 Noun : {twitter.pos('가상화폐를 살거야')}")
print(f"틀니딱딱 Noun : {twitter.pos('틀니딱딱 거리지마~')}")
print(f"젤루 Adverb : {twitter.pos('엄마가 젤루 좋아')}")
print(f"틀림없이 Adverb : {twitter.pos('이번엔 틀림없이 합격할 거야')}")
print(f"쏘 러블리하다 Adjective : {twitter.pos('쏘 러블리하다')}")

# %% [markdown]
# # Install

# %%
# !pip3 install pshmodule

# %%
# !pip3 install pickle5

# %%
# !pip3 install pandas==1.5.0

# %%
# !pip3 install swifter

# %%
# !pip install transformers
# !wget https://raw.githubusercontent.com/smilegate-ai/korean_smile_style_dataset/main/smilestyle_dataset.tsv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Load

# %%
import sys
sys.path.append('/content/drive/MyDrive/MemeProject/src/pytorch/preprocessing')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/MemeProject/src/pytorch/preprocessing']

# %%
from tqdm import tqdm
import config as cfg
import pandas as pd
import numpy as np
import swifter
from tqdm import tqdm
from pshmodule.utils import filemanager as fm

# %%
df = fm.load(cfg.origin_class153_ref)
# Out:
# extension : .pickle
# Loaded 181704 records from drive/MyDrive/MemeProject/data/augmentation/origin_class153_ref.pickle

# %%
df.head()
# Out:
#   num g_num u_num material speech                u  \
# 0   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
# 1   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
# 2   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
# 3   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
# 4   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
#
#                                           meme  arg1 arg_op1 arg_op2 label
# 0           그렇다면 통 크게 함 쏴야지! 근데 이제 내 것도 곁들인...  중간고사                   146
# 1     그렇다면 통 크게 함 쏴야지! 근데 이제 내 몫을 제일 많이 곁들인...  중간고사                   146
# 2         그렇다면 통 크게 함 쏴야지! 근데 이제 대춘이 몫도 곁들인...  중간고사                   146
# 3  그렇다면 통 크게 함 쏴야지! 근데 이제 배보다 배꼽이 더 큰 걸 곁들인...  중간고사                   146
# 4           그렇다면 통 크게 함 쏴야지! 근데 이제 과소비를 곁들인...  중간고사                   146

# %% [markdown]
# #####  origin check

# %%
df = df[['material', 'speech', 'u', 'label']]

# %%
df.drop_duplicates(inplace=True)
# Out:
# <ipython-input-6-16cdb8520be8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (9141, 4)

# %%
check = {f"{i[1]['material']}, {i[1]['speech']}, {i[1]['label']}": 0 for i in df.iterrows()}

# %%
for i in df.iterrows():
  check[f"{i[1]['material']}, {i[1]['speech']}, {i[1]['label']}"] += 1

# %%
temp = sorted(check.items(), key=lambda x: x[1], reverse=True)

# %%
print(temp)
# Out:
# [('밈봇, 명령, 150', 491), ('밈봇, 혐오, 152', 483), ('밈봇, 실망, 151', 480), ('밈봇, 만족, 149', 479), ('유명인, 칭찬, 89', 144), ('기후, 진술, 28', 144), ('패션, 칭찬, 142', 126), ('기념일, 계획, 18', 114), ('경사, 자랑, 9', 108), ('자기개발, 계획, 107', 102), ('전자기기, 칭찬, 118', 102), ('자기개발, 의지, 109', 102), ('음식, 칭찬, 101', 96), ('주거, 소망, 120', 96), ('인간관계, 칭찬, 106', 96), ('돈, 자랑, 33', 96), ('운동, 계획, 78', 95), ('문화예술, 칭찬, 41', 90), ('연애, 자랑, 75', 90), ('취미, 의지, 133', 90), ('음료, 의지, 92', 90), ('미용, 의지, 50', 90), ('직장생활, 의지, 127', 90), ('가정생활, 계획, 0', 90), ('미디어콘텐츠, 칭찬, 47', 84), ('교통, 소망, 13', 78), ('운동, 의지, 80', 78), ('반려동물, 칭찬, 59', 78), ('연애, 소망, 73', 78), ('돈, 소망, 31', 78), ('여행, 소망, 67', 77), ('반려동물, 자랑, 57', 77), ('음식, 진술, 100', 72), ('여행, 계획, 66', 72), ('학교생활, 진술, 147', 72), ('미디어콘텐츠, 진술, 46', 72), ('학교생활, 계획, 143', 72), ('직장생활, 소망, 126', 72), ('인간관계, 자랑, 104', 72), ('돈, 의지, 32', 66), ('쇼핑, 진술, 64', 66), ('교통, 계획, 12', 66), ('음식, 계획, 96', 65), ('학교생활, 자랑, 146', 60), ('학교생활, 소망, 144', 60), ('가정생활, 자랑, 3', 60), ('인간관계, 진술, 105', 60), ('음료, 진술, 94', 54), ('문화예술, 계획, 36', 54), ('미용, 계획, 48', 54), ('음식, 소망, 97', 54), ('쇼핑, 자랑, 63', 54), ('전자기기, 자랑, 116', 54), ('미디어콘텐츠, 계획, 42', 54), ('쇼핑, 소망, 61', 54), ('경사, 진술, 10', 54), ('유명인, 소망, 85', 54), ('취미, 진술, 135', 54), ('음료, 칭찬, 95', 54), ('취미, 자랑, 134', 53), ('직장생활, 자랑, 128', 48), ('반려동물, 진술, 58', 48), ('전자기기, 진술, 117', 48), ('미용, 칭찬, 53', 48), ('주거, 진술, 123', 48), ('취미, 계획, 131', 48), ('학교생활, 의지, 145', 48), ('미용, 자랑, 51', 48), ('운동, 자랑, 81', 48), ('미용, 소망, 49', 42), ('기념일, 소망, 19', 42), ('교통, 진술, 16', 42), ('가정생활, 진술, 4', 42), ('연애, 의지, 74', 42), ('주거, 계획, 119', 42), ('음료, 소망, 91', 42), ('쇼핑, 의지, 62', 42), ('음식, 의지, 98', 42), ('반려동물, 소망, 55', 42), ('교통, 칭찬, 17', 42), ('패션, 소망, 138', 42), ('돈, 진술, 34', 42), ('기후, 칭찬, 29', 42), ('쇼핑, 계획, 60', 42), ('기념일, 자랑, 21', 42), ('문화예술, 자랑, 39', 37), ('인간관계, 의지, 103', 36), ('유명인, 자랑, 87', 36), ('패션, 계획, 137', 36), ('여행, 진술, 70', 36), ('기후, 소망, 25', 36), ('교통, 의지, 14', 36), ('미디어콘텐츠, 소망, 43', 36), ('경사, 계획, 6', 36), ('운동, 진술, 82', 36), ('전자기기, 소망, 114', 36), ('음료, 계획, 90', 36), ('기후, 의지, 26', 36), ('가정생활, 칭찬, 5', 36), ('여행, 의지, 68', 36), ('문화예술, 진술, 40', 36), ('문화예술, 소망, 37', 36), ('주거, 자랑, 122', 36), ('연애, 계획, 72', 36), ('경사, 의지, 8', 36), ('기념일, 의지, 20', 36), ('주거, 칭찬, 124', 30), ('직장생활, 계획, 125', 30), ('교통, 자랑, 15', 30), ('패션, 의지, 139', 30), ('취미, 칭찬, 136', 30), ('가정생활, 소망, 1', 30), ('인간관계, 소망, 102', 30), ('직장생활, 진술, 129', 30), ('미용, 진술, 52', 30), ('연애, 진술, 76', 30), ('패션, 자랑, 140', 30), ('가정생활, 의지, 2', 30), ('문화예술, 의지, 38', 30), ('여행, 칭찬, 71', 30), ('패션, 진술, 141', 24), ('기념일, 진술, 22', 24), ('기후, 자랑, 27', 24), ('자기개발, 소망, 108', 24), ('주거, 의지, 121', 24), ('자기개발, 자랑, 110', 24), ('경사, 소망, 7', 24), ('전자기기, 의지, 115', 24), ('기념일, 칭찬, 23', 24), ('음식, 자랑, 99', 24), ('미디어콘텐츠, 의지, 44', 24), ('유명인, 진술, 88', 18), ('반려동물, 계획, 54', 18), ('미디어콘텐츠, 자랑, 45', 18), ('전자기기, 계획, 113', 18), ('자기개발, 진술, 111', 18), ('운동, 소망, 79', 18), ('음료, 자랑, 93', 18), ('여행, 자랑, 69', 18), ('경사, 칭찬, 11', 12), ('유명인, 계획, 84', 12), ('학교생활, 칭찬, 148', 12), ('쇼핑, 칭찬, 65', 12), ('직장생활, 칭찬, 130', 12), ('취미, 소망, 132', 12), ('반려동물, 의지, 56', 12), ('유명인, 의지, 86', 12), ('기후, 계획, 24', 6), ('연애, 칭찬, 77', 6), ('돈, 계획, 30', 6), ('자기개발, 칭찬, 112', 6), ('돈, 칭찬, 35', 6), ('운동, 칭찬, 83', 6)]

# %%
temp_check = pd.DataFrame(temp, columns=['label', '건수'])

# %%
temp_check['대화소재'] = temp_check.label.apply(lambda x: x.split(',')[0])
temp_check['화행'] = temp_check.label.apply(lambda x: x.split(',')[1])
temp_check['레이블'] = temp_check.label.apply(lambda x: x.split(',')[2])

# %%
temp_check = temp_check[['대화소재', '화행', '레이블', '건수']]

# %%
fm.save('drive/MyDrive/MemeProject/data/report/origin_count.xlsx', temp_check)
# Out:
# file exists
# exceptions must derive from BaseException

# %% [markdown]
# report

# %%
df_table = fm.load(cfg.report_label)
# Out:
# extension : .xlsx
# Loaded 153 records from drive/MyDrive/MemeProject/data/report/table.xlsx

# %%
df.head()
# Out:
#     material speech                       u label
# 0       학교생활     자랑         나 중간고사 반에서 1등했어   146
# 36      학교생활     자랑  중간고사 점수 내가 반에서 제일 잘 받음   146
# 72      학교생활     자랑       나 반에서 중간 성적 제일 좋아   146
# 108     학교생활     자랑    우리 반에서 내가 시험 제일 잘 봤다   146
# 144     학교생활     자랑            중간고사 반 1등 먹음   146

# %% [markdown]
# # Augmentation

# %% [markdown]
# replace에서 arg1(너, 대춘이),  너 너무 -> 대춘이 대춘이무 같은 상황을 방지하기 위해 앞 뒤로 공백 처리

# %%
df['arg1_strip'] = [i[1]['arg1'].strip() for i in df.iterrows()]
df['arg1_space'] = " " + df.arg1_strip.values + " "

# %%
df.head()
# Out:
#   num g_num u_num material speech                u  \
# 0   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
# 1   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
# 2   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
# 3   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
# 4   1     1     1     학교생활     자랑  나 중간고사 반에서 1등했어
#
#                                           meme  arg1 arg_op1 arg_op2 label  \
# 0           그렇다면 통 크게 함 쏴야지! 근데 이제 내 것도 곁들인...  중간고사                   146
# 1     그렇다면 통 크게 함 쏴야지! 근데 이제 내 몫을 제일 많이 곁들인...  중간고사                   146
# 2         그렇다면 통 크게 함 쏴야지! 근데 이제 대춘이 몫도 곁들인...  중간고사                   146
# 3  그렇다면 통 크게 함 쏴야지! 근데 이제 배보다 배꼽이 더 큰 걸 곁들인...  중간고사                   146
# 4           그렇다면 통 크게 함 쏴야지! 근데 이제 과소비를 곁들인...  중간고사                   146
#
#   arg1_strip arg1_space
# 0       중간고사      중간고사
# 1       중간고사      중간고사
# 2       중간고사      중간고사
# 3       중간고사      중간고사
# 4       중간고사      중간고사

# %%
df = df[['g_num', 'u_num', 'material', 'speech', 'u', 'arg1_space', 'arg_op1', 'arg_op2', 'label']]

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (9150, 9)

# %%
df.arg1_space.value_counts()
# Out:
# (arg1_space,)
#                  2112
#  너                 78
#  나                 47
#  커피                45
#  날씨                39
#                  ...
#  본인 험담              1
#  본인 흉보는 거           1
#  봄, 햇살              1
#  봄볕                 1
#  힙한 패션 아이템          1
# Length: 3202, dtype: int64

# %%
df.head()
# Out:
#   g_num u_num material speech                       u arg1_space arg_op1  \
# 0     1     1     학교생활     자랑         나 중간고사 반에서 1등했어      중간고사
# 1     1     2     학교생활     자랑  중간고사 점수 내가 반에서 제일 잘 받음      중간고사
# 2     1     3     학교생활     자랑       나 반에서 중간 성적 제일 좋아        중간
# 3     1     4     학교생활     자랑    우리 반에서 내가 시험 제일 잘 봤다        시험
# 4     1     5     학교생활     자랑            중간고사 반 1등 먹음      중간고사
#
#   arg_op2 label
# 0           146
# 1           146
# 2           146
# 3           146
# 4           146

# %% [markdown]
# 대화소재 밈봇 제거

# %%
df_memebot = df[(df.label.values == 149) | (df.label.values == 150) | (df.label.values == 151) | (df.label.values == 152)]
df_remain = df[(df.label.values != 149) & (df.label.values != 150) & (df.label.values != 151) & (df.label.values != 152)]

# %%
print(df_memebot.label.value_counts().shape)
print(df_remain.label.value_counts().shape)
# Out:
# (4,)
# (149,)

# %%
df_memebot.shape
# Out:
# (1938, 9)

# %%
df_remain[df_remain.label.values==83]
# Out:
#      g_num u_num material speech                      u arg1_space arg_op1  \
# 9090  1516     1       운동     칭찬    이다빈 선수 올림픽 은메달도 간지나   올림픽 은메달
# 9091  1516     2       운동     칭찬         다빈선수 은메달도 멋지잖아       은메달
# 9092  1516     3       운동     칭찬    이다빈 선수 올림픽 2등도 본새난다    올림픽 2등
# 9093  1516     4       운동     칭찬   그 선수 2등 은메달도 대단하지 않냐    2등 은메달
# 9094  1516     5       운동     칭찬  다빈 선수 올림픽 2위도 쩌는 거 같음    올림픽 2위
# 9095  1516     6       운동     칭찬     이다빈 선수 2위 은메달도 멋있어    2위 은메달
#
#      arg_op2 label
# 9090            83
# 9091            83
# 9092            83
# 9093            83
# 9094            83
# 9095            83

# %% [markdown]
# ### arg 목적어 교체

# %%
stopwords = "은/는/이/가/을/를/와/과/이랑/랑/도/로/으로/에서/에게/한테/부터/까지/에/만/와도/와는/과도/과는/이랑도/이랑은/랑도/랑은/로는/에는/에도/까지도/한테도/한테는"
stop_list = stopwords.split("/")

# %%
print(stop_list)
# Out:
# ['은', '는', '이', '가', '을', '를', '와', '과', '이랑', '랑', '도', '로', '으로', '에서', '에게', '한테', '부터', '까지', '에', '만', '와도', '와는', '과도', '과는', '이랑도', '이랑은', '랑도', '랑은', '로는', '에는', '에도', '까지도', '한테도', '한테는']

# %%
temp_list = []
result = []

for i in tqdm(df_remain.iterrows()):
  temp_list.append([i[1]['g_num'], i[1]['u_num'], i[1]['material'], i[1]['speech'], i[1]['u'], i[1]['arg1_space'], i[1]['arg_op1'], i[1]['arg_op2'], i[1]['label']])
  
  # group of 6
  if len(temp_list) % 6 == 0:
    # replace arg
    temp_arg = list(set([i[5].replace(',', '') for i in temp_list]))
    for l in temp_list:
      # origin
      result.append([l[0], l[1], l[2], l[3], l[4], l[5], l[6], l[7], l[8]])

      # replacement
      if len(temp_arg) > 1:
        # 교체될 단어가 문장의 첫 어절이면 스페이스를 뒤만.
        # 교체될 단어가 문장의 첫 어절이 아니면 스페이스를 앞뒤로.
        for k, v in enumerate(temp_arg):
          temp_arg_copy = temp_arg.copy()
          temp_arg_copy.pop(k)
          for ii in temp_arg_copy:
            # 어절이 맨 앞인 경우
            if l[4].find(v.strip()) == 0 and l[4] != l[4].replace(v.lstrip(), ii.lstrip()):
              result.append([l[0], l[1], l[2], l[3], l[4].replace(v.lstrip(), ii.lstrip()), ii.strip(), l[6], l[7], l[8]])
            # 어절이 중간에 있는 경우
            elif l[4].find(v.strip()) > 0 and l[4] != l[4].replace(v, ii):
              result.append([l[0], l[1], l[2], l[3], l[4].replace(v, ii), ii.strip(), l[6], l[7], l[8]])
            # 조사는 어절의 뒤에 붙기 때문에 목적어를 찾아 뒤에 말에 조사가 있는지를 판단해서 ex) 올림픽 은메달도 -> 올림픽 은메달 x
            for s in stop_list:
              if l[4].find(v.strip() + s) >= 0:
                result.append([l[0], l[1], l[2], l[3], l[4].replace(v.strip() + s, ii.strip() + s), ii.strip(), l[6], l[7], l[8]])
    temp_list = []
# Out:
# 7212it [00:02, 2837.14it/s]

# %%
print(f"result : {result}")
# Out:
# result : [[1, 1, '학교생활', '자랑', '나 중간고사 반에서 1등했어', ' 중간고사 ', '', '', 146], [1, 1, '학교생활', '자랑', '나 중간 반에서 1등했어', '중간', '', '', 146], [1, 1, '학교생활', '자랑', '나 시험 반에서 1등했어', '시험', '', '', 146], [1, 1, '학교생활', '자랑', '나 중간시험 반에서 1등했어', '중간시험', '', '', 146], [1, 2, '학교생활', '자랑', '중간고사 점수 내가 반에서 제일 잘 받음', ' 중간고사 ', '', '', 146], [1, 2, '학교생활', '자랑', '중간 점수 내가 반에서 제일 잘 받음', '중간', '', '', 146], [1, 2, '학교생활', '자랑', '시험 점수 내가 반에서 제일 잘 받음', '시험', '', '', 146], [1, 2, '학교생활', '자랑', '중간시험 점수 내가 반에서 제일 잘 받음', '중간시험', '', '', 146], [1, 3, '학교생활', '자랑', '나 반에서 중간 성적 제일 좋아', ' 중간 ', '', '', 146], [1, 3, '학교생활', '자랑', '나 반에서 중간고사 성적 제일 좋아', '중간고사', '', '', 146], [1, 3, '학교생활', '자랑', '나 반에서 시험 성적 제일 좋아', '시험', '', '', 146], [1, 3, '학교생활', '자랑', '나 반에서 중간시험 성적 제일 좋아', '중간시험', '', '', 146], [1, 4, '학교생활', '자랑', '우리 반에서 내가 시험 제일 잘 봤다', ' 시험 ', '', '', 146], [1, 4, '학교생활', '자랑', '우리 반에서 내가 중간고사 제일 잘 봤다', '중간고사', '', '', 146], [1, 4, '학교생활', '자랑', '우리 반에서 내가 중간 제일 잘 봤다', '중간', '', '', 146], [1, 4, '학교생활', '자랑', '우리 반에서 내가 중간시험 제일 잘 봤다', '중간시험', '', '', 146], [1, 5, '학교생활', '자랑', '중간고사 반 1등 먹음', ' 중간고사 ', '', '', 146], [1, 5, '학교생활', '자랑', '중간 반 1등 먹음', '중간', '', '', 146], [1, 5, '학교생활', '자랑', '시험 반 1등 먹음', '시험', '', '', 146], [1, 5, '학교생활', '자랑', '중간시험 반 1등 먹음', '중간시험', '', '', 146], [1, 6, '학교생활', '자랑', '중간시험 내가 반 1등이야', ' 중간시험 ', '', '', 146], [1, 6, '학교생활', '자랑', '중간고사 내가 반 1등이야', '중간고사', '', '', 146], [1, 6, '학교생활', '자랑', '중간 내가 반 1등이야', '중간', '', '', 146], [1, 6, '학교생활', '자랑', '시험 내가 반 1등이야', '시험', '', '', 146], [4, 1, '문화예술', '자랑', '오예 티켓팅 성공했어', ' 티켓팅 ', '', '', 39], [4, 1, '문화예술', '자랑', '오예 티켓 성공했어', '티켓', '', '', 39], [4, 2, '문화예술', '자랑', '나 티켓 잡았다~', ' 티켓 ', '', '', 39], [4, 2, '문화예술', '자랑', '나 티켓팅 잡았다~', '티켓팅', '', '', 39], [4, 3, '문화예술', '자랑', '드디어 티켓 겟했다고!', ' 티켓 ', '', '', 39], [4, 3, '문화예술', '자랑', '드디어 티켓팅 겟했다고!', '티켓팅', '', '', 39], [4, 4, '문화예술', '자랑', '나도 이제 티켓 갖게 됐어', ' 티켓 ', '', '', 39], [4, 4, '문화예술', '자랑', '나도 이제 티켓팅 갖게 됐어', '티켓팅', '', '', 39], [4, 5, '문화예술', '자랑', '티켓팅 성공적으로 끝냄', ' 티켓팅 ', '', '', 39], [4, 5, '문화예술', '자랑', '티켓 성공적으로 끝냄', '티켓', '', '', 39], [4, 6, '문화예술', '자랑', '이번 티켓팅은 실패 안 했지롱', ' 티켓팅 ', '', '', 39], [4, 6, '문화예술', '자랑', '이번 티켓은 실패 안 했지롱', '티켓', '', '', 39], [6, 1, '문화예술', '칭찬', '해리포터는 최고야', ' 해리포터 ', '', '', 41], [6, 2, '문화예술', '칭찬', '해리포터는 짱이지', ' 해리포터 ', '', '', 41], [6, 3, '문화예술', '칭찬', '해리포터는 레전드라니까', ' 해리포터 ', '', '', 41], [6, 4, '문화예술', '칭찬', '해리포터 미만 잡', ' 해리포터 ', '', '', 41], [6, 5, '문화예술', '칭찬', '해리포터 레게노', ' 해리포터 ', '', '', 41], [6, 6, '문화예술', '칭찬', '해리포터는 원탑이야', ' 해리포터 ', '', '', 41], [8, 1, '음식', '계획', '퇴근하면 치킨 먹을 거야', ' 치킨 ', '퇴근하면', '', 96], [8, 2, '음식', '계획', '나 퇴근하고 치킨 조지려고', ' 치킨 ', '퇴근하고', '', 96], [8, 3, '음식', '계획', '집 가서 치킨 냠냠할 것', ' 치킨 ', '집 가서', '', 96], [8, 4, '음식', '계획', '저녁엔 치킨을 해치우겠어', ' 치킨 ', '저녁에', '', 96], [8, 5, '음식', '계획', '귀가하고 치킨 먹을 거임~', ' 치킨 ', '귀가하고', '', 96], [8, 6, '음식', '계획', '일 끝나면 치킨 먹어야지', ' 치킨 ', '일 끝나면', '', 96], [9, 1, '교통', '소망', '한강에서 자전거 타고 싶어', ' 한강에서 자전거 ', '', '', 13], [9, 1, '교통', '소망', '한강 라이딩 타고 싶어', '한강 라이딩', '', '', 13], [9, 1, '교통', '소망', '한강에서 라이딩 타고 싶어', '한강에서 라이딩', '', '', 13], [9, 1, '교통', '소망', '한강에서 바이크 타고 싶어', '한강에서 바이크', '', '', 13], [9, 1, '교통', '소망', '한강 가서 자전거 타고 싶어', '한강 가서 자전거', '', '', 13], [9, 2, '교통', '소망', '한강에서 라이딩 하고 싶다', ' 한강에서 라이딩 ', '', '', 13], [9, 2, '교통', '소망', '한강 라이딩 하고 싶다', '한강 라이딩', '', '', 13], [9, 2, '교통', '소망', '한강에서 자전거 하고 싶다', '한강에서 자전거', '', '', 13], [9, 2, '교통', '소망', '한강에서 바이크 하고 싶다', '한강에서 바이크', '', '', 13], [9, 2, '교통', '소망', '한강 가서 자전거 하고 싶다', '한강 가서 자전거', '', '', 13], [9, 3, '교통', '소망', '한강 가서 자전거 끌고 싶네', ' 한강 가서 자전거 ', '', '', 13], [9, 3, '교통', '소망', '한강 라이딩 끌고 싶네', '한강 라이딩', '', '', 13], [9, 3, '교통', '소망', '한강에서 자전거 끌고 싶네', '한강에서 자전거', '', '', 13], [9, 3, '교통', '소망', '한강에서 라이딩 끌고 싶네', '한강에서 라이딩', '', '', 13], [9, 3, '교통', '소망', '한강에서 바이크 끌고 싶네', '한강에서 바이크', '', '', 13], [9, 4, '교통', '소망', '한강 라이딩 돌고 싶어', ' 한강 라이딩 ', '', '', 13], [9, 4, '교통', '소망', '한강에서 자전거 돌고 싶어', '한강에서 자전거', '', '', 13], [9, 4, '교통', '소망', '한강에 ...

# %%
df_result = pd.DataFrame(result, columns=['g_num', 'u_num', 'material', 'speech', 'u', 'arg_replace', 'arg_op1', 'arg_op2', 'label'])

# %%
df_result[df_result.g_num.values==1516]
# Out:
#        g_num  u_num material speech                         u arg_replace  \
# 22210   1516      1       운동     칭찬       이다빈 선수 올림픽 은메달도 간지나    올림픽 은메달
# 22211   1516      1       운동     칭찬    이다빈 선수 올림픽 2위 은메달도 간지나      2위 은메달
# 22212   1516      1       운동     칭찬    이다빈 선수 올림픽 2등 은메달도 간지나      2등 은메달
# 22213   1516      1       운동     칭찬    이다빈 선수 올림픽 올림픽 2등도 간지나      올림픽 2등
# 22214   1516      1       운동     칭찬   이다빈 선수 올림픽 올림픽 은메달도 간지나     올림픽 은메달
# 22215   1516      1       운동     칭찬    이다빈 선수 올림픽 올림픽 2위도 간지나      올림픽 2위
# 22216   1516      1       운동     칭찬        이다빈 선수 2위 은메달도 간지나      2위 은메달
# 22217   1516      1       운동     칭찬        이다빈 선수 2등 은메달도 간지나      2등 은메달
# 22218   1516      1       운동     칭찬        이다빈 선수 올림픽 2등도 간지나      올림픽 2등
# 22219   1516      1       운동     칭찬           이다빈 선수 은메달도 간지나         은메달
# 22220   1516      1       운동     칭찬        이다빈 선수 올림픽 2위도 간지나      올림픽 2위
# 22221   1516      2       운동     칭찬            다빈선수 은메달도 멋지잖아        은메달
# 22222   1516      2       운동     칭찬         다빈선수 2위 은메달도 멋지잖아      2위 은메달
# 22223   1516      2       운동     칭찬         다빈선수 2등 은메달도 멋지잖아      2등 은메달
# 22224   1516      2       운동     칭찬         다빈선수 올림픽 2등도 멋지잖아      올림픽 2등
# 22225   1516      2       운동     칭찬        다빈선수 올림픽 은메달도 멋지잖아     올림픽 은메달
# 22226   1516      2       운동     칭찬         다빈선수 올림픽 2위도 멋지잖아      올림픽 2위
# 22227   1516      3       운동     칭찬       이다빈 선수 올림픽 2등도 본새난다     올림픽 2등
# 22228   1516      3       운동     칭찬       이다빈 선수 2위 은메달도 본새난다      2위 은메달
# 22229   1516      3       운동     칭찬       이다빈 선수 2등 은메달도 본새난다      2등 은메달
# 22230   1516      3       운동     칭찬          이다빈 선수 은메달도 본새난다         은메달
# 22231   1516      3       운동     칭찬      이다빈 선수 올림픽 은메달도 본새난다     올림픽 은메달
# 22232   1516      3       운동     칭찬       이다빈 선수 올림픽 2위도 본새난다      올림픽 2위
# 22233   1516      4       운동     칭찬      그 선수 2등 은메달도 대단하지 않냐     2등 은메달
# 22234   1516      4       운동     칭찬      그 선수 2위 은메달도 대단하지 않냐      2위 은메달
# 22235   1516      4       운동     칭찬      그 선수 올림픽 2등도 대단하지 않냐      올림픽 2등
# 22236   1516      4       운동     칭찬         그 선수 은메달도 대단하지 않냐         은메달
# 22237   1516      4       운동     칭찬     그 선수 올림픽 은메달도 대단하지 않냐     올림픽 은메달
# 22238   1516      4       운동     칭찬      그 선수 올림픽 2위도 대단하지 않냐      올림픽 2위
# 22239   1516      4       운동     칭찬   그 선수 2등 2위 은메달도 대단하지 않냐      2위 은메달
# 22240   1516      4       운동     칭찬   그 선수 2등 2등 은메달도 대단하지 않냐      2등 은메달
# 22241   1516      4       운동     칭찬   그 선수 2등 올림픽 2등도 대단하지 않냐      올림픽 2등
# 22242   1516      4       운동     칭찬  그 선수 2등 올림픽 은메달도 대단하지 않냐     올림픽 은메달
# 22243   1516      4       운동     칭찬   그 선수 2등 올림픽 2위도 대단하지 않냐      올림픽 2위
# 22244   1516      5       운동     칭찬     다빈 선수 올림픽 2위도 쩌는 거 같음     올림픽 2위
# 22245   1516      5       운동     칭찬     다빈 선수 2위 은메달도 쩌는 거 같음      2위 은메달
# 22246   1516      5       운동     칭찬     다빈 선수 2등 은메달도 쩌는 거 같음      2등 은메달
# 22247   1516      5       운동     칭찬     다빈 선수 올림픽 2등도 쩌는 거 같음      올림픽 2등
# 22248   1516      5       운동     칭찬        다빈 선수 은메달도 쩌는 거 같음         은메달
# 22249   1516      5       운동     칭찬    다빈 선수 올림픽 은메달도 쩌는 거 같음     올림픽 은메달
# 22250   1516      6       운동     칭찬        이다빈 선수 2위 은메달도 멋있어     2위 은메달
# 22251   1516      6       운동     칭찬        이다빈 선수 2등 은메달도 멋있어      2등 은메달
# 22252   1516      6       운동     칭찬        이다빈 선수 올림픽 2등도 멋있어      올림픽 2등
# 22253   1516      6       운동     칭찬           이다빈 선수 은메달도 멋있어         은메달
# 22254   1516      6       운동     칭찬       이다빈 선수 올림픽 은메달도 멋있어     올림픽 은메달
# 22255   1516      6       운동     칭찬        이다빈 선수 올림픽 2위도 멋있어      올림픽 2위
# 22256   1516      6       운동     칭찬     이다빈 선수 2위 2위 은메달도 멋있어      2위 은메달
# 22257   1516      6       운동     칭찬     이다빈 선수 2위 2등 은메달도 멋있어      2등 은메달
# 22258   1516      6       운동     칭찬     이다빈 선수 2위 올림픽 2등도 멋있어      올림픽 2등
# 22259   1516      6       운동     칭찬    이다빈 선수 2위 올림픽 은메달도 멋있어     올림픽 은메달
# 22260   1516      6       운동     칭찬     이다빈 선수 2위 올림픽 2위도 멋있어      올림픽 2위
#
#       arg_op1 arg_op2  label
# 22210                     83
# 22211                     83
# 22212                     83
# 22213                     83
# 22214                     83
# 22215                     83
# 22216                     83
# 22217                     83
# 22218                     83
# 22219                     83
# 22220                     83
# 22221                     83
# 22222                     83
# 22223                     83
# 22224                     83
# 22225                     83
# 22226                     83
# 22227                     83
# 22228                     83
# 22229                     83
# 22230                     83
# 22231                     83
# 22232                     83
# 22233                     83
# 22234                     83
# 22235                     83
# 22236                     83
# 22237                     83
# 22238                     83
# 22239                     83
# 22240                     83
# 22241                     83
# 22242                     83
# 22243                     83
# 22244                     83
# 22245                     83
# 22246                     83
# 22247                     83
# 22248                     83
# 22249                     83
# 22250                     83
# 22251                     83
# 22252                     83
# 22253                     83
# 22254                     83
# 22255                     83
# 22256                     83
# 22257                     83
# 22258                     83
# 22259                     83
# 22260                     83

# %%
df_result.shape
# Out:
# (22468, 9)

# %% [markdown]
# ### arg_op 부사어 교체

# %% [markdown]
# arg_op1

# %%
temp_list2 = []
result2 = []

for i in tqdm(df_result.iterrows()):
  #if i[0] == 0 or i[1]['g_num'] == 1525 or df_result.g_num.iloc[i[0]-1] == i[1]['g_num']:
  temp_list2.append([i[1]['g_num'], i[1]['u_num'], i[1]['material'], i[1]['speech'], i[1]['u'], i[1]['arg_replace'].strip(), i[1]['arg_op1'], i[1]['arg_op2'], i[1]['label']])

  if df_result.g_num.iloc[i[0]-1] != i[1]['g_num']:
    # 마지막 요소 다음으로 보내기
    temp_pop = temp_list2.pop()

    # replace arg_op
    temp_arg_op = [i for i in list(set([i[6].strip()+", "+i[7].strip() for i in temp_list2])) if i != ', ']
    temp_arg_op = [i.split(', ') for i in temp_arg_op]

    # 부사어 arg_op1 부터 쉼표를 두 개로 나누는데 하나면 제외
    # 교체될 단어가 문장의 첫 어절이면 스페이스를 뒤만.
    # 교체될 단어가 문장의 첫 어절이 아니면 스페이스를 앞뒤로.
    temp_arg_op_check = []
    temp_arg_op_v = []
    for i in temp_arg_op:
      temp = []
      for ii in i:
        if len(ii) > 0:
          temp.append(" " + ii.strip() + " ")
      temp_arg_op_check.append(len(temp))
      temp_arg_op_v.append(temp)

    temp_arg_op_check = list(set([len(i) for i in temp_arg_op_v]))
    temp_arg_op1 = []
    temp_arg_op2 = []

    # origin
    result2.append([l[0], l[1], l[2], l[3], l[4], l[5].strip(), l[6], l[7], l[8]])

    # 없을 때
    if not temp_arg_op_check:
      for l in temp_list2:
        result2.append([l[0], l[1], l[2], l[3], l[4], l[5].strip(), '', l[7], l[8]])
    # 1개 일 때
    elif temp_arg_op_check == [1]:
      temp_arg_op11 = sum(temp_arg_op_v, [])
      for l in temp_list2:
        # origin
        result2.append([l[0], l[1], l[2], l[3], l[4], l[5].strip(), '', l[7], l[8]])
        # 1
        for k, i2 in enumerate(temp_arg_op11):
          temp_arg_op11_copy = temp_arg_op11.copy()
          temp_arg_op11_copy.pop(k)
          for ii2 in temp_arg_op11_copy:
            # 첫 번째 어절인지
            if l[4].find(i2.strip()) == 0 and l[4] != l[4].replace(i2.lstrip(), ii2.lstrip()):
              result2.append([l[0], l[1], l[2], l[3], l[4].replace(i2.lstrip(), ii2.lstrip()), l[5].strip(), ii2.strip(), l[7], l[8]])
            # 중간에 있는 어절인지
            elif l[4].find(i2.strip()) > 0 and l[4] != l[4].replace(i2, ii2):
              result2.append([l[0], l[1], l[2], l[3], l[4].replace(i2, ii2), l[5].strip(), ii2.strip(), l[7], l[8]])            
            # 조사는 어절의 뒤에 붙기 때문에 목적어를 찾아 뒤에 말에 조사가 있는지를 판단해서 ex)올림픽 은메달도 -> 올림픽 은메달 x
            for s in stop_list:
              if l[4].find(i2.strip() + s) >= 0:
                result.append([l[0], l[1], l[2], l[3], l[4].replace(i2.strip() + s, ii2.strip() + s), ii2.strip(), l[6], l[7], l[8]])
    # 2개 일 때
    elif 2 in temp_arg_op_check:
      for i in temp_arg_op_v:
        if len(i) != 1:
          temp_arg_op1.append(i[0])
          temp_arg_op2.append(i[1])
      
      for l in temp_list2:
        # origin
        result2.append([l[0], l[1], l[2], l[3], l[4], l[5], '', l[7], l[8]])
        
        # 1
        for k, i2 in enumerate(temp_arg_op1):
          temp_arg_op1_copy = temp_arg_op1.copy()
          temp_arg_op1_copy.pop(k)
          for ii2 in temp_arg_op1_copy:
            if l[4].find(i2.strip()) == 0 and l[4] != l[4].replace(i2.lstrip(), ii2.lstrip()):
              result2.append([l[0], l[1], l[2], l[3], l[4].replace(i2.lstrip(), ii2.lstrip()), l[5], ii2.strip(), l[7].strip(), l[8]])
            elif l[4].find(i2.strip()) > 0 and l[4] != l[4].replace(i2, ii2):
              result2.append([l[0], l[1], l[2], l[3], l[4].replace(i2, ii2), l[5], ii2.strip(), l[7].strip(), l[8]])
            # 조사는 어절의 뒤에 붙기 때문에 목적어를 찾아 뒤에 말에 조사가 있는지를 판단해서 ex)올림픽 은메달도 -> 올림픽 은메달 x
            for s in stop_list:
              if l[4].find(i2.strip() + s) >= 0:
                result.append([l[0], l[1], l[2], l[3], l[4].replace(i2.strip() + s, ii2.strip() + s), ii2.strip(), l[6], l[7], l[8]])
        # 2
        for k, i2 in enumerate(temp_arg_op2):
          temp_arg_op2_copy = temp_arg_op2.copy()
          temp_arg_op2_copy.pop(k)
          for ii2 in temp_arg_op2_copy:
            if l[4].find(i2.strip()) == 0 and l[4] != l[4].replace(i2.lstrip(), ii2.lstrip()):
              result2.append([l[0], l[1], l[2], l[3], l[4].replace(i2.lstrip(), ii2.lstrip()), l[5], l[6].strip(), ii2.strip(), l[8]])
            elif l[4].find(i2.strip()) > 0 and l[4] != l[4].replace(i2, ii2):
              result2.append([l[0], l[1], l[2], l[3], l[4].replace(i2, ii2), l[5], l[6].strip(), ii2.strip(), l[8]])
            # 조사는 어절의 뒤에 붙기 때문에 목적어를 찾아 뒤에 말에 조사가 있는지를 판단해서 ex)올림픽 은메달도 -> 올림픽 은메달 x
            for s in stop_list:
              if l[4].find(i2.strip() + s) >= 0:
                result.append([l[0], l[1], l[2], l[3], l[4].replace(i2.strip() + s, ii2.strip() + s), ii2.strip(), l[6], l[7], l[8]])

    temp_list2 = []
    temp_list2.append(temp_pop)
# Out:
# 22468it [00:04, 4607.59it/s]

# %%
print(result2[:2])
# Out:
# [[1525, 6, '경사', '자랑', '전국노래자랑에서 이모가 1등했다', '', '전국노래자랑에서', '', 9], [1525, 6, '경사', '자랑', '전국노래자랑에서 이모가 1등했다', '', '전국노래자랑에서', '', 9]]

# %%
df_result2 = pd.DataFrame(result2, columns=['g_num', 'u_num', 'material', 'speech', 'u', 'arg_replace', 'arg_op1_replace', 'arg_op2_replace', 'label'])

# %%
df_result2.shape
# Out:
# (56262, 9)

# %%
df_result2.tail()
# Out:
#        g_num  u_num material speech                       u arg_replace  \
# 56257   1524      6       미용     계획  울 엄마한테 아이브로우문신 시술받을 거다     아이브로우문신
# 56258   1524      6       미용     계획   울엄마한테 아이브로우문신 시술받을 거다     아이브로우문신
# 56259   1524      6       미용     계획       엄마한테 눈썹헤나 시술받을 거다        눈썹헤나
# 56260   1524      6       미용     계획     울 엄마한테 눈썹헤나 시술받을 거다        눈썹헤나
# 56261   1524      6       미용     계획      울엄마한테 눈썹헤나 시술받을 거다        눈썹헤나
#
#       arg_op1_replace arg_op2_replace  label
# 56257          울 엄마한테                     48
# 56258           울엄마한테                     48
# 56259                                     48
# 56260          울 엄마한테                     48
# 56261           울엄마한테                     48

# %%
df_result2[df_result2.g_num.values==1516]
# Out:
#        g_num  u_num material speech                         u arg_replace  \
# 55740   1516      1       운동     칭찬       이다빈 선수 올림픽 은메달도 간지나     올림픽 은메달
# 55741   1516      1       운동     칭찬    이다빈 선수 올림픽 2위 은메달도 간지나      2위 은메달
# 55742   1516      1       운동     칭찬    이다빈 선수 올림픽 2등 은메달도 간지나      2등 은메달
# 55743   1516      1       운동     칭찬    이다빈 선수 올림픽 올림픽 2등도 간지나      올림픽 2등
# 55744   1516      1       운동     칭찬   이다빈 선수 올림픽 올림픽 은메달도 간지나     올림픽 은메달
# 55745   1516      1       운동     칭찬    이다빈 선수 올림픽 올림픽 2위도 간지나      올림픽 2위
# 55746   1516      1       운동     칭찬        이다빈 선수 2위 은메달도 간지나      2위 은메달
# 55747   1516      1       운동     칭찬        이다빈 선수 2등 은메달도 간지나      2등 은메달
# 55748   1516      1       운동     칭찬        이다빈 선수 올림픽 2등도 간지나      올림픽 2등
# 55749   1516      1       운동     칭찬           이다빈 선수 은메달도 간지나         은메달
# 55750   1516      1       운동     칭찬        이다빈 선수 올림픽 2위도 간지나      올림픽 2위
# 55751   1516      2       운동     칭찬            다빈선수 은메달도 멋지잖아         은메달
# 55752   1516      2       운동     칭찬         다빈선수 2위 은메달도 멋지잖아      2위 은메달
# 55753   1516      2       운동     칭찬         다빈선수 2등 은메달도 멋지잖아      2등 은메달
# 55754   1516      2       운동     칭찬         다빈선수 올림픽 2등도 멋지잖아      올림픽 2등
# 55755   1516      2       운동     칭찬        다빈선수 올림픽 은메달도 멋지잖아     올림픽 은메달
# 55756   1516      2       운동     칭찬         다빈선수 올림픽 2위도 멋지잖아      올림픽 2위
# 55757   1516      3       운동     칭찬       이다빈 선수 올림픽 2등도 본새난다      올림픽 2등
# 55758   1516      3       운동     칭찬       이다빈 선수 2위 은메달도 본새난다      2위 은메달
# 55759   1516      3       운동     칭찬       이다빈 선수 2등 은메달도 본새난다      2등 은메달
# 55760   1516      3       운동     칭찬          이다빈 선수 은메달도 본새난다         은메달
# 55761   1516      3       운동     칭찬      이다빈 선수 올림픽 은메달도 본새난다     올림픽 은메달
# 55762   1516      3       운동     칭찬       이다빈 선수 올림픽 2위도 본새난다      올림픽 2위
# 55763   1516      4       운동     칭찬      그 선수 2등 은메달도 대단하지 않냐      2등 은메달
# 55764   1516      4       운동     칭찬      그 선수 2위 은메달도 대단하지 않냐      2위 은메달
# 55765   1516      4       운동     칭찬      그 선수 올림픽 2등도 대단하지 않냐      올림픽 2등
# 55766   1516      4       운동     칭찬         그 선수 은메달도 대단하지 않냐         은메달
# 55767   1516      4       운동     칭찬     그 선수 올림픽 은메달도 대단하지 않냐     올림픽 은메달
# 55768   1516      4       운동     칭찬      그 선수 올림픽 2위도 대단하지 않냐      올림픽 2위
# 55769   1516      4       운동     칭찬   그 선수 2등 2위 은메달도 대단하지 않냐      2위 은메달
# 55770   1516      4       운동     칭찬   그 선수 2등 2등 은메달도 대단하지 않냐      2등 은메달
# 55771   1516      4       운동     칭찬   그 선수 2등 올림픽 2등도 대단하지 않냐      올림픽 2등
# 55772   1516      4       운동     칭찬  그 선수 2등 올림픽 은메달도 대단하지 않냐     올림픽 은메달
# 55773   1516      4       운동     칭찬   그 선수 2등 올림픽 2위도 대단하지 않냐      올림픽 2위
# 55774   1516      5       운동     칭찬     다빈 선수 올림픽 2위도 쩌는 거 같음      올림픽 2위
# 55775   1516      5       운동     칭찬     다빈 선수 2위 은메달도 쩌는 거 같음      2위 은메달
# 55776   1516      5       운동     칭찬     다빈 선수 2등 은메달도 쩌는 거 같음      2등 은메달
# 55777   1516      5       운동     칭찬     다빈 선수 올림픽 2등도 쩌는 거 같음      올림픽 2등
# 55778   1516      5       운동     칭찬        다빈 선수 은메달도 쩌는 거 같음         은메달
# 55779   1516      5       운동     칭찬    다빈 선수 올림픽 은메달도 쩌는 거 같음     올림픽 은메달
# 55780   1516      6       운동     칭찬        이다빈 선수 2위 은메달도 멋있어      2위 은메달
# 55781   1516      6       운동     칭찬        이다빈 선수 2등 은메달도 멋있어      2등 은메달
# 55782   1516      6       운동     칭찬        이다빈 선수 올림픽 2등도 멋있어      올림픽 2등
# 55783   1516      6       운동     칭찬           이다빈 선수 은메달도 멋있어         은메달
# 55784   1516      6       운동     칭찬       이다빈 선수 올림픽 은메달도 멋있어     올림픽 은메달
# 55785   1516      6       운동     칭찬        이다빈 선수 올림픽 2위도 멋있어      올림픽 2위
# 55786   1516      6       운동     칭찬     이다빈 선수 2위 2위 은메달도 멋있어      2위 은메달
# 55787   1516      6       운동     칭찬     이다빈 선수 2위 2등 은메달도 멋있어      2등 은메달
# 55788   1516      6       운동     칭찬     이다빈 선수 2위 올림픽 2등도 멋있어      올림픽 2등
# 55789   1516      6       운동     칭찬    이다빈 선수 2위 올림픽 은메달도 멋있어     올림픽 은메달
# 55790   1516      6       운동     칭찬     이다빈 선수 2위 올림픽 2위도 멋있어      올림픽 2위
# 55791   1516      6       운동     칭찬     이다빈 선수 2위 올림픽 2위도 멋있어      올림픽 2위
#
#       arg_op1_replace arg_op2_replace  label
# 55740                                     83
# 55741                                     83
# 55742                                     83
# 55743                                     83
# 55744                                     83
# 55745                                     83
# 55746                                     83
# 55747                                     83
# 55748                                     83
# 55749                                     83
# 55750                                     83
# 55751                                     83
# 55752                                     83
# 55753                                     83
# 55754                                     83
# 55755                                     83
# 55756                                     83
# 55757                                     83
# 55758                                     83
# 55759                                     83
# 55760                                     83
# 55761                                     83
# 55762                                     83
# 55763                                     83
# 55764                                     83
# 55765                                     83
# 55766                                     83
# 55767                                     83
# 55768                                     83
# 55769                                     83
# 55770                                     83
# 55771                                     83
# 55772                                     83
# 55773                                     83
# 55774                                     83
# 55775                                     83
# 55776                                     83
# 55777                                     83
# 55778                                     83
# 55779                                     83
# 55780                                     83
# 55781                                     83
# 55782                                     83
# 55783                                     83
# 55784                                     83
# 55785                                     83
# 55786                                     83
# 55787                                     83
# 55788                                     83
# 55789                                     83
# 55790                                     83
# 55791                                     83

# %% [markdown]
# ### data concatenate

# %%
df_memebot.label.value_counts()
# Out:
# (label,)
# 150         492
# 152         486
# 149         480
# 151         480
# dtype: int64

# %%
df_memebot.rename(columns={'arg1_space' : 'arg'}, inplace=True)
df_result2.rename(columns={'arg_replace':'arg'}, inplace=True)
df_result2.rename(columns={'arg_op1_replace':'arg_op1'}, inplace=True)
df_result2.rename(columns={'arg_op2_replace':'arg_op2'}, inplace=True)
# Out:
# <ipython-input-140-c9a1073855a2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_memebot.rename(columns={'arg1_space' : 'arg'}, inplace=True)

# %%
df_result2.head()
# Out:
#    g_num  u_num material speech                  u   arg   arg_op1 arg_op2  \
# 0   1525      6       경사     자랑  전국노래자랑에서 이모가 1등했다        전국노래자랑에서
# 1   1525      6       경사     자랑  전국노래자랑에서 이모가 1등했다        전국노래자랑에서
# 2      1      1     학교생활     자랑    나 중간고사 반에서 1등했어  중간고사
# 3      1      1     학교생활     자랑      나 중간 반에서 1등했어    중간
# 4      1      1     학교생활     자랑      나 시험 반에서 1등했어    시험
#
#    label
# 0      9
# 1      9
# 2    146
# 3    146
# 4    146

# %%
df_memebot = df_memebot[['g_num',	'u_num', 'material', 'speech', 'u', 'arg', 'arg_op1', 'arg_op2', 'label']]
df_result2 = df_result2[['g_num',	'u_num', 'material', 'speech', 'u', 'arg', 'arg_op1', 'arg_op2', 'label']]

# %%
df_result2.head()
# Out:
#    g_num  u_num material speech                  u   arg   arg_op1 arg_op2  \
# 0   1525      6       경사     자랑  전국노래자랑에서 이모가 1등했다        전국노래자랑에서
# 1   1525      6       경사     자랑  전국노래자랑에서 이모가 1등했다        전국노래자랑에서
# 2      1      1     학교생활     자랑    나 중간고사 반에서 1등했어  중간고사
# 3      1      1     학교생활     자랑      나 중간 반에서 1등했어    중간
# 4      1      1     학교생활     자랑      나 시험 반에서 1등했어    시험
#
#    label
# 0      9
# 1      9
# 2    146
# 3    146
# 4    146

# %%
memebot = [[i[1]['g_num'], i[1]['u_num'], i[1]['material'], i[1]['speech'], i[1]['u'], i[1]['arg'].strip(), i[1]['arg_op1'], i[1]['arg_op2'], i[1]['label']] for i in df_memebot.iterrows()]
result = [[i[1]['g_num'], i[1]['u_num'], i[1]['material'], i[1]['speech'], i[1]['u'], i[1]['arg'], i[1]['arg_op1'], i[1]['arg_op2'], i[1]['label']] for i in df_result2.iterrows()]

# %%
result_list = result + memebot

# %%
len(result_list)
# Out:
# 58200

# %%
df = pd.DataFrame(result_list, columns=[['g_num',	'u_num', 'material', 'speech', 'u', 'arg', 'arg_op1', 'arg_op2', 'label']])

# %%
# df = df[['g_num',	'u_num', 'material', 'speech', 'u', 'label']]
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (52802, 9)

# %%
df[df.label.values==101]
# Out:
#       g_num u_num material speech                     u              arg  \
# 356      24     1       음식     칭찬     이번에 개업한 삼겹살집 맛있더라     이번에 개업한 삼겹살집
# 357      24     1       음식     칭찬     새로 생긴 삼겹살 가게 맛있더라     새로 생긴 삼겹살 가게
# 358      24     1       음식     칭찬  얼마 전에 오픈한 정육 식당 맛있더라  얼마 전에 오픈한 정육 식당
# 359      24     1       음식     칭찬       최근에 생긴 고깃집 맛있더라       최근에 생긴 고깃집
# 360      24     1       음식     칭찬            그 고깃집 맛있더라            그 고깃집
# ...     ...   ...      ...    ...                   ...              ...
# 44326  1439     6       음식     칭찬     집앞 족발가게 찐으로 존맛탱이야          집앞 족발가게
# 44327  1439     6       음식     칭찬      집앞 족발가게 완전 존맛탱이야          집앞 족발가게
# 44328  1439     6       음식     칭찬      집앞 족발가게 진짜 존맛탱이야          집앞 족발가게
# 44329  1439     6       음식     칭찬      집앞 족발가게 레알 존맛탱이야          집앞 족발가게
# 44330  1439     6       음식     칭찬      집앞 족발가게 정말 존맛탱이야          집앞 족발가게
#
#       arg_op1 arg_op2 label
# 356                     101
# 357                     101
# 358                     101
# 359                     101
# 360                     101
# ...       ...     ...   ...
# 44326     찐으로           101
# 44327      완전           101
# 44328      진짜           101
# 44329      레알           101
# 44330      정말           101
#
# [675 rows x 9 columns]

# %%
df[df.label.values==83]
# Out:
#       g_num u_num material speech                         u      arg arg_op1  \
# 50346  1516     1       운동     칭찬       이다빈 선수 올림픽 은메달도 간지나  올림픽 은메달
# 50347  1516     1       운동     칭찬    이다빈 선수 올림픽 2위 은메달도 간지나   2위 은메달
# 50348  1516     1       운동     칭찬    이다빈 선수 올림픽 2등 은메달도 간지나   2등 은메달
# 50349  1516     1       운동     칭찬    이다빈 선수 올림픽 올림픽 2등도 간지나   올림픽 2등
# 50350  1516     1       운동     칭찬   이다빈 선수 올림픽 올림픽 은메달도 간지나  올림픽 은메달
# 50351  1516     1       운동     칭찬    이다빈 선수 올림픽 올림픽 2위도 간지나   올림픽 2위
# 50352  1516     1       운동     칭찬        이다빈 선수 2위 은메달도 간지나   2위 은메달
# 50353  1516     1       운동     칭찬        이다빈 선수 2등 은메달도 간지나   2등 은메달
# 50354  1516     1       운동     칭찬        이다빈 선수 올림픽 2등도 간지나   올림픽 2등
# 50355  1516     1       운동     칭찬           이다빈 선수 은메달도 간지나      은메달
# 50356  1516     1       운동     칭찬        이다빈 선수 올림픽 2위도 간지나   올림픽 2위
# 50357  1516     2       운동     칭찬            다빈선수 은메달도 멋지잖아      은메달
# 50358  1516     2       운동     칭찬         다빈선수 2위 은메달도 멋지잖아   2위 은메달
# 50359  1516     2       운동     칭찬         다빈선수 2등 은메달도 멋지잖아   2등 은메달
# 50360  1516     2       운동     칭찬         다빈선수 올림픽 2등도 멋지잖아   올림픽 2등
# 50361  1516     2       운동     칭찬        다빈선수 올림픽 은메달도 멋지잖아  올림픽 은메달
# 50362  1516     2       운동     칭찬         다빈선수 올림픽 2위도 멋지잖아   올림픽 2위
# 50363  1516     3       운동     칭찬       이다빈 선수 올림픽 2등도 본새난다   올림픽 2등
# 50364  1516     3       운동     칭찬       이다빈 선수 2위 은메달도 본새난다   2위 은메달
# 50365  1516     3       운동     칭찬       이다빈 선수 2등 은메달도 본새난다   2등 은메달
# 50366  1516     3       운동     칭찬          이다빈 선수 은메달도 본새난다      은메달
# 50367  1516     3       운동     칭찬      이다빈 선수 올림픽 은메달도 본새난다  올림픽 은메달
# 50368  1516     3       운동     칭찬       이다빈 선수 올림픽 2위도 본새난다   올림픽 2위
# 50369  1516     4       운동     칭찬      그 선수 2등 은메달도 대단하지 않냐   2등 은메달
# 50370  1516     4       운동     칭찬      그 선수 2위 은메달도 대단하지 않냐   2위 은메달
# 50371  1516     4       운동     칭찬      그 선수 올림픽 2등도 대단하지 않냐   올림픽 2등
# 50372  1516     4       운동     칭찬         그 선수 은메달도 대단하지 않냐      은메달
# 50373  1516     4       운동     칭찬     그 선수 올림픽 은메달도 대단하지 않냐  올림픽 은메달
# 50374  1516     4       운동     칭찬      그 선수 올림픽 2위도 대단하지 않냐   올림픽 2위
# 50375  1516     4       운동     칭찬   그 선수 2등 2위 은메달도 대단하지 않냐   2위 은메달
# 50376  1516     4       운동     칭찬   그 선수 2등 2등 은메달도 대단하지 않냐   2등 은메달
# 50377  1516     4       운동     칭찬   그 선수 2등 올림픽 2등도 대단하지 않냐   올림픽 2등
# 50378  1516     4       운동     칭찬  그 선수 2등 올림픽 은메달도 대단하지 않냐  올림픽 은메달
# 50379  1516     4       운동     칭찬   그 선수 2등 올림픽 2위도 대단하지 않냐   올림픽 2위
# 50380  1516     5       운동     칭찬     다빈 선수 올림픽 2위도 쩌는 거 같음   올림픽 2위
# 50381  1516     5       운동     칭찬     다빈 선수 2위 은메달도 쩌는 거 같음   2위 은메달
# 50382  1516     5       운동     칭찬     다빈 선수 2등 은메달도 쩌는 거 같음   2등 은메달
# 50383  1516     5       운동     칭찬     다빈 선수 올림픽 2등도 쩌는 거 같음   올림픽 2등
# 50384  1516     5       운동     칭찬        다빈 선수 은메달도 쩌는 거 같음      은메달
# 50385  1516     5       운동     칭찬    다빈 선수 올림픽 은메달도 쩌는 거 같음  올림픽 은메달
# 50386  1516     6       운동     칭찬        이다빈 선수 2위 은메달도 멋있어   2위 은메달
# 50387  1516     6       운동     칭찬        이다빈 선수 2등 은메달도 멋있어   2등 은메달
# 50388  1516     6       운동     칭찬        이다빈 선수 올림픽 2등도 멋있어   올림픽 2등
# 50389  1516     6       운동     칭찬           이다빈 선수 은메달도 멋있어      은메달
# 50390  1516     6       운동     칭찬       이다빈 선수 올림픽 은메달도 멋있어  올림픽 은메달
# 50391  1516     6       운동     칭찬        이다빈 선수 올림픽 2위도 멋있어   올림픽 2위
# 50392  1516     6       운동     칭찬     이다빈 선수 2위 2위 은메달도 멋있어   2위 은메달
# 50393  1516     6       운동     칭찬     이다빈 선수 2위 2등 은메달도 멋있어   2등 은메달
# 50394  1516     6       운동     칭찬     이다빈 선수 2위 올림픽 2등도 멋있어   올림픽 2등
# 50395  1516     6       운동     칭찬    이다빈 선수 2위 올림픽 은메달도 멋있어  올림픽 은메달
# 50396  1516     6       운동     칭찬     이다빈 선수 2위 올림픽 2위도 멋있어   올림픽 2위
#
#       arg_op2 label
# 50346            83
# 50347            83
# 50348            83
# 50349            83
# 50350            83
# 50351            83
# 50352            83
# 50353            83
# 50354            83
# 50355            83
# 50356            83
# 50357            83
# 50358            83
# 50359            83
# 50360            83
# 50361            83
# 50362            83
# 50363            83
# 50364            83
# 50365            83
# 50366            83
# 50367            83
# 50368            83
# 50369            83
# 50370            83
# 50371            83
# 50372            83
# 50373            83
# 50374            83
# 50375            83
# 50376            83
# 50377            83
# 50378            83
# 50379            83
# 50380            83
# 50381            83
# 50382            83
# 50383            83
# 50384            83
# 50385            83
# 50386            83
# 50387            83
# 50388            83
# 50389            83
# 50390            83
# 50391            83
# 50392            83
# 50393            83
# 50394            83
# 50395            83
# 50396            83

# %% [markdown]
# temp save

# %%
df.shape
# Out:
# (52802, 9)

# %%
# fm.save(cfg.aug_check, df)

# %%
df.label.value_counts().iloc[:30]
# Out:
# (label,)
# 18          1573
# 109         1388
# 107         1334
# 28          1057
# 143          964
# 46           917
# 133          758
# 127          724
# 94           711
# 41           694
# 101          675
# 42           663
# 120          648
# 142          616
# 81           587
# 31           584
# 67           577
# 75           576
# 0            575
# 89           568
# 50           560
# 63           557
# 48           551
# 16           543
# 17           540
# 33           527
# 66           521
# 100          521
# 78           515
# 47           515
# dtype: int64

# %%
df.label.value_counts().iloc[110:]
# Out:
# (label,)
# 128         185
# 91          182
# 84          180
# 130         179
# 69          179
# 58          178
# 111         177
# 10          172
# 113         171
# 90          169
# 99          166
# 119         155
# 14          155
# 115         152
# 88          151
# 40          145
# 102         142
# 70          139
# 129         138
# 93          135
# 43          134
# 76          133
# 24          133
# 45          132
# 108         132
# 55          127
# 37          124
# 136         106
# 87          104
# 5           100
# 23           97
# 7            86
# 132          66
# 148          57
# 83           51
# 112          49
# 56           42
# 79           42
# 11           37
# 35           33
# 86           31
# 77           30
# 30           28
# dtype: int64

# %%
fm.save('drive/MyDrive/MemeProject/data/report/증강_temp.xlsx', df)
# Out:
# Saved 45503 records

# %% [markdown]
# temp load

# %%
df = fm.load('drive/MyDrive/MemeProject/data/report/증강.xlsx')
# Out:
# extension : .xlsx
# Loaded 41667 records from drive/MyDrive/MemeProject/data/report/증강.xlsx

# %%
df.head()
# Out:
#   g_num u_num material speech                  u   arg   arg_op1 arg_op2 label
# 0  1525     6       경사     자랑  전국노래자랑에서 이모가 1등했다        전국노래자랑에서             9
# 1     1     1     학교생활     자랑    나 중간고사 반에서 1등했어  중간고사                     146
# 2     1     1     학교생활     자랑      나 중간 반에서 1등했어    중간                     146
# 3     1     1     학교생활     자랑      나 시험 반에서 1등했어    시험                     146
# 4     1     1     학교생활     자랑    나 중간시험 반에서 1등했어  중간시험                     146

# %%
df = df[['u', 'material', 'speech', 'label']]

# %%
df[df['label'].values==83]
# Out:
#                               u material speech label
# 50346       이다빈 선수 올림픽 은메달도 간지나       운동     칭찬    83
# 50347    이다빈 선수 올림픽 2위 은메달도 간지나       운동     칭찬    83
# 50348    이다빈 선수 올림픽 2등 은메달도 간지나       운동     칭찬    83
# 50349    이다빈 선수 올림픽 올림픽 2등도 간지나       운동     칭찬    83
# 50350   이다빈 선수 올림픽 올림픽 은메달도 간지나       운동     칭찬    83
# 50351    이다빈 선수 올림픽 올림픽 2위도 간지나       운동     칭찬    83
# 50352        이다빈 선수 2위 은메달도 간지나       운동     칭찬    83
# 50353        이다빈 선수 2등 은메달도 간지나       운동     칭찬    83
# 50354        이다빈 선수 올림픽 2등도 간지나       운동     칭찬    83
# 50355           이다빈 선수 은메달도 간지나       운동     칭찬    83
# 50356        이다빈 선수 올림픽 2위도 간지나       운동     칭찬    83
# 50357            다빈선수 은메달도 멋지잖아       운동     칭찬    83
# 50358         다빈선수 2위 은메달도 멋지잖아       운동     칭찬    83
# 50359         다빈선수 2등 은메달도 멋지잖아       운동     칭찬    83
# 50360         다빈선수 올림픽 2등도 멋지잖아       운동     칭찬    83
# 50361        다빈선수 올림픽 은메달도 멋지잖아       운동     칭찬    83
# 50362         다빈선수 올림픽 2위도 멋지잖아       운동     칭찬    83
# 50363       이다빈 선수 올림픽 2등도 본새난다       운동     칭찬    83
# 50364       이다빈 선수 2위 은메달도 본새난다       운동     칭찬    83
# 50365       이다빈 선수 2등 은메달도 본새난다       운동     칭찬    83
# 50366          이다빈 선수 은메달도 본새난다       운동     칭찬    83
# 50367      이다빈 선수 올림픽 은메달도 본새난다       운동     칭찬    83
# 50368       이다빈 선수 올림픽 2위도 본새난다       운동     칭찬    83
# 50369      그 선수 2등 은메달도 대단하지 않냐       운동     칭찬    83
# 50370      그 선수 2위 은메달도 대단하지 않냐       운동     칭찬    83
# 50371      그 선수 올림픽 2등도 대단하지 않냐       운동     칭찬    83
# 50372         그 선수 은메달도 대단하지 않냐       운동     칭찬    83
# 50373     그 선수 올림픽 은메달도 대단하지 않냐       운동     칭찬    83
# 50374      그 선수 올림픽 2위도 대단하지 않냐       운동     칭찬    83
# 50375   그 선수 2등 2위 은메달도 대단하지 않냐       운동     칭찬    83
# 50376   그 선수 2등 2등 은메달도 대단하지 않냐       운동     칭찬    83
# 50377   그 선수 2등 올림픽 2등도 대단하지 않냐       운동     칭찬    83
# 50378  그 선수 2등 올림픽 은메달도 대단하지 않냐       운동     칭찬    83
# 50379   그 선수 2등 올림픽 2위도 대단하지 않냐       운동     칭찬    83
# 50380     다빈 선수 올림픽 2위도 쩌는 거 같음       운동     칭찬    83
# 50381     다빈 선수 2위 은메달도 쩌는 거 같음       운동     칭찬    83
# 50382     다빈 선수 2등 은메달도 쩌는 거 같음       운동     칭찬    83
# 50383     다빈 선수 올림픽 2등도 쩌는 거 같음       운동     칭찬    83
# 50384        다빈 선수 은메달도 쩌는 거 같음       운동     칭찬    83
# 50385    다빈 선수 올림픽 은메달도 쩌는 거 같음       운동     칭찬    83
# 50386        이다빈 선수 2위 은메달도 멋있어       운동     칭찬    83
# 50387        이다빈 선수 2등 은메달도 멋있어       운동     칭찬    83
# 50388        이다빈 선수 올림픽 2등도 멋있어       운동     칭찬    83
# 50389           이다빈 선수 은메달도 멋있어       운동     칭찬    83
# 50390       이다빈 선수 올림픽 은메달도 멋있어       운동     칭찬    83
# 50391        이다빈 선수 올림픽 2위도 멋있어       운동     칭찬    83
# 50392     이다빈 선수 2위 2위 은메달도 멋있어       운동     칭찬    83
# 50393     이다빈 선수 2위 2등 은메달도 멋있어       운동     칭찬    83
# 50394     이다빈 선수 2위 올림픽 2등도 멋있어       운동     칭찬    83
# 50395    이다빈 선수 2위 올림픽 은메달도 멋있어       운동     칭찬    83
# 50396     이다빈 선수 2위 올림픽 2위도 멋있어       운동     칭찬    83

# %%
df.drop_duplicates(inplace=True)

# %%
df.tail()
# Out:
#                       u material speech label
# 52797        너 취향 좀 이상해       밈봇     실망   151
# 52798      니 취향 좀 괴랄한 듯       밈봇     실망   151
# 52799    야 너 취향이 좀 괴상하다       밈봇     실망   151
# 52800  야 니 취향 기괴한 거 아냐?       밈봇     실망   151
# 52801    너말야 취향 쫌 괴상망측해       밈봇     실망   151

# %%
df.shape
# Out:
# (51447, 4)

# %%
check = {f"{i[1]['material']}, {i[1]['speech']}, {i[1]['label']}": 0 for i in df.iterrows()}

# %%
for i in df.iterrows():
  check[f"{i[1]['material']}, {i[1]['speech']}, {i[1]['label']}"] += 1

# %%
temp = sorted(check.items(), key=lambda x: x[1], reverse=True)

# %%
print(temp)
# Out:
# [('기념일, 계획, 18', 1549), ('자기개발, 의지, 109', 1369), ('자기개발, 계획, 107', 1315), ('기후, 진술, 28', 1026), ('학교생활, 계획, 143', 924), ('미디어콘텐츠, 진술, 46', 908), ('취미, 의지, 133', 743), ('음료, 진술, 94', 704), ('직장생활, 의지, 127', 696), ('문화예술, 칭찬, 41', 689), ('음식, 칭찬, 101', 673), ('미디어콘텐츠, 계획, 42', 655), ('주거, 소망, 120', 625), ('패션, 칭찬, 142', 606), ('돈, 소망, 31', 573), ('운동, 자랑, 81', 568), ('여행, 소망, 67', 563), ('가정생활, 계획, 0', 563), ('유명인, 칭찬, 89', 562), ('연애, 자랑, 75', 561), ('쇼핑, 자랑, 63', 553), ('미용, 의지, 50', 540), ('교통, 진술, 16', 535), ('미용, 계획, 48', 534), ('교통, 칭찬, 17', 532), ('돈, 자랑, 33', 516), ('음식, 진술, 100', 512), ('미디어콘텐츠, 칭찬, 47', 510), ('운동, 계획, 78', 499), ('여행, 계획, 66', 498), ('경사, 자랑, 9', 497), ('밈봇, 명령, 150', 491), ('음료, 의지, 92', 488), ('전자기기, 칭찬, 118', 484), ('밈봇, 혐오, 152', 483), ('밈봇, 실망, 151', 480), ('밈봇, 만족, 149', 479), ('쇼핑, 진술, 64', 478), ('연애, 소망, 73', 464), ('교통, 계획, 12', 455), ('돈, 진술, 34', 450), ('미용, 자랑, 51', 443), ('취미, 진술, 135', 442), ('여행, 의지, 68', 441), ('경사, 의지, 8', 428), ('음식, 계획, 96', 415), ('패션, 의지, 139', 412), ('전자기기, 소망, 114', 409), ('반려동물, 칭찬, 59', 398), ('경사, 계획, 6', 397), ('연애, 의지, 74', 389), ('패션, 계획, 137', 384), ('문화예술, 계획, 36', 380), ('학교생활, 진술, 147', 377), ('인간관계, 의지, 103', 374), ('미용, 칭찬, 53', 373), ('학교생활, 의지, 145', 370), ('연애, 계획, 72', 368), ('운동, 의지, 80', 364), ('반려동물, 계획, 54', 362), ('학교생활, 소망, 144', 359), ('인간관계, 칭찬, 106', 358), ('전자기기, 진술, 117', 347), ('교통, 소망, 13', 332), ('취미, 계획, 131', 329), ('인간관계, 진술, 105', 324), ('가정생활, 진술, 4', 314), ('학교생활, 자랑, 146', 309), ('주거, 칭찬, 124', 309), ('미용, 진술, 52', 300), ('가정생활, 자랑, 3', 291), ('기념일, 의지, 20', 290), ('직장생활, 소망, 126', 284), ('운동, 진술, 82', 282), ('쇼핑, 의지, 62', 282), ('음식, 의지, 98', 276), ('돈, 의지, 32', 274), ('여행, 칭찬, 71', 273), ('반려동물, 자랑, 57', 269), ('기념일, 진술, 22', 269), ('쇼핑, 소망, 61', 269), ('음식, 소망, 97', 268), ('주거, 진술, 123', 266), ('기후, 의지, 26', 256), ('미디어콘텐츠, 의지, 44', 255), ('자기개발, 자랑, 110', 248), ('기념일, 소망, 19', 239), ('쇼핑, 칭찬, 65', 237), ('음료, 칭찬, 95', 233), ('인간관계, 자랑, 104', 232), ('문화예술, 의지, 38', 228), ('교통, 자랑, 15', 226), ('기념일, 자랑, 21', 226), ('전자기기, 자랑, 116', 225), ('쇼핑, 계획, 60', 224), ('직장생활, 계획, 125', 217), ('주거, 의지, 121', 211), ('유명인, 소망, 85', 211), ('기후, 자랑, 27', 202), ('가정생활, 의지, 2', 202), ('기후, 칭찬, 29', 199), ('문화예술, 자랑, 39', 198), ('취미, 자랑, 134', 191), ('패션, 소망, 138', 191), ('패션, 진술, 141', 187), ('패션, 자랑, 140', 185), ('기후, 소망, 25', 183), ('가정생활, 소망, 1', 182), ('주거, 자랑, 122', 182), ('직장생활, 자랑, 128', 181), ('음료, 소망, 91', 180), ('미용, 소망, 49', 179), ('유명인, 계획, 84', 178), ('직장생활, 칭찬, 130', 178), ('반려동물, 진술, 58', 177), ('자기개발, 진술, 111', 174), ('전자기기, 계획, 113', 169), ('경사, 진술, 10', 165), ('여행, 자랑, 69', 164), ('음료, 계획, 90', 163), ('음식, 자랑, 99', 163), ('유명인, 진술, 88', 150), ('전자기기, 의지, 115', 150), ('주거, 계획, 119', 145), ('인간관계, 소망, 102', 142), ('문화예술, 진술, 40', 142), ('교통, 의지, 14', 139), ('직장생활, 진술, 129', 136), ('여행, 진술, 70', 135), ('기후, 계획, 24', 132), ('연애, 진술, 76', 132), ('미디어콘텐츠, 자랑, 45', 131), ('자기개발, 소망, 108', 129), ('음료, 자랑, 93', 128), ('미디어콘텐츠, 소망, 43', 126), ('반려동물, 소망, 55', 124), ('문화예술, 소망, 37', 114), ('취미, 칭찬, 136', 105), ('유명인, 자랑, 87', 95), ('기념일, 칭찬, 23', 94), ('경사, 소망, 7', 83), ('가정생활, 칭찬, 5', 75), ('학교생활, 칭찬, 148', 56), ('취미, 소망, 132', 56), ('운동, 칭찬, 83', 51), ('자기개발, 칭찬, 112', 48), ('반려동물, 의지, 56', 42), ('운동, 소망, 79', 40), ('경사, 칭찬, 11', 36), ('돈, 칭찬, 35', 33), ('연애, 칭찬, 77', 30), ('유명인, 의지, 86', 30), ('돈, 계획, 30', 27)]

# %%
temp_check = pd.DataFrame(temp, columns=['label', '건수'])

# %%
temp_check['대화소재'] = temp_check.label.apply(lambda x: x.split(',')[0])
temp_check['화행'] = temp_check.label.apply(lambda x: x.split(',')[1])
temp_check['레이블'] = temp_check.label.apply(lambda x: x.split(',')[2])

# %%
temp_check = temp_check[['대화소재', '화행', '레이블', '건수']]

# %%
fm.save('drive/MyDrive/MemeProject/data/report/count.xlsx', temp_check)
# Out:
# Saved 153 records

# %%
df[df.label.values==101]
# Out:
#                           u material speech label
# 356       이번에 개업한 삼겹살집 맛있더라       음식     칭찬   101
# 357       새로 생긴 삼겹살 가게 맛있더라       음식     칭찬   101
# 358    얼마 전에 오픈한 정육 식당 맛있더라       음식     칭찬   101
# 359         최근에 생긴 고깃집 맛있더라       음식     칭찬   101
# 360              그 고깃집 맛있더라       음식     칭찬   101
# ...                     ...      ...    ...   ...
# 44325      집앞 족발가게 정말 존맛탱이야       음식     칭찬   101
# 44326     집앞 족발가게 찐으로 존맛탱이야       음식     칭찬   101
# 44327      집앞 족발가게 완전 존맛탱이야       음식     칭찬   101
# 44328      집앞 족발가게 진짜 존맛탱이야       음식     칭찬   101
# 44329      집앞 족발가게 레알 존맛탱이야       음식     칭찬   101
#
# [673 rows x 4 columns]

# %% [markdown]
# ##### Save

# %%
fm.save(cfg.arg_aug_data, df)
# Out:
# Saved 20462 records

# %% [markdown]
# # Korean SmileStyle Dataset Train

# %% [markdown]
# ##### Text Style Trans Model

# %%
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
    DataCollatorForSeq2Seq,
)
from tokenizers import Tokenizer
from typing import Dict, List, Optional
from torch.utils.data import Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from IPython.display import display
from typing import Dict

# %%
df = pd.read_csv("smilestyle_dataset.tsv", sep="\t")
display(df.head())
display(df.isna().mean())
display(df.describe())
print(df.shape)
# Out:
#                         formal                    informal  \
# 0       안녕하세요. 저는 고양이 6마리 키워요.          안녕! 나는 고양이 6마리 키워.
# 1     고양이를 6마리나요? 키우는거 안 힘드세요?      고양이를 6마리나? 키우는거 안 힘들어?
# 2  제가 워낙 고양이를 좋아해서 크게 힘들진 않아요.  내가 워낙 고양이를 좋아해서 크게 힘들진 않아.
# 3       가장 나이가 많은 고양이가 어떻게 돼요?       가장 나이가 많은 고양이가 몇 살이야?
# 4           여섯 살입니다. 갈색 고양이에요.            여섯 살이야. 갈색 고양이지.
#
#                            android                                   azae  \
# 0  휴먼. 반갑다. 안드로이드는. 고양이. 6마리. 소유중.  아이고 안녕하십니까~ 나는 그냥 고양이 6마리 키우고 있는 사람이여
# 1             고양이. 6마리. 양육. 번거로운가.        아니 무슨 고양이를 6마리나? 거 키우는 거 안 힘든가?
# 2         안드로이드. 고양이. 선호. 힘들지. 않음.        내가 또 워~낙에 고양이를 좋아해서 크게 뭐 힘들진 않고
# 3           제일. 나이많은. 고양이. 나이. 무엇.                그려 가장 나이가 많은 고양이가 몇살이여?
# 4                    고양이. 갈색. 여섯살.                        6살인데 갈색 고양이 있어~
#
#                      chat                 choding  \
# 0     하잉ㅋㅋ 나 떼걸룩 6마리 키운다!      ㅎㅇ 나 주인님 6마리 모심 ㅋㅋ
# 1       엥? 6마리나? 안힘듬?ㅋㅋㅋㅋ        6마리? 에바아니냐 안 힘듦?
# 2  내가 고양이 좋아해서 딱히 안힘듬 ㅋㅋㅋ  ㄱㅊ 나 고양이 환장해서 힘든 것도 모름
# 3     가장 나이 먹은 고양이가 몇살이야?         젤 낡은 고영희가 몇 살임?
# 4        이제 여섯살이고 갈색고양이임!                 6살, 갈색임
#
#                                   emoticon  \
# 0        안녕!! >< 나는 고양이😺를 ➏ 마리 키우고있어!! 0_0
# 1  고양이를 6마리나?!! w(ﾟДﾟ)w 키우는거 안 힘듬?? (⊙_⊙;)
# 2    뭐 나야 워낙에 고양이 좋아하니까 딱히 안힘드엉! \(@^0^@)/
# 3             가장 나이 먹은 고양인 몇 살이양? (´･ω･`)?
# 4           여설 살!! ㄱ^o^/ 색깔은 갈색! O(*￣▽￣*)ブ
#
#                                        enfp                        gentle  \
# 0           안녕안녕~! 나 고양이 6마리나 키운다? 완전 대박이징~     안녕하십니까,, 저는 고양이 6마리 키웁니다.
# 1           고양이를 6마리나? 완전 대박~ 키우는 거 안 힘들어?!     고양이를 6마리나 키우십니까? 안 힘드신지,,
# 2  내가 또 워~낙에 고양이를 좋아하잖아~ 그렇게 크~게 힘들진 않아 ㅎㅎ~  제가 워낙 고양이를 좋아해서 크게 힘들진 않습니다.
# 3    대박대박 완전 대박!! 그럼 제~일 나이 많은 고양이는 몇살이야~?!         가장 나이가 있는 고양이가 몇살입니까?
# 4     6살인 애 있는데, 완전 귀.여.워. 갈색 고양이야 진짜 대박이지?              6살된 갈색 아이가 있습니다.
#
#                                 halbae                       halmae  \
# 0      안녕하신가~... 난 지금 고양이를 6마리 키우고 있다네  하유 시벌것 괭이놈 6마리 키우는데 힘들어 죽겟네
# 1             고양이를 6마리나? 키우는거 힘들지 않는가?      니기럴 털만 날리는 거 키우기 안 힘들데?
# 2  내가 워낙에...고양이가 좋아가지고 그렇게 힘들지 않어...^^         옘병 내가 좋아하니까 키워야지 시벌것
# 3        고양이들 중에서…가장 나이 먹을 애가 몇살인가?...     거 젤 빨리 뒤질 놈이 나이 얼마나 쳐먹었냐
# 4                  저…갈색 고양이인데…여섯살이지~..   저 노망난 갈색놈이 6살 뒤룩뒤룩 쳐먹은 놈이여
#
#                    joongding                         king  \
# 0  안녕하냐 ㅡㅡ 나 씹냥이 6마리나 키운다 하;       반갑소. 짐은 고양이를 6마리나 키우오.
# 1        아니 고양이를 6마리나? 안힘드냐?    고양이를 6마리나? 키우는게 수고스럽진 않소?
# 2      고양이 좋아한다고ㅡㅡ 1도 안힘듬 ㅡㅡ  과인은 고양이를 어여삐 어겨 그리 수고스럽진 않소
# 3               가장 늙은애가 몇살인데        최고령 고양이의 나이는 어떻게 되는가?
# 4                여섯살 갈색냥인데 왜             여섯 살이오. 갈색 고양이오.
#
#                          naruto                            seonbi  \
# 0   안녕하냐니깐! 난 고양이를 6마리 키우고있다니깐!       안녕하시오! 소인은 고양이를 6마리 키우고 있소!
# 1     고양이를 6마리나? 키우는거 힘들지 않냐니깐?     고양이를 6마리나 키우고 있는 것이오? 힘들지 않소?
# 2  내가 고양이를 엄청 좋아해서 별로 힘들지 않다니깐!  소인 고양이를 엄청 좋아하기 때문에 별로 힘들지 않소이다.
# 3   가장 나이 많이 먹은 고양이가 몇 살 이냐니깐?!          나이를 가장 많이 먹은 고양이가 몇 살이오?
# 4              갈색 고양이가 여섯살이라니깐!                     여섯 살에 갈색 고양이오
#
#                                  sosim                     translator
# 0                  안녕… 난 고양이 6마리 키워 ㅠㅠ     반가운. 나는 6마리의 고양이를 소지하고 있다.
# 1         고양이..6마리나? ㅠ 키우는건 혹시 안힘들어..?  6마리의 고양이? 당신은 그들로부터 지치지 않습니까?
# 2  내가 고양이 워낙 좋아해서..ㅠㅠ 크게 힘들진 않은 것 같아..        나는 고양이의 큰 애호가. 지치지 않는다.
# 3        혹시.. 제일 나이 많은 고양이는.. 몇살이야..?ㅠ             가장 늙은 고양이가 몇 년입니까?
# 4                여섯살이야.. 갈색 ㅠㅠ 고양이야..ㅠ                 여섯. 고양이는 갈색이다.
# formal        0.063428
# informal      0.063428
# android       0.520918
# azae          0.723347
# chat          0.063428
# choding       0.063428
# emoticon      0.514980
# enfp          0.544130
# gentle        0.540351
# halbae        0.515789
# halmae        0.726586
# joongding     0.063428
# king          0.520918
# naruto        0.514980
# seonbi        0.514980
# sosim         0.520918
# translator    0.594062
# dtype: float64
#         formal informal android                                   azae  chat  \
# count     3470     3470    1775                                   1025  3470
# unique    3430     3417    1748                                   1025  3437
# top     안녕하세요.      안녕.    반갑다.  아이고 안녕하십니까~ 나는 그냥 고양이 6마리 키우고 있는 사람이여    하이
# freq        23       25      10                                      1    13
#
#        choding      emoticon  enfp  gentle  halbae halmae joongding  king  \
# count     3470          1797  1689    1703    1794   1013      3470  1775
# unique    3390          1793  1679    1691    1784   1005      3396  1759
# top         왜?  안녕! (ﾉ*･ω･)ﾉ   안뇽~  안녕하십니까  안녕하신가…  왜 땜시?        ㅎㅇ  반갑소.
# freq        37             3     6       5       8      4        29     7
#
#          naruto  seonbi sosim translator
# count      1797    1797  1775       1504
# unique     1779    1784  1758       1489
# top     안녕하냐니깐!  안녕하시오!  안녕..       반가운.
# freq          9       9     9          9
# (3705, 17)

# %% [markdown]
# 2개 이상의 열이 NaN이 아니어야 하는데, 이 조건을 만족하지 못하는 row를 찾아내서 제외한다. 3475행이 3470행으로 바뀌었다.

# %%
row_notna_count = df.notna().sum(axis=1)
row_notna_count.plot.hist(bins=row_notna_count.max())
plt.show()

df = df[row_notna_count >= 2]
print(len(df))
# Out:
# 3470

# %%
model_name = "gogamza/kobart-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/682k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/4.00 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
lengths = []

for column in df.columns:
  out = tokenizer(df[column][df[column].notna()].tolist())
  out = [len(x) for x in out['input_ids']]
  lengths.extend(out)

lengths = pd.Series(lengths)
display(lengths.describe())
lengths.plot.hist(bins=80)
# Out:
# count    36793.000000
# mean        13.147582
# std          6.909344
# min          1.000000
# 25%          8.000000
# 50%         12.000000
# 75%         17.000000
# max        318.000000
# dtype: float64

# %% [markdown]
# 대부분 토큰의 길이가 50 이하

# %% [markdown]
# ##### Dataset Class 만들기

# %%
style_map = {
    'formal': '문어체',
    'informal': '구어체',
    'android': '안드로이드',
    'azae': '아재',
    'chat': '채팅',
    'choding': '초등학생',
    'emoticon': '이모티콘',
    'enfp': 'enfp',
    'gentle': '신사',
    'halbae': '할아버지',
    'halmae': '할머니',
    'joongding': '중학생',
    'king': '왕',
    'naruto': '나루토',
    'seonbi': '선비',
    'sosim': '소심한',
    'translator': '번역기'
}

# %%
class TextStyleTransferDataset(Dataset):
  def __init__(self, 
               df: pd.DataFrame, 
               tokenizer: Tokenizer
               ):
    self.df = df
    self.tokenizer = tokenizer
    
  def __len__(self):
    return len(self.df)

  def __getitem__(self, index):
    row = self.df.iloc[index, :].dropna().sample(2)
    text1 = row[0]
    text2 = row[1]
    target_style = row.index[1]
    target_style_name = style_map[target_style]

    encoder_text = f"{target_style_name} 말투 : {text1}"
    decoder_text = f"{text2}{self.tokenizer.eos_token}"
    model_inputs = self.tokenizer(encoder_text, max_length=64, truncation=True)

    with self.tokenizer.as_target_tokenizer():
      labels = tokenizer(decoder_text, max_length=64, truncation=True)
    model_inputs['labels'] = labels['input_ids']
    del model_inputs['token_type_ids']

    return model_inputs

# %%
dataset = TextStyleTransferDataset(df, tokenizer)
out = dataset[0]
print(out['input_ids'])
print(out['labels'])
print(tokenizer.decode(out['input_ids']))
print(tokenizer.decode(out['labels']))

out = dataset[1]
print(out['input_ids'])
print(out['labels'])
print(tokenizer.decode(out['input_ids']))
print(tokenizer.decode(out['labels']))
# Out:
# [26988, 14070, 13282, 14987, 14042, 12053, 1223, 1223, 14054, 18646, 9036, 10397, 14195, 26832, 14947, 11914, 9754, 232]
# [27616, 11478, 14495, 243, 243, 16530, 17849, 12034, 14195, 26832, 14947, 11922, 14562, 1]
# 신사 말투 : 하잉ᄏᄏ 나 떼걸룩 6마리 키운다!
# 안녕하십니까,, 저는 고양이 6마리 키웁니다.</s>
# [17802, 14070, 13282, 14987, 17849, 15188, 14195, 10496, 24665, 22679, 11478, 27879, 14105, 14452, 9989, 11467, 15248, 243]
# [16513, 9264, 10285, 16973, 10500, 14456, 14298, 14118, 22679, 9264, 14105, 15994, 9828, 262, 1]
# 할머니 말투 : 고양이를 6마리나 키우십니까? 안 힘드신지,,
# 니기럴 털만 날리는 거 키우기 안 힘들데?</s>

# %%
from sklearn.model_selection import train_test_split

# train, test set
df_train, df_test = train_test_split(df, test_size=0.1, random_state=42)
print(len(df_train), len(df_test))
# Out:
# 3123 347

# %%
train_dataset = TextStyleTransferDataset(
    df_train,
    tokenizer
)
test_dataset = TextStyleTransferDataset(
    df_test,
    tokenizer
)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer, model=model
)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/496M [00:00<?, ?B/s]

# %%
model_path = "/content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/"

training_args = Seq2SeqTrainingArguments(
    output_dir=model_path, #The output directory
    overwrite_output_dir=True, #overwrite the content of the output directory
    num_train_epochs=24, # number of training epochs
    per_device_train_batch_size=16, # batch size for training
    per_device_eval_batch_size=16,  # batch size for evaluation
    eval_steps=500, # Number of update steps between two evaluations.
    save_steps=1000, # after # steps model is saved 
    warmup_steps=300,# number of warmup steps for learning rate scheduler
    prediction_loss_only=True,
    evaluation_strategy="steps",
    save_total_limit=3
    )

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 3123
#   Num Epochs = 24
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 4704
#   Number of trainable parameters = 123859968
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='4704' max='4704' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4704/4704 07:23, Epoch 24/24]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.676000</td>
#       <td>1.798954</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.634400</td>
#       <td>1.672204</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.375300</td>
#       <td>1.485984</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.259600</td>
#       <td>1.607790</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.139800</td>
#       <td>1.443281</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.061300</td>
#       <td>1.481546</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.004700</td>
#       <td>1.522701</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.965400</td>
#       <td>1.390216</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.924200</td>
#       <td>1.569652</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 347
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 347
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-1000
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-1000/config.json
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-1000/generation_config.json
# Model weights saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-1000/pytorch_model.bin
# /usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:3581: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 347
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 347
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-2000/config.json
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-2000/generation_config.json
# Model weights saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-2000/pytorch_model.bin
# /usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:3581: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 347
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 347
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-3000/config.json
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-3000/generation_config.json
# Model weights saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-3000/pytorch_model.bin
# /usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:3581: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 347
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 347
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-4000
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-4000/config.json
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-4000/generation_config.json
# Model weights saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-4000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/checkpoint-1000] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:3581: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 347
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=4704, training_loss=1.3184637504370034, metrics={'train_runtime': 446.9373, 'train_samples_per_second': 167.701, 'train_steps_per_second': 10.525, 'total_flos': 1399897745326080.0, 'train_loss': 1.3184637504370034, 'epoch': 24.0})

# %%
trainer.save_model()
# Out:
# Saving model checkpoint to /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/config.json
# Configuration saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/generation_config.json
# Model weights saved in /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/pytorch_model.bin

# %% [markdown]
# ##### Pipeline을 이용해서 학습한 모델로 텍스트 생성해보기

# %%
from transformers import pipeline

nlg_pipeline = pipeline('text2text-generation', model=model_path, tokenizer=model_name)
# Out:
# loading configuration file /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/config.json
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Model config BartConfig {
#   "_name_or_path": "/content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "author": "Heewon Jeon(madjakarta@gmail.com)",
#   "bos_token_id": 1,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.1,
#   "d_model": 768,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 1,
#   "do_blenderbot_90_layernorm": false,
#   "dropout": 0.1,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 1,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": false,
#   "forced_eos_token_id": 1,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "kobart_version": 2.0,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "max_position_embeddings": 1026,
#   "model_type": "bart",
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_hidden_layers": 6,
#   "pad_token_id": 3,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "tokenizer_class": "PreTrainedTokenizerFast",
#   "torch_dtype": "float32",
#   "transformers_version": "4.26.1",
#   "use_cache": true,
#   "vocab_size": 30000
# }
#
# loading configuration file /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/config.json
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Model config BartConfig {
#   "_name_or_path": "/content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "author": "Heewon Jeon(madjakarta@gmail.com)",
#   "bos_token_id": 1,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.1,
#   "d_model": 768,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 1,
#   "do_blenderbot_90_layernorm": false,
#   "dropout": 0.1,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 1,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": false,
#   "forced_eos_token_id": 1,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "kobart_version": 2.0,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "max_position_embeddings": 1026,
#   "model_type": "bart",
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_hidden_layers": 6,
#   "pad_token_id": 3,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "tokenizer_class": "PreTrainedTokenizerFast",
#   "torch_dtype": "float32",
#   "transformers_version": "4.26.1",
#   "use_cache": true,
#   "vocab_size": 30000
# }
#
# loading weights file /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/pytorch_model.bin
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# All model checkpoint weights were used when initializing BartForConditionalGeneration.
#
# All the weights of BartForConditionalGeneration were initialized from the model checkpoint at /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BartForConditionalGeneration for predictions without further training.
# loading configuration file /content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/generation_config.json
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--gogamza--kobart-base-v2/snapshots/f9f2ec35d3c32a1ecc7a3281f9626b7ec1913fed/config.json
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Model config BartConfig {
#   "_name_or_path": "gogamza/kobart-base-v2",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.0,
#   "author": "Heewon Jeon(madjakarta@gmail.com)",
#   "bos_token_id": 1,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.1,
#   "d_model": 768,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 1,
#   "do_blenderbot_90_layernorm": false,
#   "dropout": 0.1,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 1,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": false,
#   "forced_eos_token_id": 1,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "kobart_version": 2.0,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "max_position_embeddings": 1026,
#   "model_type": "bart",
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_hidden_layers": 6,
#   "pad_token_id": 3,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "tokenizer_class": "PreTrainedTokenizerFast",
#   "transformers_version": "4.26.1",
#   "use_cache": true,
#   "vocab_size": 30000
# }
#
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--gogamza--kobart-base-v2/snapshots/f9f2ec35d3c32a1ecc7a3281f9626b7ec1913fed/tokenizer.json
# loading file added_tokens.json from cache at /root/.cache/huggingface/hub/models--gogamza--kobart-base-v2/snapshots/f9f2ec35d3c32a1ecc7a3281f9626b7ec1913fed/added_tokens.json
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--gogamza--kobart-base-v2/snapshots/f9f2ec35d3c32a1ecc7a3281f9626b7ec1913fed/special_tokens_map.json
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--gogamza--kobart-base-v2/snapshots/f9f2ec35d3c32a1ecc7a3281f9626b7ec1913fed/config.json
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Model config BartConfig {
#   "_name_or_path": "gogamza/kobart-base-v2",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.0,
#   "author": "Heewon Jeon(madjakarta@gmail.com)",
#   "bos_token_id": 1,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.1,
#   "d_model": 768,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 1,
#   "do_blenderbot_90_layernorm": false,
#   "dropout": 0.1,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 1,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": false,
#   "forced_eos_token_id": 1,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "kobart_version": 2.0,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "max_position_embeddings": 1026,
#   "model_type": "bart",
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_hidden_layers": 6,
#   "pad_token_id": 3,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "tokenizer_class": "PreTrainedTokenizerFast",
#   "transformers_version": "4.26.1",
#   "use_cache": true,
#   "vocab_size": 30000
# }

# %%
def generate_text(pipe, text, target_style, num_return_sequences=5, max_length=60):
  target_style_name = style_map[target_style]
  text = f"{target_style_name} 말투 : {text}"
  out = pipe(text, num_return_sequences=num_return_sequences, max_length=max_length)
  return [x['generated_text'] for x in out]

# %%
src_text = "어제 먹은 밥이 너무 맛있었어"

print("입력 문장:", src_text)

for style in df.columns:
  print(style, generate_text(nlg_pipeline, src_text, style, num_return_sequences=1, max_length=1000)[0])
# Out:
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
# 입력 문장: 어제 먹은 밥이 너무 맛있었어
# formal 어제 먹은 밥이 너무 맛있었어요.
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
# informal 어제 먹은 밥이 너무 맛있었어.
# android 어제. 밥. 맛있음.
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
# azae 어제 먹은 밥이 넘 맛있었어~
# chat 어제 먹은 밥이 너무 맛있었음 ᄏᄏᄏᄏᄏ
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
# choding 어제 먹은 밥이 넘 맛있었음
# emoticon 어제 먹은 밥이 너무 맛있었어 (゚▽゚)ノ
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
# enfp 어제 먹은 밥이 넘 맛있었엉 ᄒᄒ
# gentle 어제 먹은 밥이 너무 맛있었습니다.
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
# halbae 어제 먹은 밥이 너무 맛있었구먼...
# halmae 어제 먹은 밥이 넘 맛있었어
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
# joongding 어제 먹은 밥이 너무 맛있었음
# king 어제 먹은 밥이 너무 맛있었소.
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
# naruto 어제 먹은 밥이 너무 맛있었다니깐!
# seonbi 어제 먹은 밥이 너무 맛있었소!
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "decoder_start_token_id": 1,
#   "eos_token_id": 1,
#   "forced_eos_token_id": 1,
#   "pad_token_id": 3,
#   "transformers_version": "4.26.1"
# }
# sosim 어제 먹은 밥이 너무 맛있었어..
# translator 어제 먹은 밥은 너무 맛있었다.

# %% [markdown]
# # Text Style Transfer

# %% [markdown]
# ##### 평균 미만 데이터 증강
# ##### data split by average

# %%
import sys
sys.path.append('/content/drive/MyDrive/MemeProject/src/pytorch/preprocessing')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/MemeProject/src/pytorch/preprocessing']

# %%
from tqdm import tqdm
import config as cfg
import pandas as pd
import numpy as np
import swifter
from pshmodule.utils import filemanager as fm

# %%
df_arg = fm.load(cfg.arg_aug_data)
# Out:
# extension : .pickle
# Loaded 20462 records from drive/MyDrive/MemeProject/data/augmentation/arg_aug.pickle

# %%
df_arg.label.describe()
# Out:
#               label
# count  20462.000000
# mean      82.362917
# std       46.729405
# min        0.000000
# 25%       42.000000
# 50%       85.000000
# 75%      124.000000
# max      152.000000

# %%
label_count = {i[1]['label']: 0 for i in df_arg.iterrows()}

for i in df_arg.iterrows():
  label_count[i[1]['label']] += 1

label_count = {k: v for k, v in sorted(label_count.items(), key=lambda x: x[1], reverse=True)}

# %% [markdown]
# 82 이상

# %%
label_count_82_upper = {i[0]: i[1] for i in label_count.items() if i[1] >= 82}

# %%
label_count_82_upper.keys()
# Out:
# dict_keys([150, 152, 151, 149, 9, 109, 89, 142, 33, 101, 47, 41, 107, 120, 28, 133, 46, 143, 63, 18, 50, 92, 3, 57, 12, 13, 0, 118, 80, 59, 78, 127, 67, 75, 116, 73, 31, 96, 106, 144, 66, 81, 117, 135, 32, 64, 61, 95, 100, 91, 104, 128, 146, 42, 36, 48, 138, 147, 126, 58, 98, 85, 139, 68, 103, 94, 97, 53, 114, 17, 39, 145, 34, 10, 60, 21, 121, 16, 105, 137, 140, 131, 51, 25, 129, 45, 2, 14, 15, 102, 134, 52, 1, 72, 4, 37, 62, 74, 141, 115, 6])

# %%
arg_upper = [[i[1]['g_num'], i[1]['u_num'], i[1]['material'], i[1]['speech'], i[1]['u'], i[1]['arg'], i[1]['label']] for i in df_arg.iterrows() if i[1]['label'] in label_count_82_upper.keys()]

# %%
df_arg_upper = pd.DataFrame(arg_upper, columns=[['g_num', 'u_num', 'material', 'speech', 'u', 'arg', 'label']])

# %%
df_arg_upper.shape
# Out:
# (17756, 7)

# %% [markdown]
# 82 미만

# %%
label_count_82_under = {i[0]: i[1] for i in label_count.items() if i[1] < 82}

# %%
label_count_82_under.keys()
# Out:
# dict_keys([87, 19, 136, 99, 54, 8, 20, 124, 49, 43, 27, 122, 71, 110, 65, 82, 108, 23, 40, 29, 26, 119, 125, 123, 70, 88, 44, 130, 93, 69, 84, 5, 38, 55, 113, 7, 22, 90, 79, 148, 76, 35, 132, 111, 11, 77, 86, 24, 56, 30, 112, 83])

# %%
arg_under = [[i[1]['g_num'], i[1]['u_num'], i[1]['material'], i[1]['speech'], i[1]['u'], i[1]['arg'], i[1]['label']] for i in df_arg.iterrows() if i[1]['label'] in label_count_82_under.keys()]

# %%
df_arg_under = pd.DataFrame(arg_under, columns=[['g_num', 'u_num', 'material', 'speech', 'u', 'arg', 'label']])

# %%
df_arg_under.shape
# Out:
# (2706, 7)

# %% [markdown]
# ##### 문체 생성

# %%
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
    DataCollatorForSeq2Seq,
    pipeline,
)
from tokenizers import Tokenizer
from typing import Dict, List, Optional
from torch.utils.data import Dataset

import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt


from IPython.display import display
from typing import Dict

# %%
model_path = "/content/drive/MyDrive/MemeProject/model/pytorch/text-transfer-smilegate-bart-eos/"
model_name = "gogamza/kobart-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/682k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/4.00 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
nlg_pipeline = pipeline('text2text-generation', model=model_path, tokenizer=model_name)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
style_map = {
    'formal': '문어체',
    'informal': '구어체',
    'android': '안드로이드',
    'azae': '아재',
    'chat': '채팅',
    'choding': '초등학생',
    'emoticon': '이모티콘',
    'enfp': 'enfp',
    'gentle': '신사',
    'halbae': '할아버지',
    'halmae': '할머니',
    'joongding': '중학생',
    'king': '왕',
    'naruto': '나루토',
    'seonbi': '선비',
    'sosim': '소심한',
    'translator': '번역기'
}

def generate_text(pipe, text, target_style, num_return_sequences=5, max_length=60):
  target_style_name = style_map[target_style]
  text = f"{target_style_name} 말투 : {text}"
  out = pipe(text, num_return_sequences=num_return_sequences, max_length=max_length)
  return [x['generated_text'] for x in out]

# %%
df = pd.read_csv("smilestyle_dataset.tsv", sep="\t")
row_notna_count = df.notna().sum(axis=1)
row_notna_count.plot.hist(bins=row_notna_count.max())

df = df[row_notna_count >= 2]

# %%
df_arg_under.head()
# Out:
#   g_num u_num material speech                      u arg label
# 0    19     1       미용     소망  나 올 여름엔 비키니 잘 어울리고 싶어        49
# 1    19     2       미용     소망       나도 비키니 잘 소화하고 싶어        49
# 2    19     3       미용     소망     여름에 비키니 소화해 보고 싶어!        49
# 3    19     4       미용     소망      나도 비키니 잘 어울리면 좋겠다        49
# 4    19     5       미용     소망       나도 비키니 소화 잘하고 싶어        49

# %%
print(df_arg_upper.shape)
print(df_arg_under.shape)
# Out:
# (17756, 7)
# (2706, 7)

# %%
df_transform = []

for i in tqdm(df_arg_under.iterrows()):
  print(" ")
  print(f"입력 문장 : {i[1]['u']}")
  for style in df.columns:
    print(style, generate_text(nlg_pipeline, i, style, num_return_sequences=1, max_length=1000)[0])
    df_transform.append([i[1]['g_num'], i[1]['u_num'], i[1]['material'], i[1]['speech'], generate_text(nlg_pipeline, i[1]['u'], style, num_return_sequences=1, max_length=1000)[0], style, i[1]['arg'], i[1]['label']])

# %%
pd.DataFrame(df_transform, columns=[['g_num', 'u_num', 'material', 'speech', 'u', 'style', 'arg', 'label']])

# %%
# src_text = "나 오늘 밤새 밖에서 놀 거야"
# print("입력 문장:", src_text)

# for style in df.columns:
#   print(style, generate_text(nlg_pipeline, src_text, style, num_return_sequences=1, max_length=1000)[0])
# Out:
# 입력 문장: 나 오늘 밤새 밖에서 놀 거야
# formal 저는 오늘 밤새 밖에서 놀고 있습니다.
# informal 나는 오늘 밤새 밖에서 놀 거야.
# android 안드로이드. 오늘. 밤. 밖. 놀 것.
# azae 오늘 밤새 밖에서 놀거야~
# chat 난 오늘 밤새 밖에서 놀거임
# choding 오늘 밤새 밖에서 놀거임
# emoticon 난 오늘 밤새 밖에서 놀 거야 (★‿★)
# enfp 웅웅! 오늘 밤엔 밖에서 놀거!!
# gentle 저는 오늘 밤새 밖에서 놀고 있습니다.
# halbae 나는......오늘 밤은...자주 밖에서 놀 것이구먼...
# halmae 오늘 밤새 밖에서 놀것네
# joongding 난 오늘새에 놀거임
# king 짐은 오늘 밤에는 밖에서 놀겠소.
# naruto 난 오늘새에 밤새 밖에서 놀고 있다니깐!
# seonbi 소생은 오늘 밤새 밖에서 놀 것이오!
# sosim 난 오늘새에 밤새 밖에서 놀거야..
# translator 나는 오늘 밤 늦게까지 밖에서 놀 예정이다.

# %% [markdown]
# # Transform

# %%
import sys
sys.path.append('/content/drive/MyDrive/MemeProject/src/pytorch/augmentation')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/MemeProject/src/pytorch/augmentation']

# %%
import config as cfg
import csv
import pandas as pd
import json

# %%
df = pd.read_csv(cfg.datasets, sep='\t')

# %%
df.shape
# Out:
# (3705, 17)

# %%
# 2 미만 제외
row_notna_count = df.notna().sum(axis=1)
row_notna_count.plot.hist(bins=row_notna_count.max())
df = df[row_notna_count >= 2]

# %%
df.shape
# Out:
# (3470, 17)

# %%
df.head()
# Out:
#                         formal                    informal  \
# 0       안녕하세요. 저는 고양이 6마리 키워요.          안녕! 나는 고양이 6마리 키워.
# 1     고양이를 6마리나요? 키우는거 안 힘드세요?      고양이를 6마리나? 키우는거 안 힘들어?
# 2  제가 워낙 고양이를 좋아해서 크게 힘들진 않아요.  내가 워낙 고양이를 좋아해서 크게 힘들진 않아.
# 3       가장 나이가 많은 고양이가 어떻게 돼요?       가장 나이가 많은 고양이가 몇 살이야?
# 4           여섯 살입니다. 갈색 고양이에요.            여섯 살이야. 갈색 고양이지.
#
#                            android                                   azae  \
# 0  휴먼. 반갑다. 안드로이드는. 고양이. 6마리. 소유중.  아이고 안녕하십니까~ 나는 그냥 고양이 6마리 키우고 있는 사람이여
# 1             고양이. 6마리. 양육. 번거로운가.        아니 무슨 고양이를 6마리나? 거 키우는 거 안 힘든가?
# 2         안드로이드. 고양이. 선호. 힘들지. 않음.        내가 또 워~낙에 고양이를 좋아해서 크게 뭐 힘들진 않고
# 3           제일. 나이많은. 고양이. 나이. 무엇.                그려 가장 나이가 많은 고양이가 몇살이여?
# 4                    고양이. 갈색. 여섯살.                        6살인데 갈색 고양이 있어~
#
#                      chat                 choding  \
# 0     하잉ㅋㅋ 나 떼걸룩 6마리 키운다!      ㅎㅇ 나 주인님 6마리 모심 ㅋㅋ
# 1       엥? 6마리나? 안힘듬?ㅋㅋㅋㅋ        6마리? 에바아니냐 안 힘듦?
# 2  내가 고양이 좋아해서 딱히 안힘듬 ㅋㅋㅋ  ㄱㅊ 나 고양이 환장해서 힘든 것도 모름
# 3     가장 나이 먹은 고양이가 몇살이야?         젤 낡은 고영희가 몇 살임?
# 4        이제 여섯살이고 갈색고양이임!                 6살, 갈색임
#
#                                   emoticon  \
# 0        안녕!! >< 나는 고양이😺를 ➏ 마리 키우고있어!! 0_0
# 1  고양이를 6마리나?!! w(ﾟДﾟ)w 키우는거 안 힘듬?? (⊙_⊙;)
# 2    뭐 나야 워낙에 고양이 좋아하니까 딱히 안힘드엉! \(@^0^@)/
# 3             가장 나이 먹은 고양인 몇 살이양? (´･ω･`)?
# 4           여설 살!! ㄱ^o^/ 색깔은 갈색! O(*￣▽￣*)ブ
#
#                                        enfp                        gentle  \
# 0           안녕안녕~! 나 고양이 6마리나 키운다? 완전 대박이징~     안녕하십니까,, 저는 고양이 6마리 키웁니다.
# 1           고양이를 6마리나? 완전 대박~ 키우는 거 안 힘들어?!     고양이를 6마리나 키우십니까? 안 힘드신지,,
# 2  내가 또 워~낙에 고양이를 좋아하잖아~ 그렇게 크~게 힘들진 않아 ㅎㅎ~  제가 워낙 고양이를 좋아해서 크게 힘들진 않습니다.
# 3    대박대박 완전 대박!! 그럼 제~일 나이 많은 고양이는 몇살이야~?!         가장 나이가 있는 고양이가 몇살입니까?
# 4     6살인 애 있는데, 완전 귀.여.워. 갈색 고양이야 진짜 대박이지?              6살된 갈색 아이가 있습니다.
#
#                                 halbae                       halmae  \
# 0      안녕하신가~... 난 지금 고양이를 6마리 키우고 있다네  하유 시벌것 괭이놈 6마리 키우는데 힘들어 죽겟네
# 1             고양이를 6마리나? 키우는거 힘들지 않는가?      니기럴 털만 날리는 거 키우기 안 힘들데?
# 2  내가 워낙에...고양이가 좋아가지고 그렇게 힘들지 않어...^^         옘병 내가 좋아하니까 키워야지 시벌것
# 3        고양이들 중에서…가장 나이 먹을 애가 몇살인가?...     거 젤 빨리 뒤질 놈이 나이 얼마나 쳐먹었냐
# 4                  저…갈색 고양이인데…여섯살이지~..   저 노망난 갈색놈이 6살 뒤룩뒤룩 쳐먹은 놈이여
#
#                    joongding                         king  \
# 0  안녕하냐 ㅡㅡ 나 씹냥이 6마리나 키운다 하;       반갑소. 짐은 고양이를 6마리나 키우오.
# 1        아니 고양이를 6마리나? 안힘드냐?    고양이를 6마리나? 키우는게 수고스럽진 않소?
# 2      고양이 좋아한다고ㅡㅡ 1도 안힘듬 ㅡㅡ  과인은 고양이를 어여삐 어겨 그리 수고스럽진 않소
# 3               가장 늙은애가 몇살인데        최고령 고양이의 나이는 어떻게 되는가?
# 4                여섯살 갈색냥인데 왜             여섯 살이오. 갈색 고양이오.
#
#                          naruto                            seonbi  \
# 0   안녕하냐니깐! 난 고양이를 6마리 키우고있다니깐!       안녕하시오! 소인은 고양이를 6마리 키우고 있소!
# 1     고양이를 6마리나? 키우는거 힘들지 않냐니깐?     고양이를 6마리나 키우고 있는 것이오? 힘들지 않소?
# 2  내가 고양이를 엄청 좋아해서 별로 힘들지 않다니깐!  소인 고양이를 엄청 좋아하기 때문에 별로 힘들지 않소이다.
# 3   가장 나이 많이 먹은 고양이가 몇 살 이냐니깐?!          나이를 가장 많이 먹은 고양이가 몇 살이오?
# 4              갈색 고양이가 여섯살이라니깐!                     여섯 살에 갈색 고양이오
#
#                                  sosim                     translator
# 0                  안녕… 난 고양이 6마리 키워 ㅠㅠ     반가운. 나는 6마리의 고양이를 소지하고 있다.
# 1         고양이..6마리나? ㅠ 키우는건 혹시 안힘들어..?  6마리의 고양이? 당신은 그들로부터 지치지 않습니까?
# 2  내가 고양이 워낙 좋아해서..ㅠㅠ 크게 힘들진 않은 것 같아..        나는 고양이의 큰 애호가. 지치지 않는다.
# 3        혹시.. 제일 나이 많은 고양이는.. 몇살이야..?ㅠ             가장 늙은 고양이가 몇 년입니까?
# 4                여섯살이야.. 갈색 ㅠㅠ 고양이야..ㅠ                 여섯. 고양이는 갈색이다.

# %%
df.fillna('', inplace=True)

# %%
df.head()
# Out:
#                         formal                    informal  \
# 0       안녕하세요. 저는 고양이 6마리 키워요.          안녕! 나는 고양이 6마리 키워.
# 1     고양이를 6마리나요? 키우는거 안 힘드세요?      고양이를 6마리나? 키우는거 안 힘들어?
# 2  제가 워낙 고양이를 좋아해서 크게 힘들진 않아요.  내가 워낙 고양이를 좋아해서 크게 힘들진 않아.
# 3       가장 나이가 많은 고양이가 어떻게 돼요?       가장 나이가 많은 고양이가 몇 살이야?
# 4           여섯 살입니다. 갈색 고양이에요.            여섯 살이야. 갈색 고양이지.
#
#                            android                                   azae  \
# 0  휴먼. 반갑다. 안드로이드는. 고양이. 6마리. 소유중.  아이고 안녕하십니까~ 나는 그냥 고양이 6마리 키우고 있는 사람이여
# 1             고양이. 6마리. 양육. 번거로운가.        아니 무슨 고양이를 6마리나? 거 키우는 거 안 힘든가?
# 2         안드로이드. 고양이. 선호. 힘들지. 않음.        내가 또 워~낙에 고양이를 좋아해서 크게 뭐 힘들진 않고
# 3           제일. 나이많은. 고양이. 나이. 무엇.                그려 가장 나이가 많은 고양이가 몇살이여?
# 4                    고양이. 갈색. 여섯살.                        6살인데 갈색 고양이 있어~
#
#                      chat                 choding  \
# 0     하잉ㅋㅋ 나 떼걸룩 6마리 키운다!      ㅎㅇ 나 주인님 6마리 모심 ㅋㅋ
# 1       엥? 6마리나? 안힘듬?ㅋㅋㅋㅋ        6마리? 에바아니냐 안 힘듦?
# 2  내가 고양이 좋아해서 딱히 안힘듬 ㅋㅋㅋ  ㄱㅊ 나 고양이 환장해서 힘든 것도 모름
# 3     가장 나이 먹은 고양이가 몇살이야?         젤 낡은 고영희가 몇 살임?
# 4        이제 여섯살이고 갈색고양이임!                 6살, 갈색임
#
#                                   emoticon  \
# 0        안녕!! >< 나는 고양이😺를 ➏ 마리 키우고있어!! 0_0
# 1  고양이를 6마리나?!! w(ﾟДﾟ)w 키우는거 안 힘듬?? (⊙_⊙;)
# 2    뭐 나야 워낙에 고양이 좋아하니까 딱히 안힘드엉! \(@^0^@)/
# 3             가장 나이 먹은 고양인 몇 살이양? (´･ω･`)?
# 4           여설 살!! ㄱ^o^/ 색깔은 갈색! O(*￣▽￣*)ブ
#
#                                        enfp                        gentle  \
# 0           안녕안녕~! 나 고양이 6마리나 키운다? 완전 대박이징~     안녕하십니까,, 저는 고양이 6마리 키웁니다.
# 1           고양이를 6마리나? 완전 대박~ 키우는 거 안 힘들어?!     고양이를 6마리나 키우십니까? 안 힘드신지,,
# 2  내가 또 워~낙에 고양이를 좋아하잖아~ 그렇게 크~게 힘들진 않아 ㅎㅎ~  제가 워낙 고양이를 좋아해서 크게 힘들진 않습니다.
# 3    대박대박 완전 대박!! 그럼 제~일 나이 많은 고양이는 몇살이야~?!         가장 나이가 있는 고양이가 몇살입니까?
# 4     6살인 애 있는데, 완전 귀.여.워. 갈색 고양이야 진짜 대박이지?              6살된 갈색 아이가 있습니다.
#
#                                 halbae                       halmae  \
# 0      안녕하신가~... 난 지금 고양이를 6마리 키우고 있다네  하유 시벌것 괭이놈 6마리 키우는데 힘들어 죽겟네
# 1             고양이를 6마리나? 키우는거 힘들지 않는가?      니기럴 털만 날리는 거 키우기 안 힘들데?
# 2  내가 워낙에...고양이가 좋아가지고 그렇게 힘들지 않어...^^         옘병 내가 좋아하니까 키워야지 시벌것
# 3        고양이들 중에서…가장 나이 먹을 애가 몇살인가?...     거 젤 빨리 뒤질 놈이 나이 얼마나 쳐먹었냐
# 4                  저…갈색 고양이인데…여섯살이지~..   저 노망난 갈색놈이 6살 뒤룩뒤룩 쳐먹은 놈이여
#
#                    joongding                         king  \
# 0  안녕하냐 ㅡㅡ 나 씹냥이 6마리나 키운다 하;       반갑소. 짐은 고양이를 6마리나 키우오.
# 1        아니 고양이를 6마리나? 안힘드냐?    고양이를 6마리나? 키우는게 수고스럽진 않소?
# 2      고양이 좋아한다고ㅡㅡ 1도 안힘듬 ㅡㅡ  과인은 고양이를 어여삐 어겨 그리 수고스럽진 않소
# 3               가장 늙은애가 몇살인데        최고령 고양이의 나이는 어떻게 되는가?
# 4                여섯살 갈색냥인데 왜             여섯 살이오. 갈색 고양이오.
#
#                          naruto                            seonbi  \
# 0   안녕하냐니깐! 난 고양이를 6마리 키우고있다니깐!       안녕하시오! 소인은 고양이를 6마리 키우고 있소!
# 1     고양이를 6마리나? 키우는거 힘들지 않냐니깐?     고양이를 6마리나 키우고 있는 것이오? 힘들지 않소?
# 2  내가 고양이를 엄청 좋아해서 별로 힘들지 않다니깐!  소인 고양이를 엄청 좋아하기 때문에 별로 힘들지 않소이다.
# 3   가장 나이 많이 먹은 고양이가 몇 살 이냐니깐?!          나이를 가장 많이 먹은 고양이가 몇 살이오?
# 4              갈색 고양이가 여섯살이라니깐!                     여섯 살에 갈색 고양이오
#
#                                  sosim                     translator
# 0                  안녕… 난 고양이 6마리 키워 ㅠㅠ     반가운. 나는 6마리의 고양이를 소지하고 있다.
# 1         고양이..6마리나? ㅠ 키우는건 혹시 안힘들어..?  6마리의 고양이? 당신은 그들로부터 지치지 않습니까?
# 2  내가 고양이 워낙 좋아해서..ㅠㅠ 크게 힘들진 않은 것 같아..        나는 고양이의 큰 애호가. 지치지 않는다.
# 3        혹시.. 제일 나이 많은 고양이는.. 몇살이야..?ㅠ             가장 늙은 고양이가 몇 년입니까?
# 4                여섯살이야.. 갈색 ㅠㅠ 고양이야..ㅠ                 여섯. 고양이는 갈색이다.

# %%
temp_dict = [{"formal": row['formal'], "informal": row['informal'], "android": row['android'], "azae": row['azae'], "chat": row['chat'], "choding": row['choding'], "emoticon": row['emoticon'], "enfp": row['enfp'], "gentle": row['gentle'], "halbae": row['halbae'], "halmae": row['halmae'], "joongding": row['joongding'], "king": row['king'], "naruto": row['naruto'], "seonbi": row['seonbi'], "sosim": row['sosim'], "translator": row['translator']} for _, row in df.iterrows()]

# %%
print(len(temp_dict))
# Out:
# 3470

# %%
# temp_dict = [{"formal": row['formal'], "informal": row['informal'], "android": row['android'], "azae": row['azae'], "chat": row['chat'], "choding": row['choding'], "emoticon": row['emoticon'], "enfp": row['enfp'], "gentle": row['gentle'], "halbae": row['halbae'], "halmae": row['halmae'], "joongding": row['joongding'], "king": row['king'], "naruto": row['naruto'], "seonbi": row['seonbi'], "sosim": row['sosim'], "translator": row['translator']} for _, row in df.iterrows()]
# temp_dict_temp = [temp_dict[0]]

# %%
# print(temp_dict_temp)

# %%
print(temp_dict[:5])
# Out:
# [{'formal': '안녕하세요. 저는 고양이 6마리 키워요.', 'informal': '안녕! 나는 고양이 6마리 키워.', 'android': '휴먼. 반갑다. 안드로이드는. 고양이. 6마리. 소유중.', 'azae': '아이고 안녕하십니까~ 나는 그냥 고양이 6마리 키우고 있는 사람이여', 'chat': '하잉ㅋㅋ 나 떼걸룩 6마리 키운다!', 'choding': 'ㅎㅇ 나 주인님 6마리 모심 ㅋㅋ', 'emoticon': '안녕!! >< 나는 고양이😺를 ➏ 마리 키우고있어!! 0_0', 'enfp': '안녕안녕~! 나 고양이 6마리나 키운다? 완전 대박이징~', 'gentle': '안녕하십니까,, 저는 고양이 6마리 키웁니다.', 'halbae': '안녕하신가~... 난 지금 고양이를 6마리 키우고 있다네', 'halmae': '하유 시벌것 괭이놈 6마리 키우는데 힘들어 죽겟네', 'joongding': '안녕하냐 ㅡㅡ 나 씹냥이 6마리나 키운다 하;', 'king': '반갑소. 짐은 고양이를 6마리나 키우오.', 'naruto': '안녕하냐니깐! 난 고양이를 6마리 키우고있다니깐!', 'seonbi': '안녕하시오! 소인은 고양이를 6마리 키우고 있소!', 'sosim': '안녕… 난 고양이 6마리 키워 ㅠㅠ', 'translator': '반가운. 나는 6마리의 고양이를 소지하고 있다.'}, {'formal': '고양이를 6마리나요? 키우는거 안 힘드세요?', 'informal': '고양이를 6마리나? 키우는거 안 힘들어?', 'android': '고양이. 6마리. 양육. 번거로운가.', 'azae': '아니 무슨 고양이를 6마리나? 거 키우는 거 안 힘든가?', 'chat': '엥? 6마리나? 안힘듬?ㅋㅋㅋㅋ', 'choding': '6마리? 에바아니냐 안 힘듦?', 'emoticon': '고양이를 6마리나?!! w(ﾟДﾟ)w 키우는거 안 힘듬?? (⊙_⊙;)', 'enfp': '고양이를 6마리나? 완전 대박~ 키우는 거 안 힘들어?!', 'gentle': '고양이를 6마리나 키우십니까? 안 힘드신지,,', 'halbae': '고양이를 6마리나? 키우는거 힘들지 않는가?', 'halmae': '니기럴 털만 날리는 거 키우기 안 힘들데?', 'joongding': '아니 고양이를 6마리나? 안힘드냐?', 'king': '고양이를 6마리나? 키우는게 수고스럽진 않소?', 'naruto': '고양이를 6마리나? 키우는거 힘들지 않냐니깐?', 'seonbi': '고양이를 6마리나 키우고 있는 것이오? 힘들지 않소?', 'sosim': '고양이..6마리나? ㅠ 키우는건 혹시 안힘들어..?', 'translator': '6마리의 고양이? 당신은 그들로부터 지치지 않습니까?'}, {'formal': '제가 워낙 고양이를 좋아해서 크게 힘들진 않아요.', 'informal': '내가 워낙 고양이를 좋아해서 크게 힘들진 않아.', 'android': '안드로이드. 고양이. 선호. 힘들지. 않음.', 'azae': '내가 또 워~낙에 고양이를 좋아해서 크게 뭐 힘들진 않고', 'chat': '내가 고양이 좋아해서 딱히 안힘듬 ㅋㅋㅋ', 'choding': 'ㄱㅊ 나 고양이 환장해서 힘든 것도 모름', 'emoticon': '뭐 나야 워낙에 고양이 좋아하니까 딱히 안힘드엉! \\(@^0^@)/', 'enfp': '내가 또 워~낙에 고양이를 좋아하잖아~ 그렇게 크~게 힘들진 않아 ㅎㅎ~', 'gentle': '제가 워낙 고양이를 좋아해서 크게 힘들진 않습니다.', 'halbae': '내가 워낙에...고양이가 좋아가지고 그렇게 힘들지 않어...^^', 'halmae': '옘병 내가 좋아하니까 키워야지 시벌것', 'joongding': '고양이 좋아한다고ㅡㅡ 1도 안힘듬 ㅡㅡ', 'king': '과인은 고양이를 어여삐 어겨 그리 수고스럽진 않소', 'naruto': '내가 고양이를 엄청 좋아해서 별로 힘들지 않다니깐!', 'seonbi': '소인 고양이를 엄청 좋아하기 때문에 별로 힘들지 않소이다.', 'sosim': '내가 고양이 워낙 좋아해서..ㅠㅠ 크게 힘들진 않은 것 같아..', 'translator': '나는 고양이의 큰 애호가. 지치지 않는다.'}, {'formal': '가장 나이가 많은 고양이가 어떻게 돼요?', 'informal': '가장 나이가 많은 고양이가 몇 살이야?', 'android': '제일. 나이많은. 고양이. 나이. 무엇.', 'azae': '그려 가장 나이가 많은 고양이가 몇살이여?', 'chat': '가장 나이 먹은 고양이가 몇살이야?', 'choding': '젤 낡은 고영희가 몇 살임?', 'emoticon': '가장 나이 먹은 고양인 몇 살이양? (´･ω･`)?', 'enfp': '대박대박 완전 대박!! 그럼 제~일 나이 많은 고양이는 몇살이야~?!', 'gentle': '가장 나이가 있는 고양이가 몇살입니까?', 'halbae': '고양이들 중에서…가장 나이 먹을 애가 몇살인가?...', 'halmae': '거 젤 빨리 뒤질 놈이 나이 얼마나 쳐먹었냐', 'joongding': '가장 늙은애가 몇살인데', 'king': '최고령 고양이의 나이는 어떻게 되는가?', 'naruto': '가장 나이 많이 먹은 고양이가 몇 살 이냐니깐?!', 'seonbi': '나이를 가장 많이 먹은 고양이가 몇 살이오?', 'sosim': '혹시.. 제일 나이 많은 고양이는.. 몇살이야..?ㅠ', 'translator': '가장 늙은 고양이가 몇 년입니까?'}, {'formal': '여섯 살입니다. 갈색 고양이에요.', 'informal': '여섯 살이야. 갈색 고양이지.', 'android': '고양이. 갈색. 여섯살.', 'azae': '6살인데 갈색 고양이 있어~', 'chat': '이제 여섯살이고 갈색고양이임!', 'choding': '6살, 갈색임', 'emoticon': '여설 살!! ㄱ^o^/ 색깔은 갈색! O(*￣▽￣*)ブ', 'enfp': '6살인 애 있는데, 완전 귀.여.워. 갈색 고양이야 진짜 대박이지?', 'gentle': '6살된 갈색 아이가 있습니다.', 'halbae': '저…갈색 고양이인데…여섯살이지~..', 'halmae': '저 노망난 갈색놈이 6살 뒤룩뒤룩 쳐먹은 놈이여', 'joongding': '여섯살 갈색냥인데 왜', 'king': '여섯 살이오. 갈색 고양이오.', 'naruto': '갈색 고양이가 여섯살이라니깐!', 'seonbi': '여섯 살에 갈색 고양이오', 'sosim': '여섯살이야.. 갈색 ㅠㅠ 고양이야..ㅠ', 'translator': '여섯. 고양이는 갈색이다.'}]

# %%
with open(cfg.datasets_json, 'w', encoding='utf-8') as f:
    for line in temp_dict:
        json_record = json.dumps(line, ensure_ascii=False)
        f.write(json_record + '\n')

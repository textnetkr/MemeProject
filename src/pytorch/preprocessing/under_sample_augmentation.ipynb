# %% [markdown]
# # Install

# %%
# !pip3 install pshmodule

# %%
# !pip3 install pickle5

# %%
# !pip3 install pandas==1.5.0

# %%
# !pip3 install swifter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Load

# %%
import sys
sys.path.append('/content/drive/MyDrive/MemeProject/src/pytorch/preprocessing')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/MemeProject/src/pytorch/preprocessing']

# %%
from tqdm import tqdm
import config as cfg
import pandas as pd
import numpy as np
import swifter
from pshmodule.utils import filemanager as fm

# %%
df = fm.load(cfg.origin_class153_ref)
# Out:
# extension : .pickle
# Loaded 181704 records from drive/MyDrive/MemeProject/data/augmentation/origin_class153_ref.pickle

# %%
df_table = fm.load(cfg.report_label)
# Out:
# extension : .xlsx
# Loaded 153 records from drive/MyDrive/MemeProject/data/report/table.xlsx

# %% [markdown]
# # Over Sampling

# %% [markdown]
# ##### table

# %%
df_table = df_table[['대화소재/화행', 'count']]

# %%
df_table.head()
# Out:
#    대화소재/화행  count
# 0   밈봇, 명령    492
# 1   밈봇, 혐오    486
# 2   밈봇, 실망    480
# 3   밈봇, 만족    480
# 4  유명인, 칭찬    144

# %%
df_table.describe()
# Out:
#             count
# count  153.000000
# mean    59.803922
# std     75.330680
# min      6.000000
# 25%     30.000000
# 50%     42.000000
# 75%     72.000000
# max    492.000000

# %% [markdown]
# ##### over sampling

# %%
df = df[['num', 'g_num', 'u_num', 'material', 'speech', 'u', 'arg1', 'label']]

# %%
df.drop_duplicates(inplace=True)
# Out:
# <ipython-input-18-16cdb8520be8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(10)
# Out:
#   num g_num u_num material speech                       u  arg1 label
# 0   1     1     1     학교생활     자랑         나 중간고사 반에서 1등했어  중간고사   146
# 1   2     1     2     학교생활     자랑  중간고사 점수 내가 반에서 제일 잘 받음  중간고사   146
# 2   3     1     3     학교생활     자랑       나 반에서 중간 성적 제일 좋아    중간   146
# 3   4     1     4     학교생활     자랑    우리 반에서 내가 시험 제일 잘 봤다    시험   146
# 4   5     1     5     학교생활     자랑            중간고사 반 1등 먹음  중간고사   146
# 5   6     1     6     학교생활     자랑          중간시험 내가 반 1등이야  중간시험   146
# 6  25     2     1       밈봇     혐오                  너 멍청하다         152
# 7  26     2     2       밈봇     혐오            이 새끼 빡대가리잖아?         152
# 8  27     2     3       밈봇     혐오            너 말귀 못 알아듣냐고         152
# 9  28     2     4       밈봇     혐오              병신 이해력 딸리네         152

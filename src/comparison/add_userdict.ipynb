# %% [markdown]
# # import

# %%
# !pip3 install swifter

# %%
# !pip3 install pshmodule

# %%
# !pip3 install pickle5

# %%
# !pip3 install pandas==1.5.0

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Example

# %% [markdown]
# ### Okt

# %%
import konlpy
konlpy.data.path
# Out:
# ['/root/konlpy_data',
#  '/usr/share/konlpy_data',
#  '/usr/local/share/konlpy_data',
#  '/usr/lib/konlpy_data',
#  '/usr/local/lib/konlpy_data',
#  '/usr/local/lib/python3.8/dist-packages/konlpy/data']

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
print(okt.pos("순대국 먹고 싶다."))
print(okt.pos("순댓국 먹고 싶다."))
print(okt.pos("패스트파이브에서 일을 합니다."))
print(okt.pos("아이오아이는 정말 이뻐요."))
# Out:
# [('순', 'Modifier'), ('대국', 'Noun'), ('먹고', 'Verb'), ('싶다', 'Verb'), ('.', 'Punctuation')]
# [('순', 'Modifier'), ('댓', 'Modifier'), ('국', 'Noun'), ('먹고', 'Verb'), ('싶다', 'Verb'), ('.', 'Punctuation')]
# [('패스트', 'Noun'), ('파이브', 'Noun'), ('에서', 'Josa'), ('일', 'Noun'), ('을', 'Josa'), ('합니다', 'Verb'), ('.', 'Punctuation')]
# [('아이오', 'Noun'), ('아이', 'Noun'), ('는', 'Josa'), ('정말', 'Noun'), ('이뻐요', 'Adjective'), ('.', 'Punctuation')]

# %%
import os

os.chdir('/usr/local/lib/python3.8/dist-packages/konlpy/java')
os.getcwd()
# Out:
# '/usr/local/lib/python3.8/dist-packages/konlpy/java'

# %%
# !ls
# Out:
# aho-corasick.jar     kkma-2.0.jar		 shineware-ds-1.0.jar
# bin		     komoran-3.0.jar		 snakeyaml-1.12.jar
# conf		     open-korean-text-2.1.0.jar  twitter-text-1.14.7.jar
# data		     scala-library-2.12.3.jar
# jhannanum-0.8.4.jar  shineware-common-1.0.jar

# %%
# !jar xvf open-korean-text-2.1.0.jar

# %% [markdown]
# ##### open user dict

# %%
with open(f"/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()

# %%
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n'

# %% [markdown]
# ##### add new word

# %%
data += '순댓국\n순대국\n아이오아이\n패스트파이브\n'

# %% [markdown]
# ##### dict save

# %%
with open("/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)

# %%
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n순댓국\n순대국\n아이오아이\n패스트파이브\n'

# %%
# !jar cvf open-korean-text-2.1.0.jar org
# !rm org

# %% [markdown]
# ##### test

# %%
from konlpy.tag import Okt

okt = Okt()

# %%
print(okt.pos("순대국 먹고 싶다."))
print(okt.pos("순댓국 먹고 싶다."))
print(okt.pos("패스트파이브에서 일을 합니다."))
print(okt.pos("아이오아이는 정말 이뻐요."))
# Out:
# [('순대국', 'Noun'), ('먹고', 'Verb'), ('싶다', 'Verb'), ('.', 'Punctuation')]
# [('순댓국', 'Noun'), ('먹고', 'Verb'), ('싶다', 'Verb'), ('.', 'Punctuation')]
# [('패스트파이브', 'Noun'), ('에서', 'Josa'), ('일', 'Noun'), ('을', 'Josa'), ('합니다', 'Verb'), ('.', 'Punctuation')]
# [('아이오아이', 'Noun'), ('는', 'Josa'), ('정말', 'Noun'), ('이뻐요', 'Adjective'), ('.', 'Punctuation')]

# %% [markdown]
# ### Mecab

# %%
from konlpy.tag import Mecab

m = Mecab()

# %%
print(m.pos("순대국 먹고 싶다."))
print(m.pos("순댓국 먹고 싶다."))
print(m.pos("패스트파이브에서 일을 합니다."))
print(m.pos("아이오아이는 정말 이뻐요."))
# Out:
# [('순', 'MM'), ('대국', 'NNG'), ('먹', 'VV'), ('고', 'EC'), ('싶', 'VX'), ('다', 'EF'), ('.', 'SF')]
# [('순댓국', 'NNG'), ('먹', 'VV'), ('고', 'EC'), ('싶', 'VX'), ('다', 'EF'), ('.', 'SF')]
# [('패스트', 'NNP'), ('파이브', 'NNP'), ('에서', 'JKB'), ('일', 'NNG'), ('을', 'JKO'), ('합니다', 'VV+EF'), ('.', 'SF')]
# [('아이오', 'NNG'), ('아이', 'NNG'), ('는', 'JX'), ('정말', 'MAG'), ('이뻐요', 'VA+EF'), ('.', 'SF')]

# %%
# !pip3 install jamo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jamo in /usr/local/lib/python3.8/dist-packages (0.4.1)

# %%
from jamo import h2j, j2hcj

def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF

# %%
with open('/tmp/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv', "r", encoding='utf-8') as f:
  user_dict = f.readlines()

# 단어 추가
add_list = ['순댓국', '순대국', '아이오아이', '패스트파이브']

for word in add_list:
  jongsung_TF = get_jongsung_TF(word)
  line = '{},*,*,*,NNP,*,{},{},*,*,*,*,*\n'.format(word, jongsung_TF, word)

  user_dict.append(line)

# %%
user_dict[-10:]
# Out:
# ['대우,,,,NNP,*,F,대우,*,*,*,*,*\n',
#  '구글,,,,NNP,*,T,구글,*,*,*,*,*\n',
#  '순댓국,*,*,*,NNP,*,T,순댓국,Compound,*,*,*,*\n',
#  '순대국,*,*,*,NNP,*,T,순대국,Compound,*,*,*,*\n',
#  '아이오아이,*,*,*,NNP,*,F,아이오아이,Compound,*,*,*,*\n',
#  '패스트파이브,*,*,*,NNP,*,F,패스트파이브,Compound,*,*,*,*\n',
#  '순댓국,*,*,*,NNP,*,T,순댓국,*,*,*,*,*\n',
#  '순대국,*,*,*,NNP,*,T,순대국,*,*,*,*,*\n',
#  '아이오아이,*,*,*,NNP,*,F,아이오아이,*,*,*,*,*\n',
#  '패스트파이브,*,*,*,NNP,*,F,패스트파이브,*,*,*,*,*\n']

# %% [markdown]
# ##### dict save

# %%
with open('/tmp/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv', 'w', encoding='utf-8') as f:
  for line in user_dict:
    f.write(line)

# %% [markdown]
# ##### check

# %%
with open("/tmp/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv", 'r', encoding='utf-8') as f:
  file_new = f.readlines()
file_new[-20:]
# Out:
# ['대우,,,,NNP,*,F,대우,*,*,*,*,*\n',
#  '구글,,,,NNP,*,T,구글,*,*,*,*,*\n',
#  '순댓국,*,*,*,NNP,*,T,순댓국,Compound,*,*,*,*\n',
#  '순대국,*,*,*,NNP,*,T,순대국,Compound,*,*,*,*\n',
#  '아이오아이,*,*,*,NNP,*,F,아이오아이,Compound,*,*,*,*\n',
#  '패스트파이브,*,*,*,NNP,*,F,패스트파이브,Compound,*,*,*,*\n']

# %%
# !bash /tmp/mecab-ko-dic-2.1.1-20180720/tools/add-userdic.sh

# %%
# !cd /tmp/mecab-ko-dic-2.1.1-20180720
# !make install

# %% [markdown]
# ##### test

# %%
from konlpy.tag import Mecab

m = Mecab(dicpath='/tmp/mecab-ko-dic-2.1.1-20180720')

# %%
print(m.pos("순대국 먹고 싶다."))
print(m.pos("순댓국 먹고 싶다."))
print(m.pos("패스트파이브에서 일을 합니다."))
print(m.pos("아이오아이는 정말 이뻐요."))
# Out:
# [('순대국', 'NNP'), ('먹', 'VV'), ('고', 'EC'), ('싶', 'VX'), ('다', 'EF'), ('.', 'SF')]
# [('순댓국', 'NNG'), ('먹', 'VV'), ('고', 'EC'), ('싶', 'VX'), ('다', 'EF'), ('.', 'SF')]
# [('패스트파이브', 'NNP'), ('에서', 'JKB'), ('일', 'NNG'), ('을', 'JKO'), ('합니다', 'VV+EF'), ('.', 'SF')]
# [('아이오아이', 'NNP'), ('는', 'JX'), ('정말', 'MAG'), ('이뻐요', 'VA+EF'), ('.', 'SF')]

# %% [markdown]
# ### Kiwi

# %%
# !pip install kiwipiepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kiwipiepy in /usr/local/lib/python3.8/dist-packages (0.14.1)
# Requirement already satisfied: kiwipiepy-model~=0.14 in /usr/local/lib/python3.8/dist-packages (from kiwipiepy) (0.14.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from kiwipiepy) (1.22.4)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.8/dist-packages (from kiwipiepy) (0.6)

# %%
from kiwipiepy import Kiwi
kiwi = Kiwi()

# %% [markdown]
# 토크나이저

# %%
for result, score in kiwi.analyze("형태소 분석 결과입니다", top_n=5):
    print(score, result, sep='\t')
# Out:
# -29.27370262145996	[Token(form='형태소', tag='NNG', start=0, len=3), Token(form='분석', tag='NNG', start=4, len=2), Token(form='결과', tag='NNG', start=7, len=2), Token(form='이', tag='VCP', start=9, len=1), Token(form='ᆸ니다', tag='EF', start=9, len=3)]
# -36.541473388671875	[Token(form='형태소', tag='NNG', start=0, len=3), Token(form='분석', tag='NNG', start=4, len=2), Token(form='결과', tag='NNG', start=7, len=2), Token(form='이', tag='VCP', start=9, len=1), Token(form='ᆸ니다', tag='EC', start=9, len=3)]
# -50.577144622802734	[Token(form='형태소', tag='NNG', start=0, len=3), Token(form='분석', tag='NNG', start=4, len=2), Token(form='결과', tag='NNG', start=7, len=2), Token(form='입', tag='NNG', start=9, len=1), Token(form='니다', tag='EF', start=10, len=2)]
# -50.773948669433594	[Token(form='형태소', tag='NNG', start=0, len=3), Token(form='분석', tag='NNG', start=4, len=2), Token(form='결과', tag='NNG', start=7, len=2), Token(form='입', tag='VV-R', start=9, len=1), Token(form='니다', tag='EF', start=10, len=2)]
# -51.84966278076172	[Token(form='형태소', tag='NNG', start=0, len=3), Token(form='분석', tag='NNG', start=4, len=2), Token(form='결과', tag='NNG', start=7, len=2), Token(form='입', tag='VV-R', start=9, len=1), Token(form='니', tag='EC', start=10, len=1), Token(form='다', tag='MAG', start=11, len=1)]

# %%
# 간단하게 형태소 분석 결과만 얻고 싶다면 `tokenize` 메소드를 사용하면 됩니다.
result = kiwi.tokenize("형태소 분석 결과입니다")

# %% [markdown]
# 사용자 사전 추가

# %%
kiwi.add_user_word('골리', 'NNP', -6)
# Out:
# False

# %%
print(*kiwi.analyze('골리는 사람이다', top_n=5), sep='\n')
# Out:
# ([Token(form='골리', tag='NNP', start=0, len=2), Token(form='는', tag='JX', start=2, len=1), Token(form='사람', tag='NNG', start=4, len=2), Token(form='이', tag='VCP', start=6, len=1), Token(form='다', tag='EF', start=7, len=1)], -19.38816261291504)
# ([Token(form='골리', tag='NNP', start=0, len=2), Token(form='는', tag='JX', start=2, len=1), Token(form='사람', tag='NNG', start=4, len=2), Token(form='이', tag='JKS', start=6, len=1), Token(form='다', tag='MAG', start=7, len=1)], -25.237586975097656)
# ([Token(form='골리', tag='NNP', start=0, len=2), Token(form='는', tag='JX', start=2, len=1), Token(form='사람', tag='NNG', start=4, len=2), Token(form='이', tag='VCP', start=6, len=1), Token(form='다', tag='EC', start=7, len=1)], -25.61087989807129)
# ([Token(form='골리', tag='NNP', start=0, len=2), Token(form='는', tag='ETM', start=2, len=1), Token(form='사람', tag='NNG', start=4, len=2), Token(form='이', tag='VCP', start=6, len=1), Token(form='다', tag='EF', start=7, len=1)], -26.696094512939453)
# ([Token(form='골리', tag='NNP', start=0, len=2), Token(form='는', tag='JX', start=2, len=1), Token(form='사람', tag='NNG', start=4, len=2), Token(form='이', tag='JKC', start=6, len=1), Token(form='다', tag='MAG', start=7, len=1)], -33.64024353027344)

# %%
print(*kiwi.analyze('사람을 골리다', top_n=5), sep='\n')
# Out:
# ([Token(form='사람', tag='NNG', start=0, len=2), Token(form='을', tag='JKO', start=2, len=1), Token(form='골리', tag='NNP', start=4, len=2), Token(form='다', tag='MAG', start=6, len=1)], -34.191368103027344)
# ([Token(form='사람', tag='NNG', start=0, len=2), Token(form='을', tag='JKO', start=2, len=1), Token(form='골리', tag='VV', start=4, len=2), Token(form='다', tag='EF', start=6, len=1)], -34.751708984375)
# ([Token(form='사람', tag='NNG', start=0, len=2), Token(form='을', tag='JKO', start=2, len=1), Token(form='골리', tag='VV', start=4, len=2), Token(form='다', tag='EC', start=6, len=1)], -35.23759460449219)
# ([Token(form='사람', tag='NNG', start=0, len=2), Token(form='을', tag='JKO', start=2, len=1), Token(form='골리', tag='NNP', start=4, len=2), Token(form='하', tag='XSV', start=6, len=0), Token(form='다', tag='EC', start=6, len=1)], -36.54280090332031)
# ([Token(form='사람', tag='NNG', start=0, len=2), Token(form='을', tag='JKO', start=2, len=1), Token(form='골리', tag='NNP', start=4, len=2), Token(form='하', tag='XSA', start=6, len=0), Token(form='다', tag='EF', start=6, len=1)], -38.032718658447266)

# %% [markdown]
# 멀티 스레드

# %%
from kiwipiepy import Kiwi
# 4개의 스레드에서 동시에 처리합니다.
# num_workers 생략시 현재 환경에서 사용가능한 모든 코어를 다 사용합니다.
kiwi = Kiwi(num_workers=4)
with open('result.txt', 'w', encoding='utf-8') as output:
    for res in kiwi.analyze(open('test.txt', encoding='utf-8')):
        output.write(' '.join(map(lambda x:x[0]+'/'+x[1], res[0][0])) + '\n')

# %% [markdown]
# # import

# %%
# !pip3 install swifter

# %%
# !pip3 install pshmodule

# %%
# !pip3 install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip3 install pandas==1.5.0

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Load

# %%
import sys
sys.path.append('/content/drive/MyDrive/MemeProject/src/comparison')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/MemeProject/src/comparison']

# %%
import swifter
import config as cfg
from pprint import pprint
from pshmodule.utils import filemanager as fm

# %%
df = fm.load(cfg.origin_data)
# Out:
# extension : .pickle
# Loaded 9141 records from /content/drive/MyDrive/MemeProject/data/temp_for_doc2vec.pickle

# %%
df.head()
# Out:
#                         u                            soynlp
# 0         나 중간고사 반에서 1등했어          [나, 중간고사, 반에, 서, 1등, 했어]
# 1  중간고사 점수 내가 반에서 제일 잘 받음  [중간고사, 점수, 내가, 반에, 서, 제일, 잘, 받음]
# 2       나 반에서 중간 성적 제일 좋아        [나, 반에, 서, 중간, 성적, 제일, 좋아]
# 3    우리 반에서 내가 시험 제일 잘 봤다    [우리, 반에, 서, 내가, 시험, 제일, 잘, 봤다]
# 4            중간고사 반 1등 먹음                 [중간고사, 반, 1등, 먹음]

# %% [markdown]
# # Example

# %% [markdown]
# ### Okt

# %%
import konlpy
konlpy.data.path
# Out:
# ['/root/konlpy_data',
#  '/usr/share/konlpy_data',
#  '/usr/local/share/konlpy_data',
#  '/usr/lib/konlpy_data',
#  '/usr/local/lib/konlpy_data',
#  '/usr/local/lib/python3.8/dist-packages/konlpy/data']

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
print(okt.pos("순대국 먹고 싶다."))
print(okt.pos("순댓국 먹고 싶다."))
print(okt.pos("패스트파이브에서 일을 합니다."))
print(okt.pos("아이오아이는 정말 이뻐요."))
# Out:
# [('순', 'Modifier'), ('대국', 'Noun'), ('먹고', 'Verb'), ('싶다', 'Verb'), ('.', 'Punctuation')]
# [('순', 'Modifier'), ('댓', 'Modifier'), ('국', 'Noun'), ('먹고', 'Verb'), ('싶다', 'Verb'), ('.', 'Punctuation')]
# [('패스트', 'Noun'), ('파이브', 'Noun'), ('에서', 'Josa'), ('일', 'Noun'), ('을', 'Josa'), ('합니다', 'Verb'), ('.', 'Punctuation')]
# [('아이오', 'Noun'), ('아이', 'Noun'), ('는', 'Josa'), ('정말', 'Noun'), ('이뻐요', 'Adjective'), ('.', 'Punctuation')]

# %%
import os

os.chdir('/usr/local/lib/python3.8/dist-packages/konlpy/java')
os.getcwd()
# Out:
# '/usr/local/lib/python3.8/dist-packages/konlpy/java'

# %%
# !ls
# Out:
# aho-corasick.jar     kkma-2.0.jar		 shineware-ds-1.0.jar
# bin		     komoran-3.0.jar		 snakeyaml-1.12.jar
# conf		     open-korean-text-2.1.0.jar  twitter-text-1.14.7.jar
# data		     scala-library-2.12.3.jar
# jhannanum-0.8.4.jar  shineware-common-1.0.jar

# %%
# !jar xvf open-korean-text-2.1.0.jar

# %% [markdown]
# ##### open user dict

# %%
with open(f"/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()

# %%
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n'

# %% [markdown]
# ##### add new word

# %%
data += '순댓국\n순대국\n아이오아이\n패스트파이브\n'

# %% [markdown]
# ##### dict save

# %%
with open("/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)

# %%
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n순댓국\n순대국\n아이오아이\n패스트파이브\n'

# %%
# !jar cvf open-korean-text-2.1.0.jar org
# !rm org

# %% [markdown]
# ##### test

# %%
from konlpy.tag import Okt

okt = Okt()

# %%
print(okt.pos("순대국 먹고 싶다."))
print(okt.pos("순댓국 먹고 싶다."))
print(okt.pos("패스트파이브에서 일을 합니다."))
print(okt.pos("아이오아이는 정말 이뻐요."))
# Out:
# [('순대국', 'Noun'), ('먹고', 'Verb'), ('싶다', 'Verb'), ('.', 'Punctuation')]
# [('순댓국', 'Noun'), ('먹고', 'Verb'), ('싶다', 'Verb'), ('.', 'Punctuation')]
# [('패스트파이브', 'Noun'), ('에서', 'Josa'), ('일', 'Noun'), ('을', 'Josa'), ('합니다', 'Verb'), ('.', 'Punctuation')]
# [('아이오아이', 'Noun'), ('는', 'Josa'), ('정말', 'Noun'), ('이뻐요', 'Adjective'), ('.', 'Punctuation')]

# %% [markdown]
# ## Mecab

# %%
from konlpy.tag import Mecab

m = Mecab()

# %%
print(m.pos("순대국 먹고 싶다."))
print(m.pos("순댓국 먹고 싶다."))
print(m.pos("패스트파이브에서 일을 합니다."))
print(m.pos("아이오아이는 정말 이뻐요."))
# Out:
# [('순', 'MM'), ('대국', 'NNG'), ('먹', 'VV'), ('고', 'EC'), ('싶', 'VX'), ('다', 'EF'), ('.', 'SF')]
# [('순댓국', 'NNG'), ('먹', 'VV'), ('고', 'EC'), ('싶', 'VX'), ('다', 'EF'), ('.', 'SF')]
# [('패스트', 'NNP'), ('파이브', 'NNP'), ('에서', 'JKB'), ('일', 'NNG'), ('을', 'JKO'), ('합니다', 'VV+EF'), ('.', 'SF')]
# [('아이오', 'NNG'), ('아이', 'NNG'), ('는', 'JX'), ('정말', 'MAG'), ('이뻐요', 'VA+EF'), ('.', 'SF')]

# %% [markdown]
# ##### add dict

# %%
# !pip3 install jamo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from jamo import h2j, j2hcj

def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF

# %%
with open('/tmp/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv', "r", encoding='utf-8') as f:
  user_dict = f.readlines()

# 단어 추가
add_list = ['순댓국', '순대국', '아이오아이', '패스트파이브']

for word in add_list:
  jongsung_TF = get_jongsung_TF(word)
  line = '{},*,*,*,NNP,*,{},{},*,*,*,*,*\n'.format(word, jongsung_TF, word)

  user_dict.append(line)

# %%
user_dict[-10:]
# Out:
# ['대우,,,,NNP,*,F,대우,*,*,*,*,*\n',
#  '구글,,,,NNP,*,T,구글,*,*,*,*,*\n',
#  '순댓국,*,*,*,NNP,*,T,순댓국,Compound,*,*,*,*\n',
#  '순대국,*,*,*,NNP,*,T,순대국,Compound,*,*,*,*\n',
#  '아이오아이,*,*,*,NNP,*,F,아이오아이,Compound,*,*,*,*\n',
#  '패스트파이브,*,*,*,NNP,*,F,패스트파이브,Compound,*,*,*,*\n',
#  '순댓국,*,*,*,NNP,*,T,순댓국,*,*,*,*,*\n',
#  '순대국,*,*,*,NNP,*,T,순대국,*,*,*,*,*\n',
#  '아이오아이,*,*,*,NNP,*,F,아이오아이,*,*,*,*,*\n',
#  '패스트파이브,*,*,*,NNP,*,F,패스트파이브,*,*,*,*,*\n']

# %% [markdown]
# ##### dict save

# %%
with open('/tmp/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv', 'w', encoding='utf-8') as f:
  for line in user_dict:
    f.write(line)

# %% [markdown]
# ##### check

# %%
with open("/tmp/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv", 'r', encoding='utf-8') as f:
  file_new = f.readlines()
file_new[-20:]
# Out:
# ['대우,,,,NNP,*,F,대우,*,*,*,*,*\n',
#  '구글,,,,NNP,*,T,구글,*,*,*,*,*\n',
#  '순댓국,*,*,*,NNP,*,T,순댓국,Compound,*,*,*,*\n',
#  '순대국,*,*,*,NNP,*,T,순대국,Compound,*,*,*,*\n',
#  '아이오아이,*,*,*,NNP,*,F,아이오아이,Compound,*,*,*,*\n',
#  '패스트파이브,*,*,*,NNP,*,F,패스트파이브,Compound,*,*,*,*\n']

# %%
# !bash /tmp/mecab-ko-dic-2.1.1-20180720/tools/add-userdic.sh

# %%
# !cd /tmp/mecab-ko-dic-2.1.1-20180720
# !make install

# %% [markdown]
# ##### test

# %%
from konlpy.tag import Mecab

m = Mecab(dicpath='/tmp/mecab-ko-dic-2.1.1-20180720')

# %%
print(m.pos("순대국 먹고 싶다."))
print(m.pos("순댓국 먹고 싶다."))
print(m.pos("패스트파이브에서 일을 합니다."))
print(m.pos("아이오아이는 정말 이뻐요."))
# Out:
# [('순대국', 'NNP'), ('먹', 'VV'), ('고', 'EC'), ('싶', 'VX'), ('다', 'EF'), ('.', 'SF')]
# [('순댓국', 'NNG'), ('먹', 'VV'), ('고', 'EC'), ('싶', 'VX'), ('다', 'EF'), ('.', 'SF')]
# [('패스트파이브', 'NNP'), ('에서', 'JKB'), ('일', 'NNG'), ('을', 'JKO'), ('합니다', 'VV+EF'), ('.', 'SF')]
# [('아이오아이', 'NNP'), ('는', 'JX'), ('정말', 'MAG'), ('이뻐요', 'VA+EF'), ('.', 'SF')]

# %% [markdown]
# # Add Dict

# %% [markdown]
# ### Data Load

# %%
import sys
sys.path.append('/content/drive/MyDrive/MemeProject/src/comparison')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/MemeProject/src/comparison']

# %%
import swifter
import config as cfg
from pprint import pprint
from pshmodule.utils import filemanager as fm

# %%
df = fm.load(cfg.origin_ref)
# Out:
# extension : .pickle
# Loaded 181704 records from /content/drive/MyDrive/MemeProject/data/origin_ref.pickle

# %%
df.head()
# Out:
#   num g_num u_num                u  \
# 0   1     1     1  나 중간고사 반에서 1등했어
# 1   1     1     1  나 중간고사 반에서 1등했어
# 2   1     1     1  나 중간고사 반에서 1등했어
# 3   1     1     1  나 중간고사 반에서 1등했어
# 4   1     1     1  나 중간고사 반에서 1등했어
#
#                                           meme  arg1 arg_op1 arg_op2
# 0           그렇다면 통 크게 함 쏴야지! 근데 이제 내 것도 곁들인...  중간고사
# 1     그렇다면 통 크게 함 쏴야지! 근데 이제 내 몫을 제일 많이 곁들인...  중간고사
# 2         그렇다면 통 크게 함 쏴야지! 근데 이제 대춘이 몫도 곁들인...  중간고사
# 3  그렇다면 통 크게 함 쏴야지! 근데 이제 배보다 배꼽이 더 큰 걸 곁들인...  중간고사
# 4           그렇다면 통 크게 함 쏴야지! 근데 이제 과소비를 곁들인...  중간고사

# %%
df = df[['u']]
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
# Out:
# <ipython-input-11-4ddb929274bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
user_dict = fm.load(cfg.user_dict)
# Out:
# extension : .xlsx
# Loaded 5103 records from /content/drive/MyDrive/MemeProject/data/user_dict/UGCD.xlsx
# /usr/local/lib/python3.8/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### User Dictionary

# %% [markdown]
# #### Dict

# %%
user_dict_2 = user_dict[5:]
user_dict_2.columns = user_dict.iloc[5]
user_dict_2.reset_index(drop=True, inplace=True)

# %%
user_dict_2 = user_dict_2[1:]
user_dict_2 = user_dict_2[['표제어', '기본형', '품사', '감정1', '연령', '용례', '반의어']]
user_dict_2.rename(columns={'표제어':'lemma', '기본형':'formal', '품사':'pos', '감정1':'sentiment', '연령':'age', '용례':'example', '반의어':'antonym'}, inplace=True)
user_dict_2.reset_index(drop=True, inplace=True)

# %%
user_dict_2.head(10)
# Out:
# 5    lemma formal pos sentiment  age           example antonym
# 0      가지다    가지다  VV       Neu  NaN         그거 내가 가진다     버리다
# 1       갖다    가지다  VV       Neu  NaN      이 지갑은 내가 갖는다     버리다
# 2   내 거 하다    가지다  VV       Hap   MZ        걔 내 거 할 거야     NaN
# 3     소유하다    가지다  VV       Hap  NaN     그 신발은 이미 소유했어     버리다
# 4     보유하다    가지다  VV       Hap  NaN  나도 그 아이템 보유하고 싶어     버리다
# 5      겟하다    가지다  VV       Hap   MZ           드디어 겟했다     버리다
# 6     겟또하다    가지다  VV       Hap   MZ          피규어 겟또했음     버리다
# 7     득템하다    가지다  VV       Hap   MZ          신상템 득템했다     버리다
# 8  굴러들어 오다    가지다  VV       Hap  NaN      꽁돈이 굴러들어 왔음!     NaN
# 9    손에 넣다    가지다  VV       Hap  NaN    한정판 운동화 손에 넣었다     NaN

# %%
user_dict_2.shape
# Out:
# (5097, 7)

# %%
user_dict_3 = user_dict_2[~user_dict_2.lemma.isnull()]

# %%
user_dict_3.shape
# Out:
# (3315, 7)

# %%
user_dict_3.pos.value_counts()
# Out:
# VV     1398
# NN     1234
# VA      308
# MAG     154
# NNP      82
# IC       74
# EO       46
# NP       17
# MM        2
# Name: pos, dtype: int64

# %% [markdown]
# #### Tag Mapping

# %% [markdown]
# Okt

# %%
def okt(pos):
  result = ""
  if pos in ['NN', 'NNP', 'NR', 'NP']:
    result = "Noun" # 명사
  elif pos == "VV":
    result = "Verb" # 동사
  elif pos == "VA":
    result = "Adjective" # 형용사
  elif pos == "MM":
    result = "Determiner" # 관형사
  elif pos in ['MAG', 'MAJ']:
    result = "Adverb" # 부사
  elif pos == "IC":
    result = "Exclamation" # 감탄사
  elif pos == "JO":
    result = "Josa" # 조사
  elif pos == "EO":
    result = "Eomi" # 어미
  return result

# %%
user_dict_3['okt_pos'] = user_dict_3.pos.swifter.apply(okt)
# Out:
# Pandas Apply:   0%|          | 0/3315 [00:00<?, ?it/s]
# <ipython-input-21-780ddc5911d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_dict_3['okt_pos'] = user_dict_3.pos.swifter.apply(okt)

# %%
user_dict_3.head()
# Out:
# 5   lemma formal pos sentiment  age           example antonym okt_pos
# 0     가지다    가지다  VV       Neu  NaN         그거 내가 가진다     버리다    Verb
# 1      갖다    가지다  VV       Neu  NaN      이 지갑은 내가 갖는다     버리다    Verb
# 2  내 거 하다    가지다  VV       Hap   MZ        걔 내 거 할 거야     NaN    Verb
# 3    소유하다    가지다  VV       Hap  NaN     그 신발은 이미 소유했어     버리다    Verb
# 4    보유하다    가지다  VV       Hap  NaN  나도 그 아이템 보유하고 싶어     버리다    Verb

# %% [markdown]
# Mecab

# %%
def mecab(pos):
  result = ""
  if pos == "NN":
    result = "NNG" # 일반 명사
  elif pos == "NNP":
    result = "NNP" # 고유 명사
  elif pos == "NR":
    result = "NR" # 수사
  elif pos == "NP":
    result = "NP" # 대명사
  elif pos == "VV":
    result = "VV" # 동사
  elif pos == "VA":
    result = "VA" # 형용사
  elif pos == "MM":
    result = "MM" # 관형사
  elif pos == "MAG":
    result = "MAG" # 일반부사
  elif pos == "MAJ":
    result = "MAJ" # 접속부사
  elif pos == "IC":
    result = "IC" # 감탄사
  elif pos == "JO":
    result = "JKS" # 조사
  return result

# %%
user_dict_3['mecab_pos'] = user_dict_3.pos.swifter.apply(mecab)
# Out:
# Pandas Apply:   0%|          | 0/3315 [00:00<?, ?it/s]
# <ipython-input-24-ed5046f81635>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_dict_3['mecab_pos'] = user_dict_3.pos.swifter.apply(mecab)

# %% [markdown]
# #### Add Dict

# %% [markdown]
# ##### Okt

# %% [markdown]
# test

# %%
import konlpy
konlpy.data.path
# Out:
# ['/root/konlpy_data',
#  '/usr/share/konlpy_data',
#  '/usr/local/share/konlpy_data',
#  '/usr/lib/konlpy_data',
#  '/usr/local/lib/konlpy_data',
#  '/usr/local/lib/python3.8/dist-packages/konlpy/data']

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
user_dict_3.pos.value_counts()
# Out:
# VV     1398
# NN     1234
# VA      308
# MAG     154
# NNP      82
# IC       74
# EO       46
# NP       17
# MM        2
# Name: pos, dtype: int64

# %%
user_dict_3[user_dict_3.pos=='VA']
# Out:
# 5           lemma formal pos sentiment  age                  example antonym  \
# 30            귀엽다    귀엽다  VA       Hap  NaN                    나 귀여워     NaN
# 31        쏘 러블리하다    귀엽다  VA       Hap   MZ                 너 쏘 러블리해     NaN
# 32          존귀탱이다    귀엽다  VA       Hap   MZ                   님 존귀탱임     NaN
# 33         쏘 큐트하다    귀엽다  VA       Hap   MZ                 얘 쏘 큐트하다     NaN
# 34        초 카와이하다    귀엽다  VA       Hap   MZ                이거 초 카와이해     NaN
# ...           ...    ...  ..       ...  ...                      ...     ...
# 3241       눈물버튼이다    슬프다  VA       Sad   MZ             이거 내 눈물버튼인데.     NaN
# 3242         비상이다    슬프다  VA       Sad   MZ            비상이다... 비상...     NaN
# 3265          꾸꾸꾸    꾸꾸꾸  VA       Dis   MZ                뭘 해도 꾸꾸꾸다     NaN
# 3266  꾸며도 꾸질 꾸질하다    꾸꾸꾸  VA       Dis   MZ  내 주변에 꾸며도 꾸질 꾸질한 사람 있음ㅋ     NaN
# 3295         빼박캔트    못하다  VA       Sad   MZ             빼박캔트 개강이라는 것     NaN
#
# 5       okt_pos mecab_pos
# ...

# %%
print(okt.pos('핸드폰을 겟또하다.'))
print(okt.pos('동전을 득템하다.'))
print(okt.pos('가상화폐를 살거야'))
print(okt.pos('틀니딱딱 거리지마~'))
print(okt.pos('엄마가 젤루 좋아'))
print(okt.pos('이번엔 틀림없이 합격할 거야'))
print(okt.pos('쏘 러블리하다'))
# Out:
# [('핸드폰', 'Noun'), ('을', 'Josa'), ('겟또하다', 'Verb'), ('.', 'Punctuation')]
# [('동전', 'Noun'), ('을', 'Josa'), ('득템하다', 'Verb'), ('.', 'Punctuation')]
# [('가상화폐', 'Noun'), ('를', 'Josa'), ('살거야', 'Verb')]
# [('틀니딱딱', 'Noun'), ('거리', 'Noun'), ('지', 'Josa'), ('마', 'Noun'), ('~', 'Punctuation')]
# [('엄마', 'Noun'), ('가', 'Josa'), ('젤루', 'Adverb'), ('좋아', 'Adjective')]
# [('이번', 'Noun'), ('엔', 'Josa'), ('틀림없이', 'Adverb'), ('합격', 'Noun'), ('할', 'Verb'), ('거야', 'Eomi')]
# [('쏘', 'Verb'), ('러블리하다', 'Adjective')]

# %% [markdown]
# add dict

# %%
import os

os.chdir('/usr/local/lib/python3.8/dist-packages/konlpy/java')
os.getcwd()
# Out:
# '/usr/local/lib/python3.8/dist-packages/konlpy/java'

# %%
# !ls
# Out:
# aho-corasick.jar     kkma-2.0.jar		 shineware-common-1.0.jar
# bin		     komoran-3.0.jar		 shineware-ds-1.0.jar
# conf		     META-INF			 snakeyaml-1.12.jar
# data		     open-korean-text-2.1.0.jar  twitter-text-1.14.7.jar
# jhannanum-0.8.4.jar  scala-library-2.12.3.jar

# %%
# !jar xvf open-korean-text-2.1.0.jar
# Out:
#   created: META-INF/
#  inflated: META-INF/MANIFEST.MF
#   created: org/
#   created: org/openkoreantext/
#   created: org/openkoreantext/processor/
#   created: org/openkoreantext/processor/stemmer/
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer$.class
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer.class
#   created: org/openkoreantext/processor/util/
#  inflated: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie$.class
#   created: org/openkoreantext/processor/util/verb/
#  inflated: org/openkoreantext/processor/util/verb/eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/pre_eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/verb_prefix.txt
#  inflated: org/openkoreantext/processor/util/verb/verb.txt
#  inflated: org/openkoreantext/processor/util/example_tweets.txt
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EntrySet.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils.class
# ...

# %%
user_dict_3.okt_pos.value_counts()
# Out:
# Verb           1398
# Noun           1333
# Adjective       308
# Adverb          154
# Exclamation      74
# Eomi             46
# Determiner        2
# Name: okt_pos, dtype: int64

# %%
paths = {
    'noun/nouns.txt':'Noun',
    'verb/verb.txt':'Verb',
    'adjective/adjective.txt':'Adjective',
    'adverb/adverb.txt':'Adverb',
    'josa/josa.txt':'Josa',
    'auxiliary/exclamation.txt':'Exclamation',
    'verb/eomi.txt':'Eomi',
    'auxiliary/determiner.txt':'Determiner'
}

# %%
for p in paths:
  with open(f"/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/{p}") as f:
    data = f.read()
  data += '\n'.join(map(str, user_dict_3[user_dict_3.okt_pos == paths[p]].lemma.tolist())) + '\n'

  with open(f"/usr/local/lib/python3.8/dist-packages/konlpy/java/org/openkoreantext/processor/util/{p}", 'w') as f:
    f.write(data)
  data = ""

# %%
# !ls /usr/local/lib/python3.8/dist-packages/konlpy/java
# Out:
# aho-corasick.jar     kkma-2.0.jar		 scala-library-2.12.3.jar
# bin		     komoran-3.0.jar		 shineware-common-1.0.jar
# conf		     META-INF			 shineware-ds-1.0.jar
# data		     open-korean-text-2.1.0.jar  snakeyaml-1.12.jar
# jhannanum-0.8.4.jar  org			 twitter-text-1.14.7.jar

# %%
# !rm open-korean-text-2.1.0.jar
# !jar cvf open-korean-text-2.1.0.jar org
# !rm -rf org

# %% [markdown]
# check

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
print(f"겟또하다 Verb : {okt.pos('핸드폰을 겟또하다.')}")
print(f"득템하다 Verb : {okt.pos('동전을 득템하다.')}")
print(f"가상화폐 Noun : {okt.pos('가상화폐를 살거야')}")
print(f"틀니딱딱 Noun : {okt.pos('틀니딱딱 거리지마~')}")
print(f"젤루 Adverb : {okt.pos('엄마가 젤루 좋아')}")
print(f"틀림없이 Adverb : {okt.pos('이번엔 틀림없이 합격할 거야')}")
print(f"쏘 러블리하다 Adjective : {okt.pos('쏘 러블리하다')}")
# Out:
# 겟또하다 Verb : [('핸드폰', 'Noun'), ('을', 'Josa'), ('겟또하다', 'Verb'), ('.', 'Punctuation')]
# 득템하다 Verb : [('동전', 'Noun'), ('을', 'Josa'), ('득템하다', 'Verb'), ('.', 'Punctuation')]
# 가상화폐 Noun : [('가상화폐', 'Noun'), ('를', 'Josa'), ('살거야', 'Verb')]
# 틀니딱딱 Noun : [('틀니딱딱', 'Noun'), ('거리', 'Noun'), ('지', 'Josa'), ('마', 'Noun'), ('~', 'Punctuation')]
# 젤루 Adverb : [('엄마', 'Noun'), ('가', 'Josa'), ('젤루', 'Adverb'), ('좋아', 'Adjective')]
# 틀림없이 Adverb : [('이번', 'Noun'), ('엔', 'Josa'), ('틀림없이', 'Adverb'), ('합격', 'Noun'), ('할', 'Verb'), ('거야', 'Eomi')]
# 쏘 러블리하다 Adjective : [('쏘', 'Verb'), ('러블리하다', 'Adjective')]

# %% [markdown]
# ##### Customized KoNLPy

# %% [markdown]
# test

# %%
# !pip install customized_konlpy

# %%
from ckonlpy.tag import Twitter

# %%
twitter = Twitter()

# %%
twitter.add_dictionary('피규어', 'Noun')
twitter.add_dictionary('소유하다', 'Verb')
twitter.add_dictionary('쏘 러블리하다', 'Adjective')
twitter.add_dictionary('드르륵 탁', 'Adverb')
twitter.add_dictionary('고고싱', 'Exclamation')
twitter.add_dictionary('테닷', 'Eomi')
twitter.add_dictionary('새', 'Determiner')

# %% [markdown]
# check

# %%
print(twitter.pos("피규어를 겟또하다."))
print(twitter.pos("피규어를 소유하다"))
print(twitter.pos("쏘 러블리하다"))
print(twitter.pos("날 추앙해요. 드르륵 탁. 날 추앙해요. 드르륵 탁."))
print(twitter.pos("가즈아 고고싱"))
print(twitter.pos("꼭 올백 맞을 테닷!"))
print(twitter.pos("오늘은 새 옷을 입고 나갈 거야"))
# Out:
# [('피규어', 'Noun'), ('를', 'Josa'), ('겟또하다', 'Verb'), ('.', 'Punctuation')]
# [('피규어', 'Noun'), ('를', 'Josa'), ('소', 'Noun'), ('유하', 'Noun'), ('다', 'Josa')]
# [('쏘', 'Verb'), ('러블', 'Noun'), ('리하', 'Noun'), ('다', 'Josa')]
# [('날', 'Noun'), ('추앙', 'Noun'), ('해', 'Josa'), ('요', 'Noun'), ('.', 'Punctuation'), ('드르륵', 'Adverb'), ('탁', 'Noun'), ('.', 'Punctuation'), ('날', 'Noun'), ('추앙', 'Noun'), ('해', 'Josa'), ('요', 'Noun'), ('.', 'Punctuation'), ('드르륵', 'Adverb'), ('탁', 'Noun'), ('.', 'Punctuation')]
# [('가즈아', 'Verb'), ('고고싱', 'Noun')]
# [('꼭', 'Noun'), ('올백', 'Noun'), ('맞을', 'Verb'), ('테닷', 'Eomi'), ('!', 'Punctuation')]
# [('오늘', 'Noun'), ('은', 'Josa'), ('새', 'Noun'), ('옷', 'Noun'), ('을', 'Josa'), ('입고', 'Verb'), ('나갈', 'Verb'), ('거야', 'Eomi')]

# %% [markdown]
# ##### Mecab

# %% [markdown]
# test

# %%
from konlpy.tag import Mecab

m = Mecab()

# %%
print(m.pos("피규어를 겟또하다."))
print(m.pos("피규어를 득템하다."))
print(m.pos("가상화폐를 살거야"))
print(m.pos("비트코인 살거야"))
print(m.pos("틀니딱딱 거리지마~"))
print(m.pos("깨물어뜨리다"))
# Out:
# [('피', 'XPN'), ('규', 'NNG'), ('어', 'NNG'), ('를', 'JKO'), ('겟', 'NNP'), ('또', 'MAG'), ('하', 'VV'), ('다', 'EF'), ('.', 'SF')]
# [('피', 'XPN'), ('규', 'NNG'), ('어', 'NNG'), ('를', 'JKO'), ('득템', 'NNG'), ('하', 'XSV'), ('다', 'EF'), ('.', 'SF')]
# [('가상', 'NNG'), ('화폐', 'NNG'), ('를', 'JKO'), ('살', 'VV+ETM'), ('거', 'NNB'), ('야', 'VCP+EF')]
# [('비트코인', 'NNP'), ('살', 'VV+ETM'), ('거', 'NNB'), ('야', 'VCP+EF')]
# [('틀니', 'NNG'), ('딱딱', 'MAG'), ('거리', 'NNG'), ('지마', 'NNG'), ('~', 'SY')]
# [('깨물어뜨리', 'VV'), ('다', 'EC')]

# %% [markdown]
# Add Dict

# %%
# !pip3 install jamo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from jamo import h2j, j2hcj

def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF

# %%
paths = {
    'NNG.csv':'NNG',
    'NNP.csv':'NNP',
    'NR.csv':'NR',
    'NP.csv':'NP',
    'VV.csv':'VV',
    'VA.csv':'VA',
    'MM.csv':'MM',
    'MAG.csv':'MAG',
    'MAJ.csv':'MAJ',
    'IC.csv':'IC',
    'J.csv':'JO',
}

# %%
for p in paths:
  with open(f'/tmp/mecab-ko-dic-2.1.1-20180720/{p}', "r", encoding='utf-8') as f:
    user_dict = f.readlines()

# %%
user_dict_3[user_dict_3.mecab_pos=='NNG']
# Out:
# 5     lemma formal pos sentiment  age           example antonym okt_pos  \
# 69     가상화폐   가상화폐  NN       Neu  NaN      가상화폐 좀 만져볼까?     NaN    Noun
# 70       코인   가상화폐  NN       Neu  NaN       이제 코인 시작해야지     NaN    Noun
# 71     암호화페   가상화폐  NN       Neu  NaN      암호화폐로 재산 날렸어     NaN    Noun
# 72     비트코인   가상화폐  NN       Neu  NaN        나도 비트코인 샀어     NaN    Noun
# 73     도지코인   가상화폐  NN       Neu  NaN       도지코인 시세 머선일     NaN    Noun
# ...     ...    ...  ..       ...  ...               ...     ...     ...
# 3317    틀딱충     틀딱  NN       Dis   MZ         저 아재 틀딱충임     NaN    Noun
# 3318   틀니딱딱     틀딱  NN       Dis   MZ           틀니딱딱 극혐     NaN    Noun
# 3319  틀니딱딱충     틀딱  NN       Dis   MZ  이 정도면 틀니딱딱충 아니냐?     NaN    Noun
# 3323     흑형     흑인  NN       Neu   MZ       개간지 나는 흑형 봄     NaN    Noun
# 3324    흑언니     흑인  NN       Neu   MZ        흑언니 진짜 멋져잉     NaN    Noun
#
# 5    mecab_pos
# 69         NNG
# 70         NNG
# 71         NNG
# 72         NNG
# 73         NNG
# ...

# %%
# 단어 추가
add_list = ['순댓국', '순대국', '아이오아이', '패스트파이브']

for word in add_list:
  jongsung_TF = get_jongsung_TF(word)
  line = '{},*,*,*,NNP,*,{},{},*,*,*,*,*\n'.format(word, jongsung_TF, word)

  user_dict.append(line)

# %%
user_dict[-10:]

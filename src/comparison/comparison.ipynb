# %% [markdown]
# # install

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Dec 13 06:58:45 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    50W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !pip3 install swifter

# %%
# !pip3 install pshmodule

# %%
# !pip3 install pickle5

# %%
# !pip3 install pandas==1.5.0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ##### okt, mecab

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %% [markdown]
# ##### pororo

# %% [markdown]
# # Data Load

# %%
import sys
sys.path.append('/content/drive/MyDrive/MemeProject/src/comparison')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/MemeProject/src/comparison']

# %%
import swifter
import config
from pprint import pprint
import pandas as pd
from pshmodule.utils import filemanager as fm

# %%
df = fm.load(config.origin_data)
# df = fm.load(config.origin_data_local)
# Out:
# extension : .pickle
# Loaded 10317 records from /Volumes/GoogleDrive/내 드라이브/MemeProject/data/temp_for_doc2vec.pickle

# %%
df = df[['content']]

# %%
df.head()
# Out:
#                   content
# 0         나 중간고사 반에서 1등했어
# 1  중간고사 점수 내가 반에서 제일 잘 받음
# 2       나 반에서 중간 성적 제일 좋아
# 3    우리 반에서 내가 시험 제일 잘 봤다
# 4            중간고사 반 1등 먹음

# %%
# fm.save(config.origin_excel_local, df)
# Out:
# Saved 10317 records

# %% [markdown]
# # Tokenizer

# %% [markdown]
# # Pororo

# %% [markdown]
# ##### install

# %%
# !pip install pip==20.0.2 pororo fairseq==0.10.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pip==20.0.2
#   Downloading pip-20.0.2-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 4.8 MB/s
# Collecting pororo
#   Using cached pororo-0.4.2-py3-none-any.whl (256 kB)
# Collecting fairseq==0.10.2
#   Downloading fairseq-0.10.2-cp38-cp38-manylinux1_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 57.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from fairseq==0.10.2) (1.21.6)
# Collecting hydra-core
#   Downloading hydra_core-1.3.0-py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 78.7 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.8/dist-packages (from fairseq==0.10.2) (0.29.32)
# Requirement already satisfied: cffi in /usr/local/lib/python3.8/dist-packages (from fairseq==0.10.2) (1.15.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from fairseq==0.10.2) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from fairseq==0.10.2) (4.64.1)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from fairseq==0.10.2) (1.13.0+cu116)
# Collecting sacrebleu>=1.4.12
#   Using cached sacrebleu-2.3.1-py3-none-any.whl (118 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from sacrebleu>=1.4.12->fairseq==0.10.2) (4.9.1)
# Collecting portalocker
#   Using cached portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.8/dist-packages (from sacrebleu>=1.4.12->fairseq==0.10.2) (0.8.10)
# Collecting whoosh
#   Using cached Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
# Collecting torch
#   Using cached torch-1.6.0-cp38-cp38-manylinux1_x86_64.whl (748.8 MB)
# Requirement already satisfied: nltk>=3.5 in /usr/local/lib/python3.8/dist-packages (from pororo) (3.7)
# Collecting word2word
#   Using cached word2word-1.0.0-py3-none-any.whl (31 kB)
# Collecting marisa-trie
#   Using cached marisa_trie-0.7.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from pororo) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from pororo) (1.2.0)
# Collecting kss
#   Using cached kss-3.7.3.tar.gz (42.4 MB)
# Collecting wget
#   Using cached wget-3.2.zip (10 kB)
# Collecting torchvision==0.7.0
#   Using cached torchvision-0.7.0-cp38-cp38-manylinux1_x86_64.whl (5.9 MB)
# Collecting sentence-transformers>=0.4.1.2
#   Using cached sentence-transformers-2.2.2.tar.gz (85 kB)
# Collecting g2p-en
#   Using cached g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
# Collecting transformers>=4.0.0
#   Using cached transformers-4.25.1-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from torch->fairseq==0.10.2) (0.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.5->pororo) (7.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1.2->pororo) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1.2->pororo) (1.7.3)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting huggingface-hub>=0.4.0
#   Using cached huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (3.0.9)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi->fairseq==0.10.2) (2.21)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      |████████████████████████████████| 180 kB 98.1 MB/s
# Requirement already satisfied: inflect>=0.3.1 in /usr/local/lib/python3.8/dist-packages (from g2p-en->pororo) (2.1.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from hydra-core->fairseq==0.10.2) (5.10.0)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.9 MB/s
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 101.2 MB/s
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources->hydra-core->fairseq==0.10.2) (3.11.0)
# Collecting emoji==1.2.0
#   Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 86.5 MB/s
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.8/dist-packages (from kss->pororo) (9.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from marisa-trie->pororo) (57.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1.2->pororo) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sentence-transformers>=0.4.1.2->pororo) (3.1.0)
# Building wheels for collected packages: sentence-transformers, distance, antlr4-python3-runtime, kss, wget
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=61dee2646c94349c3bda34f802812e50ba6865f794f368b8e355c95324b1dff2
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16275 sha256=ceaeb7e40a29e8b5cd4b046113541ebe5648d9cdad1ce25e3b57240172cbb9cb
#   Stored in directory: /root/.cache/pip/wheels/fb/a8/64/6edcab63ec51512a87cacf9b3563c711ad6b7b05d61b704493
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=688d97ecdb05fe1c7036af1fea850e762fd052471ede4759c9734ee9e8e7ed2c
#   Stored in directory: /root/.cache/pip/wheels/b1/a3/c2/6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
#   Building wheel for kss (setup.py) ... done
#   Created wheel for kss: filename=kss-3.7.3-py3-none-any.whl size=42449195 sha256=8ab2c4704232208bccfe9d0463f9bace0427f5879cb3e50a23d33b0d9e12045a
#   Stored in directory: /root/.cache/pip/wheels/21/ae/be/1795119115db76f9824f02c419582c5c14dc4a6e8f144337a2
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=232fc9347339bc4cf259def689b6fe774a7d830ef1d46b4cffef7dde853f2350
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built sentence-transformers distance antlr4-python3-runtime kss wget
# Installing collected packages: antlr4-python3-runtime, torch, tokenizers, portalocker, omegaconf, huggingface-hub, colorama, wget, transformers, torchvision, sentencepiece, sacrebleu, hydra-core, emoji, distance, dataclasses, word2word, whoosh, sentence-transformers, marisa-trie, kss, g2p-en, fairseq, pororo, pip
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0+cu116
#     Uninstalling torchvision-0.14.0+cu116:
#       Successfully uninstalled torchvision-0.14.0+cu116
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.3
#     Uninstalling pip-21.1.3:
#       Successfully uninstalled pip-21.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.6.0 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.6.0 which is incompatible.
# pip-tools 6.2.0 requires pip>=20.3, but you have pip 20.0.2 which is incompatible.
# fastai 2.7.10 requires torch<1.14,>=1.7, but you have torch 1.6.0 which is incompatible.
# fastai 2.7.10 requires torchvision>=0.8.2, but you have torchvision 0.7.0 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 colorama-0.4.6 dataclasses-0.6 distance-0.1.3 emoji-1.2.0 fairseq-0.10.2 g2p-en-2.1.0 huggingface-hub-0.11.1 hydra-core-1.3.0 kss-3.7.3 marisa-trie-0.7.8 omegaconf-2.3.0 pip-20.0.2 pororo-0.4.2 portalocker-2.6.0 sacrebleu-2.3.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 torch-1.6.0 torchvision-0.7.0 transformers-4.25.1 wget-3.2 whoosh-2.7.4 word2word-1.0.0

# %%
# #Uninstall the current CUDA version
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update

# %%
# # install cuda 10.1
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# !sudo mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !sudo apt-key adv --fetch-keys https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/7fa2af80.pub
# !sudo add-apt-repository "deb https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/ /"
# !apt-get update
# !apt-get -y install cuda-10.1

# %%
# !pip uninstall torch torchvision
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cpu
# !pip install pytorch==1.6.0 torchvision==0.7.0 cpuonly -c pytorch
# Out:
# Found existing installation: torch 1.6.0
# Uninstalling torch-1.6.0:
#   Would remove:
#     /usr/local/bin/convert-caffe2-to-onnx
#     /usr/local/bin/convert-onnx-to-caffe2
#     /usr/local/lib/python3.8/dist-packages/caffe2/*
#     /usr/local/lib/python3.8/dist-packages/torch-1.6.0.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/torch/*
# Proceed (y/n)? y
#   Successfully uninstalled torch-1.6.0
# Found existing installation: torchvision 0.7.0
# Uninstalling torchvision-0.7.0:
#   Would remove:
#     /usr/local/lib/python3.8/dist-packages/torchvision-0.7.0.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/torchvision/*
# Proceed (y/n)? y
#   Successfully uninstalled torchvision-0.7.0
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'pytorch'

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %% [markdown]
# # 런타임 다시 시작

# %%
import torch
print("Torch version:{}".format(torch.__version__))
print("cuda version: {}".format(torch.version.cuda))
print("cudnn version:{}".format(torch.backends.cudnn.version()))
# Out:
# Torch version:1.6.0
# cuda version: 10.2
# cudnn version:7605

# %%
# !nvidia-smi
# Out:
# Tue Dec 13 08:28:57 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   28C    P0    49W / 400W |   1006MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from pororo import Pororo

# %%
Pororo.available_models("dp")
dp = Pororo(task="dep_parse", lang="ko")
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:125: UserWarning:
# A100-SXM4-40GB with CUDA capability sm_80 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_37 sm_50 sm_60 sm_70 sm_75.
# If you want to use the A100-SXM4-40GB GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(incompatible_device_warn.format(device_name, capability, " ".join(arch_list), device_name))

# %%
print(dp('저는 개인적으로 하자면 저도 아홉시까지 일하고 6천을 받자 입니다.'))
print(dp('왜냐하면 저는 평일보다는 주말에 가치를 두는 사람이고요 제 여가 시간 저의 삶 중에서 약간 즐겁고 해피하고 긍정적인 시간은 보통 주말로 몰고 평일은 그냥 나를 성장하고'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-bac2bea45ddc> in <module>
# ----> 1 print(dp('저는 개인적으로 하자면 저도 아홉시까지 일하고 6천을 받자 입니다.'))
#       2 print(dp('왜냐하면 저는 평일보다는 주말에 가치를 두는 사람이고요 제 여가 시간 저의 삶 중에서 약간 즐겁고 해피하고 긍정적인 시간은 보통 주말로 몰고 평일은 그냥 나를 성장하고'))
#
# /usr/local/lib/python3.8/dist-packages/pororo/tasks/utils/base.py in __call__(self, text, **kwargs)
#     111
#     112     def __call__(self, text: str, **kwargs):
# --> 113         return self.predict(text, **kwargs)
#     114
#     115
#
# /usr/local/lib/python3.8/dist-packages/pororo/tasks/dependency_parsing.py in predict(self, sent, **kwargs)
#     164         """
#     165         tokens, tags = self._preprocess(sent)
# --> 166         heads, labels = self._model.predict_dependency(tokens, tags)
#     167         heads = [int(head) - 1 for head in heads]  # due to default <s> token
#     168         return self._postprocess(sent, tokens, heads, labels)
#
# /usr/local/lib/python3.8/dist-packages/pororo/models/brainbert/PoSLaBERTa.py in predict_dependency(self, tokens, segments)
#     111         masks = masks.to(device=self.device)
#     112
# --> 113         features = self.extract_features(
#     114             tokens.to(device=self.device),
#     115             segments.to(device=self.device),
#
# /usr/local/lib/python3.8/dist-packages/pororo/models/brainbert/PoSLaBERTa.py in extract_features(self, tokens, segments, return_all_hiddens)
#      59             raise ValueError("tokens exceeds maximum length: {} > {}".format(
#      60                 tokens.size(-1), self.model.max_positions()))
# ---> 61         features, extra = self.model(
#      62             tokens.to(device=self.device),
#      63             segments.to(device=self.device),
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/pororo/models/brainbert/PoSLaBERTa.py in forward(self, src_tokens, seg_tokens, features_only, return_all_hiddens, classification_head_name, **kwargs)
#     267             features_only = True
#     268
# --> 269         x, extra = self.decoder(
#     270             src_tokens,
#     271             seg_tokens,
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/pororo/models/brainbert/PoSLaBERTa.py in forward(self, src_tokens, seg_tokens, features_only, return_all_hiddens, masked_tokens, **unused)
#     438                   states have shape `(src_len, batch, vocab)`.
#     439         """
# --> 440         x, extra = self.extract_features(
#     441             src_tokens,
#     442             seg_tokens,
#
# /usr/local/lib/python3.8/dist-packages/pororo/models/brainbert/PoSLaBERTa.py in extract_features(self, src_tokens, seg_tokens, return_all_hiddens, **kwargs)
#     454         **kwargs,
#     455     ):
# --> 456         inner_states, _ = self.sentence_encoder(
#     457             src_tokens,
#     458             seg_tokens,
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/fairseq/modules/transformer_sentence_encoder.py in forward(self, tokens, segment_labels, last_state_only, positions, token_embeddings)
#     234
#     235         # compute padding mask. This is needed for multi-head attention
# --> 236         padding_mask = tokens.eq(self.padding_idx)
#     237         if not self.traceable and not self.tpu and not padding_mask.any():
#     238             padding_mask = None
#
# RuntimeError: CUDA error: no kernel image is available for execution on the device

# %% [markdown]
# # okt

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
"""
근데 조금 궁금한 게 있는데 연봉 3천과 6천을 월 실수량으로 바꾸면 어느 정도인 줄
알 수 있을까요?
그 정도 되나요? 60
어느 정도
6천 만원이요 얼마죠?
450에 아홉시 퇴근..
"""

okt.phrases('근데 조금 궁금한 게 있는데 연봉 3천과 6천을 월 실수량으로 바꾸면 어느 정도인 줄')
# Out:
# ['조금', '조금 궁금한 게', '연봉', '연봉 3천', '6천', '월 실수량', '정도', '3천', '수량']

# %%
df['pos'] = df.content.swifter.apply(lambda x: okt.pos(str(x)))
# Out:
# Pandas Apply:   0%|          | 0/10317 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#                   content                                                pos
# 0         나 중간고사 반에서 1등했어  [(나, Noun), (중간고사, Noun), (반, Noun), (에서, Josa...
# 1  중간고사 점수 내가 반에서 제일 잘 받음  [(중간고사, Noun), (점수, Noun), (내, Noun), (가, Josa...
# 2       나 반에서 중간 성적 제일 좋아  [(나, Noun), (반, Noun), (에서, Josa), (중간, Noun),...
# 3    우리 반에서 내가 시험 제일 잘 봤다  [(우리, Noun), (반, Noun), (에서, Josa), (내, Noun),...
# 4            중간고사 반 1등 먹음  [(중간고사, Noun), (반, Noun), (1등, Number), (먹음, N...

# %% [markdown]
# ##### change shape

# %%
result = []
for row in df.iterrows():
  for i in row[1]['pos']:
    temp = []
    temp.append(row[1]['content'])
    temp.append(i)
    result.append(temp)

# %%
pprint(result[:10])
# Out:
# [['나 중간고사 반에서 1등했어', ('나', 'Noun')],
#  ['나 중간고사 반에서 1등했어', ('중간고사', 'Noun')],
#  ['나 중간고사 반에서 1등했어', ('반', 'Noun')],
#  ['나 중간고사 반에서 1등했어', ('에서', 'Josa')],
#  ['나 중간고사 반에서 1등했어', ('1등', 'Number')],
#  ['나 중간고사 반에서 1등했어', ('했어', 'Foreign')],
#  ['중간고사 점수 내가 반에서 제일 잘 받음', ('중간고사', 'Noun')],
#  ['중간고사 점수 내가 반에서 제일 잘 받음', ('점수', 'Noun')],
#  ['중간고사 점수 내가 반에서 제일 잘 받음', ('내', 'Noun')],
#  ['중간고사 점수 내가 반에서 제일 잘 받음', ('가', 'Josa')]]

# %%
df_okt = pd.DataFrame(result, columns=['origin', 'token'])

# %%
df_okt['token1'] = df_okt.token.apply(lambda x: x[0])
df_okt['token2'] = df_okt.token.apply(lambda x: x[1])

# %%
df_okt = df_okt[['origin', 'token1', 'token2']]
df_okt.rename(columns={'origin':'유저 발화', 'token1':'토큰', 'token2':'품사'}, inplace=True)

# %%
df_okt.head()
# Out:
#              유저 발화    토큰      품사
# 0  나 중간고사 반에서 1등했어     나    Noun
# 1  나 중간고사 반에서 1등했어  중간고사    Noun
# 2  나 중간고사 반에서 1등했어     반    Noun
# 3  나 중간고사 반에서 1등했어    에서    Josa
# 4  나 중간고사 반에서 1등했어    1등  Number

# %% [markdown]
# # mecab

# %%
# import config
from konlpy.tag import Mecab

# %%
m = Mecab()

# %%
help(m)
# Out:
# Help on Mecab in module konlpy.tag._mecab object:
#
# class Mecab(builtins.object)
#  |  Mecab(dicpath='/usr/local/lib/mecab/dic/mecab-ko-dic')
#  |
#  |  Wrapper for MeCab-ko morphological analyzer.
#  |
#  |  `MeCab`_, originally a Japanese morphological analyzer and POS tagger
#  |  developed by the Graduate School of Informatics in Kyoto University,
#  |  was modified to MeCab-ko by the `Eunjeon Project`_
#  |  to adapt to the Korean language.
#  |
#  |  In order to use MeCab-ko within KoNLPy, follow the directions in
#  |  :ref:`optional-installations`.
#  |
#  |  .. code-block:: python
#  |      :emphasize-lines: 1
#  |
#  |      >>> # MeCab installation needed
#  |      >>> from konlpy.tag import Mecab
#  |      >>> mecab = Mecab()
#  |      >>> print(mecab.morphs(u'영등포구청역에 있는 맛집 좀 알려주세요.'))
#  |      ['영등포구', '청역', '에', '있', '는', '맛집', '좀', '알려', '주', '세요', '.']
#  |      >>> print(mecab.nouns(u'우리나라에는 무릎 치료를 잘하는 정형외과가 없는가!'))
#  |      ['우리', '나라', '무릎', '치료', '정형외과']
#  |      >>> print(mecab.pos(u'자연주의 쇼핑몰은 어떤 곳인가?'))
#  |      [('자연', 'NNG'), ('주', 'NNG'), ('의', 'JKG'), ('쇼핑몰', 'NNG'), ('은', 'JX'), ('어떤', 'MM'), ('곳', 'NNG'), ('인가', 'VCP+EF'), ('?', 'SF')]
#  |
#  |  :param dicpath: The path of the MeCab-ko dictionary.
#  |
#  |  .. _MeCab: https://code.google.com/p/mecab/
#  |  .. _Eunjeon Project: http://eunjeon.blogspot.kr/
#  |
#  |  Methods defined here:
#  |
#  |  __getstate__(self)
#  |      store arguments.
#  |
#  |  __init__(self, dicpath='/usr/local/lib/mecab/dic/mecab-ko-dic')
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __setstate__(self, state)
#  |      just reinitialize.
#  |
#  |  morphs(self, phrase)
#  |      Parse phrase to morphemes.
#  |
#  |  nouns(self, phrase)
#  |      Noun extractor.
#  |
#  |  pos(self, phrase, flatten=True, join=False)
#  |      POS tagger.
#  |
#  |      :param flatten: If False, preserves eojeols.
#  |      :param join: If True, returns joined sets of morph and tag.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
df['mecab'] = df.content.swifter.apply(lambda x: m.pos(str(x)))
# Out:
# Pandas Apply:   0%|          | 0/10317 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#                   content                                                pos  \
# 0         나 중간고사 반에서 1등했어  [(나, Noun), (중간고사, Noun), (반, Noun), (에서, Josa...
# 1  중간고사 점수 내가 반에서 제일 잘 받음  [(중간고사, Noun), (점수, Noun), (내, Noun), (가, Josa...
# 2       나 반에서 중간 성적 제일 좋아  [(나, Noun), (반, Noun), (에서, Josa), (중간, Noun),...
# 3    우리 반에서 내가 시험 제일 잘 봤다  [(우리, Noun), (반, Noun), (에서, Josa), (내, Noun),...
# 4            중간고사 반 1등 먹음  [(중간고사, Noun), (반, Noun), (1등, Number), (먹음, N...
#
#                                                mecab
# 0  [(나, NP), (중간고사, NNG), (반, NNG), (에서, JKB), (1...
# 1  [(중간고사, NNG), (점수, NNG), (내, NP), (가, JKS), (반...
# 2  [(나, NP), (반, NNG), (에서, JKB), (중간, NNG), (성적,...
# 3  [(우리, NP), (반, NNG), (에서, JKB), (내, NP), (가, J...
# 4  [(중간고사, NNG), (반, NNG), (1, SN), (등, NNBC), (먹...

# %% [markdown]
# ##### change shape

# %%
result = []
for row in df.iterrows():
  for i in row[1]['mecab']:
    temp = []
    temp.append(row[1]['content'])
    temp.append(i)
    result.append(temp)

# %%
pprint(result[:10])
# Out:
# [['나 중간고사 반에서 1등했어', ('나', 'NP')],
#  ['나 중간고사 반에서 1등했어', ('중간고사', 'NNG')],
#  ['나 중간고사 반에서 1등했어', ('반', 'NNG')],
#  ['나 중간고사 반에서 1등했어', ('에서', 'JKB')],
#  ['나 중간고사 반에서 1등했어', ('1', 'SN')],
#  ['나 중간고사 반에서 1등했어', ('등', 'NNBC')],
#  ['나 중간고사 반에서 1등했어', ('했', 'VV+EP')],
#  ['나 중간고사 반에서 1등했어', ('어', 'EC')],
#  ['중간고사 점수 내가 반에서 제일 잘 받음', ('중간고사', 'NNG')],
#  ['중간고사 점수 내가 반에서 제일 잘 받음', ('점수', 'NNG')]]

# %%
df_mecab = pd.DataFrame(result, columns=['origin', 'token'])

# %%
df_mecab['token1'] = df_mecab.token.apply(lambda x: x[0])
df_mecab['token2'] = df_mecab.token.apply(lambda x: x[1])

# %%
df_mecab = df_mecab[['origin', 'token1', 'token2']]
df_mecab.rename(columns={'origin':'유저 발화', 'token1':'토큰', 'token2':'품사'}, inplace=True)
# Out:
# <ipython-input-31-bb1e9d7315a3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mecab.rename(columns={'origin':'유저 발화', 'token1':'토큰', 'token2':'품사'}, inplace=True)

# %%
df_mecab.head()
# Out:
#              유저 발화    토큰   품사
# 0  나 중간고사 반에서 1등했어     나   NP
# 1  나 중간고사 반에서 1등했어  중간고사  NNG
# 2  나 중간고사 반에서 1등했어     반  NNG
# 3  나 중간고사 반에서 1등했어    에서  JKB
# 4  나 중간고사 반에서 1등했어     1   SN

# %% [markdown]
# # pecab

# %%
# !pip3 install pecab

# %%
from pecab import PeCab

# %%
p = PeCab()

# %%
df['pecab'] = df.content.swifter.apply(lambda x: p.pos(str(x)))
# Out:
# Pandas Apply:   0%|          | 0/10317 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/swifter/swifter.py in apply(self, func, convert_dtype, args, **kwds)
#     311                 self._validate_apply(
# --> 312                     np.array_equal(sample_df, tmp_df) & (hasattr(tmp_df, "shape")) & (sample_df.shape == tmp_df.shape),
#     313                     error_message=("Vectorized function sample doesn't match pandas apply sample."),
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-1307af03d95e> in <module>
# ----> 1 df['pecab'] = df.content.swifter.apply(lambda x: p.pos(str(x)))
#
# /usr/local/lib/python3.8/dist-packages/swifter/swifter.py in apply(self, func, convert_dtype, args, **kwds)
#     327                 if self._progress_bar:
#     328                     tqdm.pandas(desc=self._progress_bar_desc or "Pandas Apply")
# --> 329                     return self._obj.progress_apply(func, convert_dtype=convert_dtype, args=args, **kwds)
#     330                 else:
#     331                     return self._obj.apply(func, convert_dtype=convert_dtype, args=args, **kwds)
#
# /usr/local/lib/python3.8/dist-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     812                 # on the df using our wrapper (which provides bar updating)
#     813                 try:
# --> 814                     return getattr(df, df_function)(wrapper, **kwargs)
#     815                 finally:
#     816                     t.close()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4772         dtype: float64
#    4773         """
# -> 4774         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4775
#    4776     def _reduce(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#    1098
#    1099         # self.f is Callable
# -> 1100         return self.apply_standard()
#    1101
#    1102     def agg(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1149             else:
#    1150                 values = obj.astype(object)._values
# -> 1151                 mapped = lib.map_infer(
#    1152                     values,
#    1153                     f,
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /usr/local/lib/python3.8/dist-packages/tqdm/std.py in wrapper(*args, **kwargs)
#     807                     # take a fast or slow code path; so stop when t.total==t.n
#     808                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809                     return func(*args, **kwargs)
#     810
#     811                 # Apply the provided function (in **kwargs)
#
# <ipython-input-36-1307af03d95e> in <lambda>(x)
# ----> 1 df['pecab'] = df.content.swifter.apply(lambda x: p.pos(str(x)))
#
# /usr/local/lib/python3.8/dist-packages/pecab/_pecab.py in pos(self, text, drop_space)
#      40
#      41     def pos(self, text: str, drop_space: bool = True):
# ---> 42         tokenization_output = self._tokenize(text)
#      43         return [
#      44             (token, pos)
#
# /usr/local/lib/python3.8/dist-packages/pecab/_pecab.py in _tokenize(self, text)
#      15     def _tokenize(self, text: str):
#      16         self.tokenizer.set_input(text)
# ---> 17         while self.tokenizer.increment_token():
#      18             pass
#      19
#
# /usr/local/lib/python3.8/dist-packages/pecab/_tokenizer.py in increment_token(self)
#     290             if self.end:
#     291                 return False
# --> 292             self.parse()
#     293
#     294         token = self.pending.pop()
#
# /usr/local/lib/python3.8/dist-packages/pecab/_tokenizer.py in parse(self)
#     438
#     439                 word_id_ref = self.unknown_dict[character_id]
# --> 440                 self.add(
#     441                     character_id,
#     442                     word_id_ref,
#
# /usr/local/lib/python3.8/dist-packages/pecab/_tokenizer.py in add(self, surface, data_dict, from_pos_data, word_pos, end_pos, type_)
#     249     def add(self, surface, data_dict, from_pos_data, word_pos, end_pos, type_):
#     250         word_id = surface
# --> 251         left_pos = data_dict["POS"]
#     252         word_cost = int(data_dict["word_cost"])
#     253         left_id = int(data_dict["left_id"])
#
# TypeError: tuple indices must be integers or slices, not str

# %% [markdown]
# # Save

# %%
df_okt.head()
# Out:
#              유저 발화    토큰      품사
# 0  나 중간고사 반에서 1등했어     나    Noun
# 1  나 중간고사 반에서 1등했어  중간고사    Noun
# 2  나 중간고사 반에서 1등했어     반    Noun
# 3  나 중간고사 반에서 1등했어    에서    Josa
# 4  나 중간고사 반에서 1등했어    1등  Number

# %%
df_mecab.head()
# Out:
#              유저 발화    토큰   품사
# 0  나 중간고사 반에서 1등했어     나   NP
# 1  나 중간고사 반에서 1등했어  중간고사  NNG
# 2  나 중간고사 반에서 1등했어     반  NNG
# 3  나 중간고사 반에서 1등했어    에서  JKB
# 4  나 중간고사 반에서 1등했어     1   SN

# %%
# !ls "/content/drive/MyDrive/MemeProject/data/report/"
# Out:
# comparison.xlsx  report.xlsx

# %%
writer = pd.ExcelWriter("/content/drive/MyDrive/MemeProject/data/report/comparison.xlsx", engine='openpyxl')

df_okt.to_excel(writer, sheet_name='okt')
df_mecab.to_excel(writer, sheet_name='mecab')
 
writer.save()
